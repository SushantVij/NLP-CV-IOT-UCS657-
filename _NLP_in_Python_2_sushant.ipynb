# %% [markdown]
# <a href="https://colab.research.google.com/github/SushantVij/NLP-CV-IOT-UCS657-/blob/main/_NLP_in_Python_2_sushant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ` Data cleaning is a time consuming and unenjoyable task, yet it's a very important one. Keep in mind, "garbage in, garbage out".`
#
# #### Feeding dirty data into a model will give us results that are meaningless.
#
# ### Objective:
#
# 1. Getting the data
# 2. Cleaning the data
# 3. Organizing the data - organize the cleaned data into a way that is easy to input into other algorithms
#
# ### Output :
# #### cleaned and organized data in two standard text formats:
#
# 1. Corpus - a collection of text
# 2. Document-Term Matrix - word counts in matrix format

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Look at transcripts of various comedians and note their similarities and differences and find if the stand up comedian of your choice has comedy style different than other comedian.

# %% [markdown]
# ## Getting The Data

# %% [markdown]
# You can get the transcripts of some comedian from [Scraps From The Loft](http://scrapsfromtheloft.com).
#
# You can take help of IMDB and select only 10 or 20 comedian having highest rating.
#
#
#
#
#
#
# ### For example:

# %% [markdown]
# Tried to correct the original function and successfully removed the error. It still did not fetch the transcripts because there was problem with the class of data we were scraping.

# %% [markdown]
# Wrote the code to fetch the data from the website and save it in a text file.
# Changed the class of the p tag and it worked.

# %%
#%pip install requests
#%pip install BeautifulSoup
from pip._vendor import requests
from bs4 import BeautifulSoup
import pickle

def url_to_transcript(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    text = []
    script = soup.find_all(class_='full-script')[0].get_text()
    script_list = list(script.split('<br/>'))
    return script_list

# URLs of transcripts in scope
urls = ['https://subslikescript.com/series/The_Boys-1190634/season-1/episode-1-The_Name_of_the_Game',
        'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-2-Cherry',
        'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-3-Get_Some',     
        'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-4-The_Female_of_the_Species',
        
        
       
         'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-5-Good_for_the_Soul',
         'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-6-The_Innocents',
         'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-7-The_Self-Preservation_Society',
         'https://subslikescript.com/series/The_Boys-1190634/season-1/episode-8-You_Found_Me']

# Stranger Things Chapter one
seasons = ['s1e1','s1e2','s1e3','s1e4','s1e5','s1e6','s1e7','s1e8']

# %%
# Actually request transcripts (takes a few minutes to run)
transcripts = [url_to_transcript(u) for u in urls]
print(transcripts[1])
# Out:
# ['So, you\'re-you\'re not a Fed?Do you hear that?That\'s the old bill.So unless you want to explainwhy you\'ve gotAmerica\'s favorite invisiblewanker dead on the floor,give us a fucking hand,will ya?Aw, shit.All right, listen,I have worked for the Feds.I\'ve worked for loads of people.I\'m what you might callan independent contractor.You got a problem, you call me,I solve the problem.What is that?\n\n\nThat\'s a problem.Oh, thank fuck, he\'s alive.Yes, yes, he\'s alive!Okay, pull over.No, no, no, Hughie,you don\'t fucking get it.- Pull the car over.- This is a fucksight worse.He\'s seen our faces.Oh, my God.No, no, no, no, no.I can\'t do this.I can\'t do this.Let me out.- Let me out. Pull over!- Hughie,you walk away now, and you willnever get payback for Robin.You\'ll spend the restof your lifesitting on your asswith fucking regret.Now, is that what you want?\n\n\nI know a bloke.Top man.He\'ll know what to do.Morning, luv.Frenchie about?Mmm.You\'ll love this guy.Frenchie.Oi, Frenchie.Monsieur Charcuter.Huh.This is a surprise.Good to see you.Good to see you, too, mate.Means you brought that 40,000you owe me?I mean, why else would youshow your face around here?Because I\'ve got somethingeven better for you.How would you liketo double your money?The double of zero is zero.Who is he?This guy?Oh, this here isHughie Campbell.We\'re, uh, workinga little job together.Ooh.And he\'s still alive?You and I worked together,and you\'re still in one piece.Am I?Look, do you want to knowwhat the fucking job is or not?Open it.Who is in there?Where\'s your sense of adventure, Frenchie?You dumb fucks are fucking dead!Have you any...Aah!That\'s Translucent.You got Translucentin your trunk, huh?Nothing gets past you, mate.Whoa, whoa, whoa, whoa!Go away.Get him out of here.All right, all right, easy.He\'s chipped.The Supes could beon their way.Homelander could be on his wayright now.Wait, he\'s chipped?You bring this to my doorstep?This is not my problem, huh?Well, it is now.He knows what you look like.Look, Frenchie, I needyour help, mate,and I ain\'t leavingtill I get it,or till The Seven show up.Ah, here comes the A-Train!My man, how you doing?Look, I brought you something.- Thanks?- Yeah.I\'m sorry, I askedfor Translucent.Right, but Translucent ison a secret,undercover mission right now.But you got the A-Train, baby.But... my wish wasto meet Translucent.That was my only wish.He\'s my hero.Yeah. Um... well, you know,maybe he can swing bynext week or some...something...Fuck.Um... you know what?Maybe I can\'t turn invisible,but I am the world\'sfastest man.Like, I can outrun anybodyor anything.That\'s-that\'s something, right?Look, I\'ll tell you what,you get better,and I\'ll teach you to runas fast as me.- Yeah?- Yeah.You\'ll teach meto outrun cancer?Yeah.Oh, my God, turn that off.How many times do I haveto tell youthat A-Train needsto be scripted?- Right.- When he does not have a script,- this is what happens.- I\'m on it. I\'m so sorry.- It will not happen again.- All right.And where is Translucent?We know he\'s notin the building.He hasn\'t triggered anyof the motion sensors.He\'s probably out on another oneof his fucking benders.Doesn\'t he have a team-uptomorrow night?Yeah, with the Deep.- Get a backup.- I\'m on it.Okay, go.Okay.Hello?Black Noir.We haven\'t properly met yet.I\'m Starlight.Well...I look forwardto working with you.There she is.Hi. How you settling in?Well, uh, it\'s an adjustment.That\'s for sure.- This is Trevor...- Hi....from Crime Analytics.So, we have exciting newsfor you.We are sending youon your first patrol.It\'s a team-up tomorrow night.Oh, that\'s great.That\'s great news.Thank you.Hi. Big fan.There you go.- A crime itinerary?- Yep.Where and when to findthe bad guys.That\'s what my department does.We vet leads,crunch satellite data,COMP-STAT.Better intel than the police.- Mm.- You know, thanks, but I\'m good.I-I like to domy own investigating.And that is why we love you,but it\'s not coming from us.It\'s corporate.To p ...

# %%
# Pickle files for later use

# Make a new directory to hold the text files
# !mkdir transcripts

for i, c in enumerate(seasons):
    with open("transcripts/" + c + ".txt", "wb") as file:
        pickle.dump(transcripts[i], file)
# Out:
# mkdir: cannot create directory ‘transcripts’: File exists

# %%
# Load pickled files
data = {}
for i, c in enumerate(seasons):
    with open("transcripts/" + c + ".txt", "rb") as file:
        data[c] = pickle.load(file)

# %%
# Double check to make sure data has been loaded properly
data.keys()
# Out:
# dict_keys(['s1e1', 's1e2', 's1e3', 's1e4', 's1e5', 's1e6', 's1e7', 's1e8'])

# %%
# More checks
data['s1e1']
# Out:
# ['Yo, I am so psychedfor Invisible Force 2.Please.Invisible Force 1 was lame.I\'m all about Rising Tide.Rising Tide? The Deep?- Uh-huh.- Translucent could kick the Deep\'s ass.How? He\'s invisible.That\'s, like, all he\'s got.That\'s it.Exactly.He sneaks up on the Deep,and then boom, motherfucker!- Sit down.- Until the Deep makes a sharkbite Translucent\'s dick off.\n\n\nHow\'s he gonna find his dick?It\'s invisible.Holy shit.Benjy!Get up. Get up, get up, get up.Come on, Benjy.Come on, come on.Stay back.Just stay the fuck back.What are you smiling at?Homelander?You boys okay?Can I... can I get a selfie?Course you can.The Seven\'s Queen Maeveand Homelandermade another heroic save today,\n\n\nstoppinga hijacked armored truckon the streets of Brooklyn,then staying behindfor a photo op- with some very lucky fans.- Nice to meet you.- Jean?- Thanks, Jennifer. And now...So, this is pretty mucheverything in one.Bluetooth speakers.It\'s in stereo,so you can put itall around your living room,have some fun with it.You said you havea standard cable box, right?- Uh-huh.- Okay, then I need to get you an audio transmitter,aptX Low Latency.It makes itso there\'s less audio lag,and it\'s gota standard optical in.And let\'s hook you upwith thousand-meg HDMI.Let\'s go with this one.Uh, it costs a little bit more,but the carbon\'sway more conductive.Hey, Gary. Um...- I really need to talk to you about something.- Later, kid.Okay. Cool.Later... you want, like...want, like, 30-30 minutes?Like, a solid 45?Excuse me, sir?Hi. I\'d liketo make an appointmentfor you to come over and...lay some cable.Okay. Uh... oh, Robin.Oh, dear, dear, Robin.Um, that doesn\'t meanwhat you think it means.Um, "laying cable" means sex.No, "laying pipe" means sex."Laying cable" meansyou want meto come over to your houseand just take a big, old shit.- That\'s disgusting.- Well, okay.But you...Who-who said it, though?Okay. Are you ready?Despite your best efforts,I\'m actually still hungry.I\'m actually more hungry now.- Where are we gonna go after all this hot talk?- I don\'t know.- You know?- More importantly, where are we gonna goto lay some cable afterwards?Geez.So, did you ask him?- Who?- Gary.Did you ask Gary for the raise?Yeah. Yeah. It was... it was a...Look, it was a crazy day,and-and he was super busy,but tomorrow for sure. Yes.Okay.What was I supposed to do,kick his door down?Like Homelander?I said "okay."Yeah, but you didn\'t mean it.Hey, I see the look.I see it. Come on.This is like whenwe started dating.I don\'t think that\'s...I don\'t think that\'s true.Dude, I had to ask you out.Well, excuse me for waiting.You ever hear of chivalry?Listen, this is about yougetting what you deserve.I\'m killing myself at schoolbecause I think it\'s gonna beworth it for both of us.You know,if we move in together.Wait, what? What?W-W-Wait. Hey, hey, hey.Hey, hey. What was that?What\'d you just say?Well, I mean, we can\'t keep,you know, laying pipeat your dad\'s place.Trying to be all quiet.Staring up at that dumbBilly Joel post...- ...poster.- Hey.Don\'t you ever besmirchBilly Jo...I can\'t stop. I can\'t stop.I can\'t stop. I can\'t stop.Can\'t stop. Can\'t stop.Robin?Robin?Robin!Robin!Let the energygo through the wall.I am Starlight.I\'m 110 pounds,and I\'m five foot six.Turn around, please.Okay. Let\'s see it, dear.- You should look away.- Sorry?You should turn awayfrom the camera,and you should close your eyes,or else I\'ll blind you.All right.Okay, go ahead.I am so sorry.Are you all right?I was born Super-Abled.Uh, my mom was thrilled.She took me to allthe little miss hero pageants,but I hated it.Ugh, I mean, I can still...smell the hairspray.Uh, but......at the Q and A, they alwaysasked me what my wish was,and I always said,"to save the world."And the judges just chuckledlike it was cute.But it wasn\'t a joke to me.Since whendid "hopeful" and "naive"become the same thing?I mean, why would youget into this businessif not to save the world?That\'s all I have ever wanted.And  ...

# %% [markdown]
# ## Cleaning The Data

# %% [markdown]
# When dealing with numerical data, data cleaning often involves removing null values and duplicate data, dealing with outliers, etc. With text data, there are some common data cleaning techniques, which are also known as text pre-processing techniques.
#
# With text data, this cleaning process can go on forever. There's always an exception to every cleaning step. So, we're going to follow the MVP (minimum viable product) approach - start simple and iterate.
# ### Assignment:
# 1. Perform the following data cleaning on transcripts:
# i) Make text all lower case
# ii) Remove punctuation
# iii) Remove numerical values
# iv) Remove common non-sensical text (/n)
# v) Tokenize text
# vi) Remove stop words

# %%
# Let's take a look at our data again
next(iter(data.keys()))
# Out:
# 's1e1'

# %%
# Notice that our dictionary is currently in key: comedian, value: list of text format
next(iter(data.values()))
# Out:
# ['Yo, I am so psychedfor Invisible Force 2.Please.Invisible Force 1 was lame.I\'m all about Rising Tide.Rising Tide? The Deep?- Uh-huh.- Translucent could kick the Deep\'s ass.How? He\'s invisible.That\'s, like, all he\'s got.That\'s it.Exactly.He sneaks up on the Deep,and then boom, motherfucker!- Sit down.- Until the Deep makes a sharkbite Translucent\'s dick off.\n\n\nHow\'s he gonna find his dick?It\'s invisible.Holy shit.Benjy!Get up. Get up, get up, get up.Come on, Benjy.Come on, come on.Stay back.Just stay the fuck back.What are you smiling at?Homelander?You boys okay?Can I... can I get a selfie?Course you can.The Seven\'s Queen Maeveand Homelandermade another heroic save today,\n\n\nstoppinga hijacked armored truckon the streets of Brooklyn,then staying behindfor a photo op- with some very lucky fans.- Nice to meet you.- Jean?- Thanks, Jennifer. And now...So, this is pretty mucheverything in one.Bluetooth speakers.It\'s in stereo,so you can put itall around your living room,have some fun with it.You said you havea standard cable box, right?- Uh-huh.- Okay, then I need to get you an audio transmitter,aptX Low Latency.It makes itso there\'s less audio lag,and it\'s gota standard optical in.And let\'s hook you upwith thousand-meg HDMI.Let\'s go with this one.Uh, it costs a little bit more,but the carbon\'sway more conductive.Hey, Gary. Um...- I really need to talk to you about something.- Later, kid.Okay. Cool.Later... you want, like...want, like, 30-30 minutes?Like, a solid 45?Excuse me, sir?Hi. I\'d liketo make an appointmentfor you to come over and...lay some cable.Okay. Uh... oh, Robin.Oh, dear, dear, Robin.Um, that doesn\'t meanwhat you think it means.Um, "laying cable" means sex.No, "laying pipe" means sex."Laying cable" meansyou want meto come over to your houseand just take a big, old shit.- That\'s disgusting.- Well, okay.But you...Who-who said it, though?Okay. Are you ready?Despite your best efforts,I\'m actually still hungry.I\'m actually more hungry now.- Where are we gonna go after all this hot talk?- I don\'t know.- You know?- More importantly, where are we gonna goto lay some cable afterwards?Geez.So, did you ask him?- Who?- Gary.Did you ask Gary for the raise?Yeah. Yeah. It was... it was a...Look, it was a crazy day,and-and he was super busy,but tomorrow for sure. Yes.Okay.What was I supposed to do,kick his door down?Like Homelander?I said "okay."Yeah, but you didn\'t mean it.Hey, I see the look.I see it. Come on.This is like whenwe started dating.I don\'t think that\'s...I don\'t think that\'s true.Dude, I had to ask you out.Well, excuse me for waiting.You ever hear of chivalry?Listen, this is about yougetting what you deserve.I\'m killing myself at schoolbecause I think it\'s gonna beworth it for both of us.You know,if we move in together.Wait, what? What?W-W-Wait. Hey, hey, hey.Hey, hey. What was that?What\'d you just say?Well, I mean, we can\'t keep,you know, laying pipeat your dad\'s place.Trying to be all quiet.Staring up at that dumbBilly Joel post...- ...poster.- Hey.Don\'t you ever besmirchBilly Jo...I can\'t stop. I can\'t stop.I can\'t stop. I can\'t stop.Can\'t stop. Can\'t stop.Robin?Robin?Robin!Robin!Let the energygo through the wall.I am Starlight.I\'m 110 pounds,and I\'m five foot six.Turn around, please.Okay. Let\'s see it, dear.- You should look away.- Sorry?You should turn awayfrom the camera,and you should close your eyes,or else I\'ll blind you.All right.Okay, go ahead.I am so sorry.Are you all right?I was born Super-Abled.Uh, my mom was thrilled.She took me to allthe little miss hero pageants,but I hated it.Ugh, I mean, I can still...smell the hairspray.Uh, but......at the Q and A, they alwaysasked me what my wish was,and I always said,"to save the world."And the judges just chuckledlike it was cute.But it wasn\'t a joke to me.Since whendid "hopeful" and "naive"become the same thing?I mean, why would youget into this businessif not to save the world?That\'s all I have ever wanted.And  ...

# %%
# We are going to change this to key: comedian, value: string format
def combine_text(list_of_text):
    '''Takes a list of text and combines them into one large chunk of text.'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combine it!
data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
# We can either keep it in dictionary format or put it into a pandas dataframe
import pandas as pd

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['transcript']
data_df = data_df.sort_index()
data_df
# Out:
#                                              transcript
# s1e1  Yo, I am so psychedfor Invisible Force 2.Pleas...
# s1e2  So, you're-you're not a Fed?Do you hear that?T...
# s1e3  I'll take this.Merci.Sorry about all the...Oh,...
# s1e4  - Come on.- Mm-mm.- Just come with.- Nuh-uh.- ...
# s1e5  Hey, baby.- Oh, Jesus Christ.- Yeah, I'm sorry...
# s1e6  Obviously, a lot of it's temp.I love it.If we'...
# s1e7  Ho, ho, ho! Merry Christmas!Who's been naughty...
# s1e8  Howdy, boys.Oh, sorry.Sorry, sorry, sorry, sor...

# %%
# Let's take a look at the transcript for Ali Wong
data_df.transcript.loc['s1e1']
# Out:
# 'Yo, I am so psychedfor Invisible Force 2.Please.Invisible Force 1 was lame.I\'m all about Rising Tide.Rising Tide? The Deep?- Uh-huh.- Translucent could kick the Deep\'s ass.How? He\'s invisible.That\'s, like, all he\'s got.That\'s it.Exactly.He sneaks up on the Deep,and then boom, motherfucker!- Sit down.- Until the Deep makes a sharkbite Translucent\'s dick off.\n\n\nHow\'s he gonna find his dick?It\'s invisible.Holy shit.Benjy!Get up. Get up, get up, get up.Come on, Benjy.Come on, come on.Stay back.Just stay the fuck back.What are you smiling at?Homelander?You boys okay?Can I... can I get a selfie?Course you can.The Seven\'s Queen Maeveand Homelandermade another heroic save today,\n\n\nstoppinga hijacked armored truckon the streets of Brooklyn,then staying behindfor a photo op- with some very lucky fans.- Nice to meet you.- Jean?- Thanks, Jennifer. And now...So, this is pretty mucheverything in one.Bluetooth speakers.It\'s in stereo,so you can put itall around your living room,have some fun with it.You said you havea standard cable box, right?- Uh-huh.- Okay, then I need to get you an audio transmitter,aptX Low Latency.It makes itso there\'s less audio lag,and it\'s gota standard optical in.And let\'s hook you upwith thousand-meg HDMI.Let\'s go with this one.Uh, it costs a little bit more,but the carbon\'sway more conductive.Hey, Gary. Um...- I really need to talk to you about something.- Later, kid.Okay. Cool.Later... you want, like...want, like, 30-30 minutes?Like, a solid 45?Excuse me, sir?Hi. I\'d liketo make an appointmentfor you to come over and...lay some cable.Okay. Uh... oh, Robin.Oh, dear, dear, Robin.Um, that doesn\'t meanwhat you think it means.Um, "laying cable" means sex.No, "laying pipe" means sex."Laying cable" meansyou want meto come over to your houseand just take a big, old shit.- That\'s disgusting.- Well, okay.But you...Who-who said it, though?Okay. Are you ready?Despite your best efforts,I\'m actually still hungry.I\'m actually more hungry now.- Where are we gonna go after all this hot talk?- I don\'t know.- You know?- More importantly, where are we gonna goto lay some cable afterwards?Geez.So, did you ask him?- Who?- Gary.Did you ask Gary for the raise?Yeah. Yeah. It was... it was a...Look, it was a crazy day,and-and he was super busy,but tomorrow for sure. Yes.Okay.What was I supposed to do,kick his door down?Like Homelander?I said "okay."Yeah, but you didn\'t mean it.Hey, I see the look.I see it. Come on.This is like whenwe started dating.I don\'t think that\'s...I don\'t think that\'s true.Dude, I had to ask you out.Well, excuse me for waiting.You ever hear of chivalry?Listen, this is about yougetting what you deserve.I\'m killing myself at schoolbecause I think it\'s gonna beworth it for both of us.You know,if we move in together.Wait, what? What?W-W-Wait. Hey, hey, hey.Hey, hey. What was that?What\'d you just say?Well, I mean, we can\'t keep,you know, laying pipeat your dad\'s place.Trying to be all quiet.Staring up at that dumbBilly Joel post...- ...poster.- Hey.Don\'t you ever besmirchBilly Jo...I can\'t stop. I can\'t stop.I can\'t stop. I can\'t stop.Can\'t stop. Can\'t stop.Robin?Robin?Robin!Robin!Let the energygo through the wall.I am Starlight.I\'m 110 pounds,and I\'m five foot six.Turn around, please.Okay. Let\'s see it, dear.- You should look away.- Sorry?You should turn awayfrom the camera,and you should close your eyes,or else I\'ll blind you.All right.Okay, go ahead.I am so sorry.Are you all right?I was born Super-Abled.Uh, my mom was thrilled.She took me to allthe little miss hero pageants,but I hated it.Ugh, I mean, I can still...smell the hairspray.Uh, but......at the Q and A, they alwaysasked me what my wish was,and I always said,"to save the world."And the judges just chuckledlike it was cute.But it wasn\'t a joke to me.Since whendid "hopeful" and "naive"become the same thing?I mean, why would youget into this businessif not to save the world?That\'s all I have ever wanted.And t ...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('\©', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_df.transcript.apply(round1))
data_clean
# Out:
#                                              transcript
# s1e1  yo i am so psychedfor invisible force  force  ...
# s1e2  so youreyoure not a feddo you hear thatthats t...
# s1e3  ill take thismercisorry about all theoh dont b...
# s1e4   come on mmmm just come with nuhuh please no f...
# s1e5  hey baby oh jesus christ yeah im sorrywhere ha...
# s1e6  obviously a lot of its tempi love itif were ai...
# s1e7  ho ho ho merry christmaswhos been naughty it i...
# s1e8  howdy boysoh sorrysorry sorry sorry sorryhow a...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                              transcript
# s1e1  yo i am so psychedfor invisible force  force  ...
# s1e2  so youreyoure not a feddo you hear thatthats t...
# s1e3  ill take thismercisorry about all theoh dont b...
# s1e4   come on mmmm just come with nuhuh please no f...
# s1e5  hey baby oh jesus christ yeah im sorrywhere ha...
# s1e6  obviously a lot of its tempi love itif were ai...
# s1e7  ho ho ho merry christmaswhos been naughty it i...
# s1e8  howdy boysoh sorrysorry sorry sorry sorryhow a...

# %% [markdown]
# ## Organizing The Data

# %% [markdown]
# ### Assignment:
# 1. Organized data in two standard text formats:
#    a) Corpus - corpus is a collection of texts, and they are all put together neatly in a pandas dataframe here.
#    b) Document-Term Matrix - word counts in matrix format

# %% [markdown]
# ### Corpus: Example

# %% [markdown]
# A corpus is a collection of texts, and they are all put together neatly in a pandas dataframe here.

# %%
# Let's take a look at our dataframe
data_df
# Out:
#                                              transcript
# s1e1  Yo, I am so psychedfor Invisible Force 2.Pleas...
# s1e2  So, you're-you're not a Fed?Do you hear that?T...
# s1e3  I'll take this.Merci.Sorry about all the...Oh,...
# s1e4  - Come on.- Mm-mm.- Just come with.- Nuh-uh.- ...
# s1e5  Hey, baby.- Oh, Jesus Christ.- Yeah, I'm sorry...
# s1e6  Obviously, a lot of it's temp.I love it.If we'...
# s1e7  Ho, ho, ho! Merry Christmas!Who's been naughty...
# s1e8  Howdy, boys.Oh, sorry.Sorry, sorry, sorry, sor...

# %%
# Let's add the comedians' full names as well
full_names = ['s1e1','s1e2','s1e3','s1e4','s1e5','s1e6','s1e7','s1e8']

data_df['full_name'] = full_names

data_df
# Out:
#                                              transcript full_name
# s1e1  Yo, I am so psychedfor Invisible Force 2.Pleas...      s1e1
# s1e2  So, you're-you're not a Fed?Do you hear that?T...      s1e2
# s1e3  I'll take this.Merci.Sorry about all the...Oh,...      s1e3
# s1e4  - Come on.- Mm-mm.- Just come with.- Nuh-uh.- ...      s1e4
# s1e5  Hey, baby.- Oh, Jesus Christ.- Yeah, I'm sorry...      s1e5
# s1e6  Obviously, a lot of it's temp.I love it.If we'...      s1e6
# s1e7  Ho, ho, ho! Merry Christmas!Who's been naughty...      s1e7
# s1e8  Howdy, boys.Oh, sorry.Sorry, sorry, sorry, sor...      s1e8

# %%
# Let's pickle it for later use
data_df.to_pickle("corpus.pkl")

# %% [markdown]
# ### Document-Term Matrix: Example

# %% [markdown]
# For many of the techniques we'll be using in future assignment, the text must be tokenized, meaning broken down into smaller pieces. The most common tokenization technique is to break down text into words. We can do this using scikit-learn's ` CountVectorizer `, where every row will represent a different document and every column will represent a different word.
#
# In addition, with ` CountVectorizer `, we can remove stop words. Stop words are common words that add no additional meaning to text such as 'a', 'the', etc.

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm
# Out:
#       aa  aapologiesplease  aare  aautograph  abandoning  abbeythen  able  \
# s1e1   0                 0     1           0           0          0     0
# s1e2   0                 0     0           0           0          0     0
# s1e3   0                 0     0           1           0          0     0
# s1e4   0                 0     0           0           0          0     1
# s1e5   0                 0     0           0           0          0     0
# s1e6   1                 1     0           0           0          1     0
# s1e7   0                 0     0           0           0          0     0
# s1e8   0                 0     0           0           1          0     0
#
#       ableto  abletoto  aboardthe  ...  youyoure  youyouve  yyou  yyoull  \
# s1e1       0         1          0  ...         0         0     0       0
# s1e2       1         0          0  ...         0         0     0       0
# s1e3       0         0          1  ...         2         1     1       0
# s1e4       0         0          0  ...         0         0     0       0
# s1e5       0         0          0  ...         1         0     0       0
# s1e6       1         0          0  ...         0         0     0       0
# s1e7       0         0          0  ...         1         1     0       0
# s1e8       0         0          0  ...         0         0     1       1
#
#       yyour  zero  zerothe  zerowho  zinc  zoneand
# s1e1      0     0        0        0     0        0
# s1e2      0     1        0        1     0        0
# s1e3      0     0        0        0     2        0
# s1e4      0     0        0        0     0        0
# s1e5      0     0        0        0     0        0
# s1e6      0     0        0        0     0        0
# s1e7      0     0        1        0     0        0
# s1e8      1     0        0        0     0        1
#
# [8 rows x 10086 columns]

# %%
# Let's pickle it for later use
data_dtm.to_pickle("dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
data_clean.to_pickle('data_clean.pkl')
pickle.dump(cv, open("cv.pkl", "wb"))

# %% [markdown]
# ## Additional Assignments:

# %% [markdown]
# 1. Can you add an additional regular expression to the clean_text_round2 function to further clean the text?
# 2. Play around with CountVectorizer's parameters. What is ngram_range? What is min_df and max_df?

# %%
# adding regex to remove to clean_text_round2 function to further clean the data
def clean_text_round2(text):
    #remove punctuations
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)        
    #remove links
    text = re.sub(r'http\S+', '', text)
    text = re.sub('www\S+', '', text)
    text = re.sub("-", "", text)
    text = re.sub('\©', '', text)
    return text

#run the function
round2 = lambda x: clean_text_round2(x)
#print the updated text
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                              transcript
# s1e1  yo i am so psychedfor invisible force  force  ...
# s1e2  so youreyoure not a feddo you hear thatthats t...
# s1e3  ill take thismercisorry about all theoh dont b...
# s1e4   come on mmmm just come with nuhuh please no f...
# s1e5  hey baby oh jesus christ yeah im sorrywhere ha...
# s1e6  obviously a lot of its tempi love itif were ai...
# s1e7  ho ho ho merry christmaswhos been naughty it i...
# s1e8  howdy boysoh sorrysorry sorry sorry sorryhow a...

# %%
#2. Play around with CountVectorizer's parameters. What is ngram_range? What is min_df and max_df?
#use the CountVectorizer to create a document-term matrix
cv = CountVectorizer(stop_words='english', ngram_range=(2,3), min_df=0.2, max_df=0.7)
data_cv = cv.fit_transform(data_clean.transcript)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index
data_dtm
# Out:
#       account yeah  actually really  aint exactly  aint got  aint hurt  \
# s1e1             0                0             0         0          0
# s1e2             0                0             0         1          0
# s1e3             0                0             1         1          1
# s1e4             0                0             0         0          0
# s1e5             0                1             0         0          1
# s1e6             0                1             1         0          0
# s1e7             1                0             0         0          0
# s1e8             1                0             0         0          0
#
#       aint seen  armed forcesthe  ask herfor  babyi got  beatthe living  ...  \
# s1e1          0                0           0          0               0  ...
# s1e2          0                0           0          0               0  ...
# s1e3          1                1           0          0               0  ...
# s1e4          1                0           1          0               1  ...
# s1e5          0                0           1          0               0  ...
# s1e6          0                0           0          1               1  ...
# s1e7          0                1           0          1               0  ...
# s1e8          0                0           0          0               0  ...
#
#       youre good  youre just  youre really  youre right  youto make  \
# s1e1           0           0             0            0           0
# s1e2           1           0             0            0           0
# s1e3           0           0             0            1           0
# s1e4           0           1             0            0           0
# s1e5           0           0             1            0           0
# s1e6           1           0             1            0           1
# s1e7           0           1             0            1           1
# s1e8           0           0             0            0           0
#
#       youve got  youyou dont  youyou guys  youyou know  youyou look
# s1e1          1            0            1            0            0
# s1e2          0            0            0            0            0
# s1e3          0            0            0            0            0
# s1e4          0            0            1            1            0
# s1e5          2            2            0            0            0
# s1e6          0            1            0            1            1
# s1e7          0            0            0            1            1
# s1e8          0            0            0            0            0
#
# [8 rows x 370 columns]

# %%
cv.get_feature_names_out()
# Out:
# array(['account yeah', 'actually really', 'aint exactly', 'aint got',
#        'aint hurt', 'aint seen', 'armed forcesthe', 'ask herfor',
#        'babyi got', 'beatthe living', 'beingan upstanding', 'big old',
#        'black vanwith', 'break bones', 'butcher got', 'butyou know',
#        'come butcher', 'come lets', 'come oni', 'come onthis',
#        'come yeah', 'compound vits', 'compound vto', 'compound vwhat',
#        'courseyou think', 'day robin', 'did break', 'did tell',
#        'did youi', 'didnt bring', 'didnt kill', 'didnt know',
#        'didnt mean', 'didnt tell', 'doesnt feel', 'doesnt matterhow',
#        'dont actually', 'dont dont', 'dont fucking', 'dont just',
#        'dont just tell', 'dont kill', 'dont know did', 'dont know dont',
#        'dont knowi', 'dont knowif', 'dont knowwhat', 'dont like',
#        'dont mean', 'dont need', 'dont really', 'dont really know',
#        'dont say', 'dont think', 'dont trust', 'dont wantyour',
#        'dont wantyour fucking', 'dont worry', 'dont worry ill',
#        'fast yeah', 'felt like', 'filthy pigwho', 'filthy pigwho likes',
#        'frenchieyou just', 'fuck im', 'fuck know', 'fuck thinkingcoming',
#        'fuck wantwhat', 'fucking baby', 'fucking job', 'fucking worth',
#        'gay away', 'goall right', 'god oh', 'godi mean', 'going onabout',
#        'goingim gonna', 'gonna burst', 'gonna care', 'gonna fucking',
#        'gonna hot', 'gonna kill', 'gonna lose', 'gonna love',
#        'gonna make', 'gonna need', 'gonna pass', 'gonna save',
#        'gonna sit', 'gonna tell', 'gonna try', 'gonna vote', 'gonna want',
#        'good friend', 'good im', 'got cold', 'got eyes', 'got got',
#        'got nothingto', 'got nothingto worry', 'got tell', 'got vought',
#        'got yeah', 'great job', 'hada crush', 'havent seen',
#        'help meunderstand', 'help youim', 'hereall right', 'hes got',
#        'hey hey', 'hey hey hey', 'hi good', 'hit himwith', 'house im',
#        'howi dont', 'hughiejust like', 'hughieyou know', 'id like',
#        'ii did', 'ii got', 'iii really', 'ill tell', 'im fine',
#        'im going', 'im gonna', 'im im', 'im kind', 'im like', 'im sorryi',
#        'im sorryii', 'im sorryim', 'im stupid', 'im supposed',
#        'im talking', 'itall right', 'iti mean', 'ityoure filthy',
#        'ityoure filthy pigwho', 'iyou know', 'just dont', 'just feel',
#        'just gonna', 'just got', 'just haveto', 'just leave', 'just like',
#        'just listen', 'just little', 'just need', 'just needto',
#        'just old', 'just say', 'just saying', 'just tell', 'just trying',
#        'just uh', 'just want', 'just wants', 'just yeah', 'kid gonna',
#        'know did', 'know doesnt', 'know dont', 'know hes', 'know im',
#        'know ive', 'know just', 'know kind', 'know know', 'know knowim',
#        'know like', 'know liketo', 'know mean', 'know thatbut',
#        'know think', 'know wasthinking', 'know whati', 'know whatim',
#        'know whats', 'knowabout compound', 'knowi know', 'knowi mean',
#        'knowyou dont', 'let gomy', 'lets just', 'like come', 'like rest',
#        'like thatall', 'like thatim', 'like thatyou', 'like thiswell',
#        'likes eat', 'little bit', 'little bitof', 'little fucking',
#        'long enoughto', 'look ii', 'look like', 'look look', 'looks like',
#        'love love', 'love youi', 'love youi love', 'love youyou',
#        'make differencei', 'make surethat', 'makes think', 'man im',
#        'matter timebefore', 'maybe im', 'mean dont', 'mean home',
#        'mean ii', 'mean know', 'mean people', 'mean really', 'mean thats',
#        'mean yeah', 'meet palgood', 'meet palgood meet', 'mei dont',
#        'mei mean', 'meto come', 'minutes ago', 'mmhmm yeah',
#        'ms stillwell', 'need know', 'need right', 'need talk',
#        'new world', 'new york', 'nice meet', 'noi mean',
#        'nothingto worry', 'oh born', 'oh god', 'oh god oh', 'oh shit',
#        'oh yeah', 'okay dont', 'okay just', 'okay look', 'okay yeahi',
#        'okayall right', 'okayyoure gonna', 'old uniform', 'owe mei',
#        'palgood meet', 'pigwho likes', 'pigwho likes eat', 'plane went',
#        'pretty sure', 'ready mmhmm', 'really did', 'really dont',
#        'really gonna', 'really good', 'really know', 'really nice',
#        'really niceto', 'really thought', 'really want', 'really yeah',
#        'right does', 'right im', 'right little', 'right nowand',
#        'right right', 'right thats', 'right want', 'right youre',
#        'righti mean', 'rightyeah im', 'rightyeah yeah',
#        'rightyou fucking', 'rightyou know', 'said im', 'say ityoure',
#        'say ityoure filthy', 'say youre', 'sell shit', 'seven just',
#        'shit right', 'shut fuck', 'sit hereand', 'skinny white',
#        'social media', 'son holy', 'sorry did', 'sorry im', 'sorry okay',
#        'sorryi dont', 'sorryim sorry', 'sound like', 'stay fuck',
#        'stop stop', 'team mm', 'tell meor', 'tell mewhat', 'tell mewhere',
#        'tell whats', 'tell youwhat', 'thank thank', 'thati dont',
#        'thats just', 'thats love', 'thats right', 'thats thats',
#        'themi mean', 'thing isi', 'thingyou know', 'think hes',
#        'think im', 'think maybe', 'think timefor', 'think youre',
#        'thisi mean', 'times haveto', 'transoceanic flight', 'uh didnt',
#        'uh im', 'uh yeah', 'uhi dont', 'uhi dont know', 'vought tell',
#        'wait wait', 'waitwait wait', 'want come', 'want kill',
#        'want know', 'want meto', 'want meto come', 'want tell',
#        'want youto', 'wantyour fucking', 'way did', 'whats going',
#        'whoa whoa', 'whoa whoawhoa', 'whoa whoawhoa whoa',
#        'whoawhoa whoa', 'worry ill', 'yeah dont', 'yeah got', 'yeah ii',
#        'yeah im', 'yeah know', 'yeah oh', 'yeah sure', 'yeah thats',
#        'yeah yeah', 'yeahi mean', 'yes yes', 'youhow know', 'youi know',
#        'youi love', 'youi need', 'youre fucking', 'youre going',
#        'youre good', 'youre just', 'youre really', 'youre right',
#        'youto make', 'youve got', 'youyou dont', 'youyou guys',
#        'youyou know', 'youyou look'], dtype=object)

# %% [markdown]
# <b> Question </b>: What is ngram range? </br>
# <b> Answer </b> : ngram_range is a parameter in CountVectorizer. It is used to specify the minimum and maximum number of words in a phrase. For example, if we set ngram_range=(1,2), then the vectorizer will create phrases of 1 word and 2 words. If we set ngram_range=(2,2), then the vectorizer will create phrases of 2 words only.
#
#
# <b> Question </b>: What is min_df and max_df? </br>
# <b> Answer </b>: min_df is a parameter in CountVectorizer. It is used to specify the minimum number of documents a word must be present in to be kept. For example, if we set min_df=0.5, then the vectorizer will ignore words that are present in less than 50% of the documents. If we set min_df=2, then the vectorizer will ignore words that are present in less than 2 documents.
# max_df is a parameter in CountVectorizer. It is used to specify the maximum number of documents a word must be present in to be kept. For example, if we set max_df=0.8, then the vectorizer will ignore words that are present in more than 80% of the documents.
