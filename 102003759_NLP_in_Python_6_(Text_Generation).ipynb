# %% [markdown]
# <a href="https://colab.research.google.com/github/SushantVij/NLP-CV-IOT-UCS657-/blob/main/102003759_NLP_in_Python_6_(Text_Generation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                              transcript full_name
# s1e1  Yo, I am so psychedfor Invisible Force 2.Pleas...      s1e1
# s1e2  So, you're-you're not a Fed?Do you hear that?T...      s1e2
# s1e3  I'll take this.Merci.Sorry about all the...Oh,...      s1e3
# s1e4  - Come on.- Mm-mm.- Just come with.- Nuh-uh.- ...      s1e4
# s1e5  Hey, baby.- Oh, Jesus Christ.- Yeah, I'm sorry...      s1e5
# s1e6  Obviously, a lot of it's temp.I love it.If we'...      s1e6
# s1e7  Ho, ho, ho! Merry Christmas!Who's been naughty...      s1e7
# s1e8  Howdy, boys.Oh, sorry.Sorry, sorry, sorry, sor...      s1e8

# %%
# Extract only Ali Wong's text
s1e7_text = data.transcript.loc['s1e7']
s1e7_text[:200]
# Out:
# "Ho, ho, ho! Merry Christmas!Who's been naughty?- It is dead center on your brand.- Mm-hmm.- Let's get a picture.- I love pictures.Hey.Smile.Another one.Oi, gorgeous.- Vodka soda, hold the soda.- Thank"

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %% [markdown]
#
# This code creates a Markov chain from a given string of text. It tokenizes the text by word, including punctuation, and then creates a dictionary with each word as a key and each value as the list of words that come after the key in the text. The code uses the defaultdict from the collections library to initialize a dictionary that holds all of the words and next words, and then zips them together into word: list of next words format. Finally, it converts the default dict back into a regular dictionary and returns it.

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
s1e7_dict = markov_chain(s1e7_text)
s1e7_dict
# Out:
# {'Ho,': ['ho,'],
#  'ho,': ['ho!'],
#  'ho!': ['Merry'],
#  'Merry': ["Christmas!Who's"],
#  "Christmas!Who's": ['been'],
#  'been': ['naughty?-',
#   'great.But',
#   'helping',
#   'sneaking',
#   'following',
#   'thinkingabout',
#   'stupidto',
#   'up',
#   'raisedin',
#   'feedingthe',
#   'using'],
#  'naughty?-': ['It'],
#  'It': ['is', "doesn't", "wasn't"],
#  'is': ['dead',
#   'my',
#   'all',
#   'a',
#   'notas',
#   'just',
#   'killing',
#   'getting',
#   'fair',
#   'Hughie',
#   'this',
#   'Hugh',
#   'insane.Starlight,',
#   'not',
#   'true,',
#   'just',
#   'next,',
#   'fuckingplaying',
#   'he',
#   "burned.They've",
#   'he?-',
#   'this',
#   'that?I',
#   'it?You',
#   'the',
#   'gone',
#   'this,',
#   'beautiful.Thank',
#   'about',
#   "Mallory.I'm",
#   'worse,',
#   'gonna',
#   'tenacious.The',
#   'my',
#   'fair',
#   'dead.And',
#   'going',
#   'that',
#   'always',
#   'so',
#   'about'],
#  'dead': ['center', 'womanwho', 'before'],
#  'center': ['on'],
#  'on': ['your',
#   'your',
#   'fucking',
#   'a',
#   'purpose.So',
#   'a',
#   'the',
#   'youback',
#   'a',
#   'you.You',
#   'the',
#   'itany'],
#  'your': ['brand.-',
#   '"A"',
#   'nametag.Yes,',
#   'place?Well,',
#   'place,or',
#   "job.You're",
#   'per',
#   'eyeon',
#   'sides,',
#   'fucking',
#   'responsibility',
#   'sakes.Class',
#   'dick.-',
#   'baby',
#   'ass',
#   'girlfriend.-',
#   'sleeve.Okay.',
#   'girlfriend.You',
#   'toys?-',
#   'wife.I',
#   'good',
#   'head',
#   'name,',
#   'uncle,',
#   'way,even',
#   'child.Pregnant?Wh...But',
#   'corporationare',
#   'superheroesare',
#   'capes.-',
#   'cutelittle',
#   'help.Yeah.'],
#  'brand.-': ['Mm-hmm.-'],
#  'Mm-hmm.-': ["Let's"],
#  "Let's": ['get', 'get'],
#  'get': ['a',
#   'the',
#   'enoughof',
#   '$75',
#   'out',
#   'this,leave',
#   'burned?Mesmer.',
#   'it.Everything',
#   'Maria',
#   'up',
#   'you',
#   'away,start',
#   'you',
#   'the',
#   'a',
#   'it.Jamming',
#   'down!What',
#   'back'],
#  'a': ['picture.-',
#   'little',
#   'cigar',
#   '"but"',
#   'hotel?Hmm?',
#   'mystery',
#   'nice',
#   'red',
#   'hero',
#   'couple',
#   'day.Grocery',
#   'Dairy',
#   'shitholelike',
#   'fuckingfaster',
#   'freak',
#   'seat,',
#   'little',
#   'joke?Why',
#   'man,',
#   'different',
#   'little',
#   'shit',
#   'shit',
#   'compellingfucking',
#   'few',
#   'fucking',
#   'choice.She',
#   'fewflying',
#   'dead',
#   'lot',
#   'fucking',
#   'whiff,a',
#   'second.She',
#   'fan!You',
#   'fan,',
#   'dabbler,',
#   'little',
#   'bigger',
#   'real',
#   'millisecond.-',
#   "kid.You're",
#   'name.And',
#   'name,',
#   'mistake.The',
#   'grown-ass',
#   'hug.',
#   'picture.You',
#   'sleepover.Can',
#   "mommy.I'm",
#   'water',
#   'good',
#   'little',
#   "daughter!No!Don't",
#   'few',
#   'fucking',
#   'family.So',
#   "deal.I'm",
#   'secure',
#   'few',
#   'hell',
#   'lad',
#   'plate,and',
#   'first.Eight',
#   'secure',
#   'boy?Does',
#   'perfect',
#   'home',
#   'familywho',
#   'cold',
#   'fucking',
#   'gun.-',
#   'human',
#   'deal.Everyone',
#   'good',
#   'shit,but',
#   'lovelyshade',
#   'bitchstill',
#   'Supe',
#   'murderer.We',
#   'choice.-',
#   'choice.-',
#   'long'],
#  'picture.-': ['I'],
#  'I': ['love',
#   'have',
#   'loved',
#   'wouldlove',
#   'just...Mm.',
#   "can't",
#   'mean,you',
#   'know',
#   'mean,everyone',
#   'got',
#   'missed',
#   'am',
#   'know',
#   "wasn't...It's",
#   'should',
#   'knowthat',
#   "didn't",
#   'say',
#   'mean...There',
#   "don't",
#   "can't.-",
#   'managed',
#   'think',
#   "don't",
#   'right?-',
#   'did',
#   'catch',
#   'got',
#   'hope',
#   'get',
#   "don't",
#   'got.Special',
#   'do',
#   'hand',
#   'kill',
#   'made',
#   'get',
#   "ain't",
#   "checked,you're",
#   'was',
#   'see?Oh,',
#   'supposed',
#   'just',
#   'was,',
#   'wasthinking',
#   "don't",
#   'said',
#   'can',
#   'have',
#   'had',
#   'say,',
#   'take',
#   "can't",
#   "don't",
#   'said.You',
#   'think',
#   'doing',
#   'thought',
#   "couldn't.So",
#   'raise',
#   'turned',
#   'thinkwhat',
#   "don't",
#   'get',
#   'hope?Someone',
#   'missing?Just',
#   'could'],
#  'love': ['pictures.Hey.Smile.Another', 'it'],
#  'pictures.Hey.Smile.Another': ['one.Oi,'],
#  'one.Oi,': ['gorgeous.-'],
#  'gorgeous.-': ['Vodka'],
#  'Vodka': ['soda,'],
#  'soda,': ['hold'],
#  'hold': ['the', 'on', 'on.To'],
#  'the': ['soda.-',
#   "food's",
#   'sound',
#   'work.She',
#   'experts.Listen,',
#   'fuck',
#   'fuck',
#   'hotelis',
#   'localbranch',
#   'whole',
#   'street.To',
#   'best',
#   'board.Not',
#   'doc.Your',
#   'basics.Nobody',
#   'rest',
#   'ball,',
#   'gates.I',
#   'guyswho',
#   'looks',
#   'Deep.Whoa,',
#   'single',
#   'golden',
#   'last',
#   'guy.Hughie',
#   'work,is',
#   'rest',
#   'house',
#   'fuck',
#   'fuckis',
#   'fastest?If',
#   'fuck',
#   'V?-',
#   'B.A.',
#   'Pentagonis',
#   'low',
#   'baby',
#   'suit.Well,',
#   'flesh.I',
#   'fuck',
#   'personwho',
#   'same',
#   'phone...-',
#   'phone',
#   'Oriental',
#   "lab,I'll",
#   'lab.',
#   'old',
#   'sizeof',
#   'potential',
#   'table.A-And',
#   'baby?Lived',
#   'right',
#   "world's",
#   'phone',
#   'last',
#   'linethat',
#   'same',
#   'worst.What',
#   'U.S.',
#   "floor.They're",
#   'conceptfor',
#   'deal',
#   'governmentand',
#   'military,and',
#   'century.Vought',
#   'hell',
#   'problem?Watch.We',
#   'fuck',
#   'cops!',
#   'only',
#   'only',
#   'Supes',
#   'fuck',
#   'fuck'],
#  'soda.-': ['Thank'],
#  'Thank': ['you.Drinks', 'you.-'],
#  'you.Drinks': ['are'],
#  'are': ['free,but',
#   'getting',
#   'you',
#   'frozenand',
#   'askingall',
#   'we?How',
#   'you?My',
#   'these?',
#   'you',
#   'a',
#   'you',
#   'no',
#   'you',
#   'you'],
#  'free,but': ['the'],
#  "food's": ['bloody'],
#  'bloody': ['awful.Ahi'],
#  'awful.Ahi': ['tartare,'],
#  'tartare,': ['for'],
#  'for': ["fuck's",
#   'shit.That',
#   'you.All',
#   'you?-',
#   'a',
#   'theirs.That',
#   'yourself.Jings.Cold',
#   'Homelanderright',
#   'you?For',
#   '15',
#   'a',
#   'your'],
#  "fuck's": ['sakes.\n\n\nOkay.'],
#  'sakes.\n\n\nOkay.': ['Just'],
#  'Just': ['let', 'what?Fuck', 'listen'],
#  'let': ['me', 'us', 'him', 'anythingget'],
#  'me': ['shakea',
#   'out.W-What',
#   'wonder,which',
#   'a',
#   'before.Not',
#   "what's",
#   'a',
#   'and',
#   'to',
#   'one',
#   'about',
#   'Uncle',
#   'John',
#   'with',
#   'now?You',
#   'that',
#   'in,-'],
#  'shakea': ['few'],
#  'few': ['more', 'Mai', 'hundred', 'cards', 'daysafter', 'nights.No,'],
#  'more': ['hands,and', 'fucking', 'club', 'of'],
#  'hands,and': ['then'],
#  'then': ["we'll", 'you'],
#  "we'll": ['beout'],
#  'beout': ['of'],
#  'of': ['here...',
#   'that.-',
#   'stuff,so',
#   'my',
#   'here.-',
#   'a',
#   'pointless.And',
#   "A.We're",
#   'that',
#   'youhave',
#   'sorts.Erratic.Unreliable.Downright',
#   'you...It',
#   'the',
#   'yoursis',
#   "Popclaw's",
#   'it,not',
#   'one.But...',
#   'the',
#   'us',
#   'adrenalineand',
#   'us.Now,',
#   'trouble.Dad,',
#   'one',
#   'your-',
#   'these?Watch',
#   'Lockheed.-',
#   'these',
#   'a',
#   "yours.'Cause,",
#   'those?You',
#   'a',
#   'here.Just',
#   'theselobsters',
#   'a',
#   'fact,',
#   'her.The',
#   'ten',
#   'yourself.All',
#   'the',
#   'orange',
#   'Damascus.Right,',
#   'a',
#   'press.The'],
#  'here...': ['whoa.Easy,'],
#  'whoa.Easy,': ['tiger.I'],
#  'tiger.I': ['want'],
#  'want': ['you',
#   'to',
#   'to',
#   'to',
#   'her,',
#   'to',
#   'with',
#   'none,',
#   'to',
#   'to',
#   'anythingfrom',
#   'to',
#   'this',
#   'to'],
#  'you': ['on',
#   'know?-',
#   'handledmy',
#   'take',
#   'up',
#   'weresuch',
#   'bring',
#   'know.I',
#   'got',
#   'ina',
#   'want',
#   'know,',
#   'see',
#   'guys.Just',
#   'want',
#   'came',
#   'were',
#   'do',
#   'and',
#   'got',
#   'go.She',
#   "were.That's",
#   'got',
#   'gave',
#   "don't",
#   "ain't",
#   'a',
#   'wouldrecognize',
#   'okay?Oh,',
#   'understand',
#   'get',
#   'will!Hey,',
#   "don't?So",
#   "don't",
#   'can',
#   'take',
#   'try',
#   'kill',
#   'threw',
#   'and',
#   'didwas',
#   'were',
#   'been',
#   'a',
#   'help',
#   'and',
#   'rememberthat',
#   'mean,',
#   'knewwhat',
#   'are',
#   'go',
#   'here',
#   'should',
#   'little',
#   'like',
#   'know,',
#   'expect',
#   'find',
#   'met',
#   "payback.Who's",
#   'want',
#   'end',
#   "can't",
#   'out',
#   'blewthe',
#   'swore',
#   'and',
#   'go.Dr.',
#   'ever,',
#   'mindif',
#   "knewthat'd",
#   'tell',
#   'telling',
#   'can',
#   'want?What?What',
#   'want...',
#   'raised',
#   'again,Marvin.Come',
#   'want',
#   'okay?I',
#   'and',
#   'doto',
#   'want?-',
#   'go',
#   'telling',
#   'kill',
#   "haven't",
#   'doing?-',
#   'in.-',
#   'better-',
#   'bring',
#   'talking',
#   'thinking,coming'],
#  '"A"': ['game.-', 'game?-'],
#  'game.-': ['"A"'],
#  'game?-': ['Mm-hmm.You'],
#  'Mm-hmm.You': ['know,I'],
#  'know,I': ['like'],
#  'like': ['the',
#   'pancakes?-',
#   'you',
#   'Sandusky,',
#   'we',
#   'the',
#   'I',
#   'this?-',
#   'roller',
#   'that?-',
#   'gettingyour',
#   'you.-',
#   "this.I'm"],
#  'sound': ['of'],
#  'that.-': ['Yeah?-'],
#  'Yeah?-': ['Yeah.Merry', 'Fine.Annie.-'],
#  'Yeah.Merry': ['Christmas.Becca.New'],
#  'Christmas.Becca.New': ['senior'],
#  'senior': ['director,digital'],
#  'director,digital': ['marketing.-'],
#  'marketing.-': ['Uh,'],
#  'Uh,': ['yeah.', 'this'],
#  'yeah.': ['How', 'You'],
#  'How': ['did'],
#  'did': ['you',
#   'you',
#   'smashthrough',
#   'your',
#   'I',
#   'they',
#   'come',
#   'this,',
#   'you...?I',
#   'you',
#   'I.Apparently,',
#   'you'],
#  'know?-': ['I'],
#  'have': ['my',
#   'a',
#   'a',
#   'a',
#   'you',
#   'time',
#   'a',
#   'we',
#   'survived.She',
#   'been',
#   'my',
#   'to',
#   'to',
#   'been',
#   'a',
#   'a'],
#  'my': ['sources.And',
#   'husband,',
#   'photos,she',
#   'messages.It',
#   'social',
#   'attention,',
#   'Dadcould',
#   'dadwas',
#   'job.Um,',
#   'dad,but',
#   'own',
#   'last',
#   "age.I'm",
#   'bones,-',
#   'face.-',
#   'position......what',
#   'voice.You',
#   'God.Get',
#   'bank',
#   "kid.Dad.I'll",
#   'God,',
#   'life',
#   'fault,',
#   'goodness,this',
#   'God,',
#   'pinkie.No,',
#   'God.',
#   'guy.Oh,',
#   'family.And',
#   'subjects.Hmm.',
#   'fault.What',
#   'greatest',
#   'word.Thank',
#   'entire'],
#  'sources.And': ['your'],
#  'nametag.Yes,': ['that,'],
#  'that,': ['too.-'],
#  'too.-': ['Uh,'],
#  'this': ['is',
#   'would',
#   'is',
#   'is',
#   'shit,',
#   'a',
#   'guy?This',
#   'guy.You',
#   'guy?-',
#   'Hugh',
#   'anymore.-',
#   'about?-',
#   'shitmust',
#   'not',
#   'right',
#   'was',
#   'is',
#   "timeit's",
#   'is',
#   'way,',
#   'or',
#   'make',
#   'one,',
#   'is',
#   'drug.It,'],
#  'husband,': ['Billy.-'],
#  'Billy.-': ['Great'],
#  'Great': ['to'],
#  'to': ['meet',
#   'that',
#   'the',
#   'talk',
#   'youabout',
#   'meet',
#   'meet',
#   'behave.-',
#   "me.T-That's",
#   'understandthat',
#   'know',
#   'have',
#   'swim.-',
#   'know.And',
#   'the',
#   'go.-',
#   'seeyour',
#   'mean?It',
#   'saythat',
#   'keep',
#   "five.We're",
#   'you.-',
#   'this.Well,',
#   'see',
#   'makethis',
#   'go',
#   'you?Homelander,',
#   'add,',
#   'knowwhere',
#   'the',
#   'stop',
#   'kick',
#   'gomy',
#   'abouta',
#   'Epcot?',
#   'be',
#   'your',
#   'me.Oh,',
#   'go',
#   'Mesmer.Fuck',
#   'dear',
#   'go.-',
#   'go.You',
#   'meand',
#   'Jesus',
#   'flaming',
#   'pack',
#   'go.I',
#   'go.And',
#   'fire',
#   'know',
#   'her.No,',
#   'stay',
#   'do?It',
#   'talk',
#   'me.Wait,',
#   'talk,I',
#   'the',
#   'meet',
#   'you.-',
#   'see',
#   'gettoo',
#   'my',
#   'knowabout',
#   'Stillwellabout',
#   'me.So',
#   'her',
#   'sign',
#   'you,and',
#   'see',
#   'see',
#   'explain,',
#   'status',
#   'zero.The',
#   'a',
#   '30.Ms.',
#   'me.Listen',
#   'me,',
#   'stringyou'],
#  'meet': ['you.Billy', 'you,', 'you.Love', 'my', 'you.Billy'],
#  'you.Billy': ['Butcher.\n\n\nBecca,', 'Butcher.Oh,'],
#  'Butcher.\n\n\nBecca,': ['you'],
#  'handledmy': ['takeover,'],
#  'takeover,': ['right?Y-Yes,'],
#  'right?Y-Yes,': ['I-I'],
#  'I-I': ['did.-'],
#  'did.-': ['You', 'If'],
#  'You': ['saw',
#   'promised',
#   "don't",
#   'fucking',
#   'mean,',
#   'put',
#   'like',
#   'got',
#   'got',
#   'know'],
#  'saw': ['it?-'],
#  'it?-': ['I'],
#  'loved': ['it.-', 'you.Not'],
#  'it.-': ['U-Uh,', 'And,', "It's", 'Thanks.Oh,'],
#  'U-Uh,': ['wow.'],
#  'wow.': ['Thank'],
#  'you.-': ['No,', "What'd", 'What?-', "Nah.She's", 'Monique.Good', 'Never'],
#  'No,': ['thank', 'no,', "sir.I'm", 'fuck!-', 'I', 'no,'],
#  'thank': ['you.-'],
#  "What'd": ['you'],
#  'take': ['over?-', "it,you'll", 'one', 'the'],
#  'over?-': ["Vought's"],
#  "Vought's": ['Twitter'],
#  'Twitter': ['account.-'],
#  'account.-': ['Yeah.-'],
#  'Yeah.-': ['Your', 'Now,', "You're"],
#  'Your': ['brilliant'],
#  'brilliant': ['wife'],
#  'wife': ['heredid'],
#  'heredid': ['all'],
#  'all': ['the',
#   'thumbs',
#   'really',
#   'right.Yeah.Yeah,',
#   'in',
#   'startedwhen',
#   'the',
#   'about?-',
#   "right.You're",
#   'right.I',
#   'startwith',
#   'mine.Hello,',
#   'over',
#   'of',
#   'under'],
#  'work.She': ['posted'],
#  'posted': ['my'],
#  'photos,she': ['wrote'],
#  'wrote': ['my'],
#  'messages.It': ['was'],
#  'was': ['exceptional.All',
#   'you',
#   'really',
#   'gone,',
#   'all',
#   'helped?',
#   'fucking',
#   'not',
#   'an',
#   'fucking',
#   'drawing',
#   'suicide.Mm.Yeah,',
#   'just',
#   'Homelander.You',
#   'a',
#   'alone',
#   'pregnant.With',
#   'developingunnaturally',
#   'difficult.The',
#   'that?Is'],
#  'exceptional.All': ['right,'],
#  'right,': ['so', 'where', 'look,I', 'easy,'],
#  'so': ['they',
#   'I',
#   'better',
#   'much',
#   'fucked',
#   'ever',
#   'far?No,',
#   'hot',
#   'fucked.You',
#   'sorry.Annie.',
#   'sorry.Get'],
#  'they': ['thoughtit', 'make,', 'say?Come', 'get', "are.It's"],
#  'thoughtit': ['was'],
#  'up': ['there,but',
#   'against',
#   'there?I',
#   'to',
#   'your',
#   'to',
#   'to?-',
#   'to.Who',
#   'here?Oh,',
#   'for',
#   'with',
#   'for'],
#  'there,but': ['it'],
#  'it': ['was',
#   'to',
#   'is.-',
#   'out',
#   'back',
#   'all',
#   'out.Stop',
#   'over,then',
#   'was',
#   'seems',
#   'here.You',
#   'true',
#   'hurt.All',
#   'kill',
#   'is?I',
#   'been,',
#   'because',
#   'led',
#   'out...Oh,',
#   'a',
#   'matter?Why',
#   "doesn't",
#   'up.N...',
#   'all'],
#  'really': ['Becca.Bit',
#   'nice.-',
#   "should've",
#   'all',
#   'did',
#   "bulletproof.What's",
#   'notthat',
#   "sorry.I'm"],
#  'Becca.Bit': ['deceptive,'],
#  'deceptive,': ["isn't"],
#  "isn't": ['it?Uh,', 'it?Protect', 'about'],
#  'it?Uh,': ['no,'],
#  'no,': ['Billy,',
#   'no.You...',
#   'no.Seven,',
#   'no,',
#   'no,',
#   'no.Not',
#   'no.Wait,',
#   'I',
#   'no.'],
#  'Billy,': ["that's"],
#  "that's": ['what',
#   'enough.You',
#   'whatmakes',
#   'so',
#   'my',
#   'what',
#   'true.Seems',
#   'not'],
#  'what': ['we',
#   'aboutmy',
#   "you've",
#   "we're",
#   'thisis',
#   'I',
#   'that',
#   'about',
#   'they',
#   "I'm",
#   'happened?Well...Everyone',
#   'I',
#   'I',
#   'happenedwith',
#   'are',
#   'you'],
#  'we': ["do'cause",
#   'got',
#   'were',
#   "talk?That's",
#   "can't",
#   'couldorder',
#   'just,',
#   'care',
#   'got',
#   "don't",
#   'refuse?-'],
#  "do'cause": ["Homelander's"],
#  "Homelander's": ['busysaving'],
#  'busysaving': ["lives.It's"],
#  "lives.It's": ['okay,'],
#  'okay,': ["it's", 'I'],
#  "it's": ['okay.I-It...',
#   'gonna',
#   'worth',
#   'definitely',
#   'tender.',
#   'just',
#   'done',
#   'his...Supe'],
#  'okay.I-It...': ["you're"],
#  "you're": ["right.It's",
#   'gonnaregret',
#   'gonna',
#   'done,',
#   'too',
#   'right.It',
#   'pulling',
#   'just'],
#  "right.It's": ['a'],
#  'little': ['dishonest,but',
#   'heart-to-heart.A',
#   'tough',
#   'out',
#   'egg',
#   'rabbit.The',
#   'asshole',
#   'jet',
#   'fucking',
#   'fucking',
#   'bug'],
#  'dishonest,but': ["I'm"],
#  "I'm": ['all',
#   'sorry,',
#   'up',
#   'good.-',
#   "fucked.He's",
#   'gonna',
#   'gonna',
#   'sorry,I-I',
#   'just...',
#   'not',
#   'counting',
#   'really',
#   'sorry.I',
#   'not',
#   'taking',
#   'dead'],
#  'thumbs': ['whenit'],
#  'whenit': ['comes'],
#  'comes': ['to', "up,we'll"],
#  'that': ['kind',
#   'accent.Hello,',
#   'sweaty',
#   'the',
#   'shit.We',
#   'supposed',
#   'lately,some',
#   'is',
#   'it?You',
#   'working',
#   'shit',
#   'I',
#   'you',
#   'the',
#   'maybe,',
#   'shithole',
#   'Christmas',
#   'one.This',
#   'situationgot',
#   'would',
#   "much.I'm",
#   'clearer',
#   "doesn't",
#   'say?"Naqib."Hey!Freeze,',
#   'son',
#   'simple.And'],
#  'kind': ['of', 'of', 'of', 'of'],
#  'stuff,so': ['leave'],
#  'leave': ['it', 'her'],
#  'experts.Listen,': ['I'],
#  'wouldlove': ['to'],
#  'talk': ['to', 'to', 'to'],
#  'youabout': ['maybe'],
#  'maybe': ['quarterbackingthe', 'you'],
#  'quarterbackingthe': ['rest'],
#  'rest': ['of', 'of', 'of'],
#  'social': ['media.-'],
#  'media.-': ['Seriously?-'],
#  'Seriously?-': ['Absolutely.My'],
#  'Absolutely.My': ['dad,'],
#  'dad,': ['he'],
#  'he': ['always', 'walk', 'was', 'do', 'was', 'here?', 'got'],
#  'always': ['said,"Surround', "asks,what's", 'job', 'a'],
#  'said,"Surround': ['yourself'],
#  'yourself': ['with'],
#  'with': ['peoplesmarter',
#   'him.I',
#   'the',
#   "Kimiko,it's-it's",
#   'your',
#   'her.-',
#   'you?I',
#   'me.Now',
#   'himfor',
#   'me?-',
#   'anyof',
#   'quitean',
#   'a...completely',
#   'a',
#   'doctors.And',
#   'Mommy.All'],
#  'peoplesmarter': ['than'],
#  'than': ['you."Oh,', 'me.Then', 'The'],
#  'you."Oh,': ['my,'],
#  'my,': ['uh,'],
#  'uh,': ['better'],
#  'better': ['half', 'to'],
#  'half': ['is,', 'dozen,-', 'century,you'],
#  'is,': ['uh,wanting'],
#  'uh,wanting': ['my'],
#  'attention,': ['but'],
#  'but': ['maybewe', 'corny', 'words...-', 'hear', "you,you've", 'I', 'next'],
#  'maybewe': ['could'],
#  'could': ['chat', 'get', 'have', 'count'],
#  'chat': ['tomorrow.That'],
#  'tomorrow.That': ['sounds'],
#  'sounds': ['wonderful.Thank', 'amazing.But'],
#  'wonderful.Thank': ['you.Thank'],
#  'you.Thank': ['you.Greet'],
#  'you.Greet': ['to'],
#  'you,': ['pal.Good',
#   'but...I',
#   "Noir.You've",
#   'Hughie?Okay,',
#   'Hughie?The',
#   'baby.Janine,',
#   "John.I'm",
#   "okay?You're",
#   "Michaela.We're"],
#  'pal.Good': ['to'],
#  'you.Love': ['that'],
#  'accent.Hello,': ['beautiful.How'],
#  'beautiful.How': ['the'],
#  'fuck': ['does',
#   'out',
#   'up.Dad,',
#   'is',
#   'Edgar.We',
#   'you.No...What',
#   "off.I'm",
#   'are',
#   'does',
#   'away',
#   'were'],
#  'does': ['he', 'this', 'that'],
#  'walk': ['aroundin'],
#  'aroundin': ['that'],
#  'sweaty': ['fucking'],
#  'fucking': ['wetsuitall',
#   'way.You',
#   'around.Did',
#   'flies,but',
#   'this',
#   'breed.We',
#   'mouth,young',
#   'stupid.She',
#   'killer,',
#   'blindto',
#   "Medicaid.He's",
#   'piñata,do',
#   'worth',
#   'do',
#   'idiotshad',
#   'garbage.How',
#   'freak.Lay',
#   'freak.Oh,',
#   'gills',
#   'superhero.You',
#   'thing',
#   'friends,',
#   'apology.All',
#   'lab',
#   'move!I'],
#  'wetsuitall': ['day'],
#  'day': ['long,-', 'now.And'],
#  'long,-': ['balls'],
#  'balls': ['mashed'],
#  'mashed': ['up'],
#  'against': ['his', 'horses.At', 'us.-'],
#  'his': ['leg', 'girlfriend,so', 'name?No.', "mistakes.I'm"],
#  'leg': ['like'],
#  'pancakes?-': ['Oh,'],
#  'Oh,': ['shh.-',
#   'yeah.Ooh.',
#   'this',
#   'boy.That',
#   'God.Okay.',
#   'God.-',
#   'yeah.',
#   'God.Ow,',
#   'God.Having',
#   'damn'],
#  'shh.-': ['What?-'],
#  'What?-': ['You', 'Oh,'],
#  'promised': ['to', 'methings'],
#  'behave.-': ["Let's"],
#  'out': ['of',
#   'thereand',
#   'loud,all',
#   'of',
#   'a',
#   'for',
#   'of',
#   'great.When',
#   'Abu'],
#  'here.-': ['Yeah?Yeah.Hi.-'],
#  'Yeah?Yeah.Hi.-': ['Huh.-'],
#  'Huh.-': ['Hmm.I'],
#  'Hmm.I': ["didn't"],
#  "didn't": ['realize',
#   'do',
#   'know.Well,',
#   'kill',
#   'bring',
#   'you',
#   'have',
#   'ask'],
#  'realize': ['you'],
#  'weresuch': ['a'],
#  'cigar': ['aficionado.I'],
#  'aficionado.I': ['really,'],
#  'really,': ['I', 'what'],
#  'just...Mm.': ['I'],
#  "can't": ['get',
#   'do',
#   'help',
#   'remember',
#   'do',
#   'getin',
#   'come',
#   'cometo',
#   'cometo'],
#  'enoughof': ['huge'],
#  'huge': ['gross'],
#  'gross': ['logsof'],
#  'logsof': ['filterless'],
#  'filterless': ['tobacco.-'],
#  'tobacco.-': ['This'],
#  'This': ['is', 'cat', 'is'],
#  'nice.-': ['Mm-hmm.But...There'],
#  'Mm-hmm.But...There': ['is'],
#  '"but"': ['coming.Okay.But'],
#  'coming.Okay.But': ['why'],
#  'why': ['did', 'would', "don't", 'are'],
#  'bring': ['meto', "youHomelander's", 'me'],
#  'meto': ['a', 'get'],
#  'hotel?Hmm?': ['And'],
#  'And': ['not', 'if'],
#  'not': ['your',
#   'you,',
#   'a',
#   'a',
#   'even',
#   'capableof',
#   'gonna',
#   'Annie.-',
#   'ever.So',
#   'smart,to',
#   'gonna',
#   'leaving',
#   'all',
#   'safe',
#   'most',
#   'going',
#   'talk?Uh,',
#   'gonna',
#   'to',
#   'enough.When',
#   'gettoo',
#   'following.You',
#   'even',
#   'all.How',
#   'that'],
#  'place?Well,': ['you'],
#  'know.I': ['mean,'],
#  'mean,': ['yeah,',
#   'what',
#   "we're",
#   "we're",
#   'why',
#   'The',
#   'Vought,whatever',
#   'um,you',
#   'like',
#   'missing?I',
#   "it's...Yeah.",
#   'I',
#   'that'],
#  'yeah,': ['sure,', 'I', "here's"],
#  'sure,': ['my'],
#  'Dadcould': ['make'],
#  'make': ['yousome', 'my', 'me', 'this', 'sense.Just'],
#  'yousome': ['post-coital'],
#  'post-coital': ['pizza'],
#  'pizza': ['rolls.I'],
#  'rolls.I': ['just'],
#  'just': ['figured',
#   'tickled',
#   'a',
#   'a',
#   "can't",
#   "hopeyou're",
#   'want',
#   'a',
#   'wondering',
#   'assumedthat',
#   'my',
#   'need',
#   'please',
#   'breeding',
#   "ask.I'll",
#   'an',
#   'assholesrunning'],
#  'figured': ['this'],
#  'would': ['beslightly', 'he', 'you', 'it', 'be', 'be'],
#  'beslightly': ['less'],
#  'less': ['humiliating.Yeah,'],
#  'humiliating.Yeah,': ['all'],
#  'right.Yeah.Yeah,': ['very'],
#  'very': ['convincing.You', 'true.He'],
#  'convincing.You': ['okay?'],
#  'okay?': ["What's"],
#  "What's": ['going', 'this?-', 'going'],
#  'going': ["on?It's",
#   'on?-',
#   "steady.He's",
#   'on,but',
#   'anywhere,you',
#   'on.About'],
#  "on?It's": ["just...I've"],
#  "just...I've": ['never'],
#  'never': ['seen', 'do', 'seen', 'want', 'seen'],
#  'seen': ['your', 'me', 'herin'],
#  'place,or': ['your'],
#  "job.You're": ['kind'],
#  'mystery': ['to'],
#  "me.T-That's": ['hot,'],
#  'hot,': ['right?Look,'],
#  'right?Look,': ['you'],
#  'got': ['to',
#   'Cedar',
#   'a',
#   'to',
#   'rid',
#   'something',
#   "this.It's",
#   "her.She's",
#   'to',
#   'me.Oh,',
#   'it.All',
#   'this.Go.All',
#   'to',
#   'to',
#   'pretty',
#   'both.Mm-hmm.You',
#   'you',
#   'to',
#   'it.-',
#   'a',
#   'here,',
#   'cold',
#   'two.-',
#   'movement!-'],
#  'understandthat': ['my'],
#  'dadwas': ['nothing'],
#  'nothing': ['but', 'to'],
#  'corny': ['jokesand'],
#  'jokesand': ['expensive'],
#  'expensive': ['gifts,until'],
#  'gifts,until': ['he'],
#  'gone,': ['and'],
#  'and': ['allthe',
#   'stuff?You',
#   'Starlightare',
#   'God',
#   "stoneswon't",
#   "me,remember?Don't",
#   'call',
#   'not,like,',
#   'you',
#   'meis',
#   'me.This',
#   'you.You',
#   'for',
#   'Raynoror',
#   'mouse',
#   'me.You',
#   'your',
#   "why?I've"],
#  'allthe': ['money'],
#  'money': ['along'],
#  'along': ['with'],
#  'him.I': ['know'],
#  'know': ["thatthat's",
#   'that',
#   'this',
#   'shit',
#   'why.Uh...Why...Is',
#   'this',
#   "what's",
#   'anything,',
#   'what',
#   'his',
#   'what?That',
#   'what',
#   'what',
#   'this',
#   'me.I',
#   'you.-'],
#  "thatthat's": ['not'],
#  'but...I': ['need', 'was'],
#  'need': ['to', '3,000', 'a'],
#  'hotelis': ['a'],
#  'nice': ['thingand'],
#  'thingand': ['not'],
#  'red': ['flag', 'flags.Hmm.Now,'],
#  'flag': ['thing.I'],
#  'thing.I': ['quit'],
#  'quit': ['my'],
#  'job.Um,': ["I'm"],
#  'sorry,': ['I-I...I'],
#  'I-I...I': ['really'],
#  "should've": ['told'],
#  'told': ['you.After', 'her'],
#  'you.After': ['Robin,'],
#  'Robin,': ['programmingother'],
#  'programmingother': ["people's"],
#  "people's": ['remotes,it'],
#  'remotes,it': ['felt'],
#  'felt': ['kind', 'like'],
#  'pointless.And': ['yeah,'],
#  'mean,you': ['can-you'],
#  'can-you': ['can'],
#  'can': ['meet',
#   'we',
#   'do',
#   'do',
#   'catch',
#   'help',
#   'help',
#   'get',
#   'call',
#   'imagine',
#   'get',
#   'now'],
#  'dad,but': ["you're"],
#  'gonnaregret': ['asking'],
#  'asking': ['that.So'],
#  'that.So': ["everything's"],
#  "everything's": ["okay?It's"],
#  "okay?It's": ['great.No'],
#  'great.No': ['red'],
#  'flags.Hmm.Now,': ['I'],
#  'notas': ['swanky'],
#  'swanky': ['as'],
#  'as': ['New',
#   'blackmailingMesmer,',
#   'you',
#   'in',
#   "anyone's.It's",
#   'planned.So'],
#  'New': ['York'],
#  'York': ['City,but'],
#  'City,but': ['to'],
#  'hero': ['like'],
#  'ina': ['place'],
#  'place': ['like', 'is'],
#  'Sandusky,': ['I'],
#  'mean,everyone': ['down'],
#  'down': ['at', 'the', 'to', 'by'],
#  'at': ['the',
#   'my',
#   'least',
#   'this.Oh,',
#   'Lincoln',
#   'leasta',
#   'her',
#   'those',
#   'that',
#   'you,standing',
#   'the',
#   "A-Train?Y...You're"],
#  'localbranch': ['is'],
#  'tickled': ['pink.-'],
#  'pink.-': ['Yeah.-'],
#  'Now,': ['we'],
#  'Cedar': ['Point,biggest', "Point's"],
#  'Point,biggest': ['roller-coaster'],
#  'roller-coaster': ['parkin'],
#  'parkin': ['the'],
#  'whole': ['U.S.', 'Deep', 'lifewithout', 'fucking'],
#  'U.S.': ['of', 'Armed'],
#  "A.We're": ['just'],
#  'couple': ['short'],
#  'short': ['hoursfrom'],
#  'hoursfrom': ['Cleveland'],
#  'Cleveland': ['or'],
#  'or': ['Toledo.And', 'other.I-I', 'knowing', 'another,', 'not?Annie,'],
#  'Toledo.And': ['Lake'],
#  'Lake': ['Erie?'],
#  'Erie?': ['Right'],
#  'Right': ['here,-'],
#  'here,-': ['if'],
#  'if': ['you',
#   'something',
#   'he',
#   'I',
#   "he's",
#   'I',
#   'you',
#   'you...if',
#   "it'syour",
#   'something',
#   'we'],
#  'swim.-': ['Oh,'],
#  'yeah.Ooh.': ['Uh...There'],
#  'Uh...There': ['it'],
#  'is.-': ["What's"],
#  'this?-': ["That's", 'Jonesing', 'Do'],
#  "That's": ['your'],
#  'per': ['diem.You'],
#  'diem.You': ['get'],
#  '$75': ['a'],
#  'day.Grocery': ['store,right'],
#  'store,right': ['down'],
#  'street.To': ['make'],
#  'own': ["food?There's", 'fucking'],
#  "food?There's": ['a'],
#  'Dairy': ['Queen,'],
#  'Queen,': ['too.Like'],
#  'too.Like': ['Blizzards'],
#  'Blizzards': ['and'],
#  'stuff?You': ['betcha.Well...I'],
#  'betcha.Well...I': ['mean,'],
#  'aboutmy': ['crime'],
#  'crime': ['itinerary?I', 'in'],
#  'itinerary?I': ['think'],
#  'think': ['the', "I'm", 'it', 'maybe', 'she', 'it'],
#  'best': ["thing's"],
#  "thing's": ['justto,'],
#  'justto,': ['you'],
#  'know,': ['get',
#   'I',
#   "I've",
#   'real',
#   'he...Right',
#   'this',
#   "you're",
#   'I',
#   'I',
#   'fuck',
#   'I'],
#  'thereand': ['put'],
#  'put': ['some', 'her', 'us'],
#  'some': ['pointson', 'kind'],
#  'pointson': ['the'],
#  'board.Not': ['much'],
#  'much': ['crime', 'of', 'time'],
#  'in': ['Sandusky.I',
#   'my',
#   'to',
#   'my',
#   'danger,and',
#   'danger',
#   'missing,presumed',
#   'and...catch',
#   'the',
#   'your',
#   'on',
#   'its',
#   'a',
#   'your'],
#  'Sandusky.I': ['mean,'],
#  "we're": ['not', 'not', 'down', 'doing,innit?No,', 'running', 'gonna', 'the'],
#  'shitholelike': ['Akron.But'],
#  'Akron.But': ['if'],
#  'something': ['comes', 'to', 'special.Hmm?I', 'happensto'],
#  "up,we'll": ["call.You'll"],
#  "call.You'll": ['call?-'],
#  'call?-': ['Absolutely.-'],
#  'Absolutely.-': ['Okay.-'],
#  'Okay.-': ['Oh,'],
#  'killing': ['me.-', 'you.Hey.'],
#  'me.-': ['Come', 'Well,'],
#  'Come': ['on.Damn.Oh,', 'on,'],
#  'on.Damn.Oh,': ['no'],
#  'no': ['fucking', 'more', 'secrets', 'talk.You', 'superheroesin'],
#  'way.You': ['need'],
#  '3,000': ['calories'],
#  'calories': ['an'],
#  'an': ['hour,or', 'asshole,just', 'accident.-', "NDA.Couldn't", 'old'],
#  'hour,or': ["you're"],
#  'gonna': ['pass',
#   'be',
#   'tell',
#   'burst',
#   'fucking',
#   'be',
#   'bea',
#   'love',
#   'get',
#   'get',
#   'let',
#   "beMallory's",
#   'be',
#   'be',
#   'be',
#   'vote',
#   'goback'],
#  'pass': ['out.I'],
#  'out.I': ["can't"],
#  'do': ['this',
#   'that?Good',
#   'anything.-',
#   'to',
#   'anything',
#   'this',
#   'all',
#   'her',
#   'this.-',
#   'whateveryou',
#   'this',
#   'you',
#   'you',
#   'you',
#   'this?-',
#   'you',
#   'you',
#   'you',
#   'anythingto'],
#  'shit,': ['man.Tough', 'if'],
#  'man.Tough': ['shit.You'],
#  'shit.You': ['heard'],
#  'heard': ['the'],
#  'doc.Your': ['heart'],
#  'heart': ['is'],
#  'getting': ['bigger,balls', 'smaller,your'],
#  'bigger,balls': ['are'],
#  'smaller,your': ['bone'],
#  'bone': ["density's"],
#  "density's": ['for'],
#  'shit.That': ['Compound'],
#  'Compound': ['V', 'V.Compound'],
#  'V': ['shitis'],
#  'shitis': ['killing'],
#  'you.Hey.': ["Don't"],
#  "Don't": ['even', 'say', 'fucking'],
#  'even': ['say', 'The', 'her', 'the'],
#  'say': ['it', 'no?Come', 'sorry.'],
#  'loud,all': ['right?You'],
#  'right?You': ["don't"],
#  "don't": ['know',
#   'want',
#   'understand.Who',
#   'know',
#   'know,got',
#   'stir,you',
#   'thinkI',
#   'youstop',
#   'know.No,',
#   "know'cause",
#   'know,',
#   'know',
#   'mind',
#   'have',
#   'looklike',
#   'think',
#   'know',
#   'do',
#   'understand.The',
#   'wantyour',
#   'want',
#   'know.',
#   "thinkthat's",
#   'give',
#   'know'],
#  'shit': ['about', 'ab...Well,', 'about', 'is.Oh,', 'that'],
#  'about': ['it,you',
#   'now?Oh,',
#   'anyone,really.And',
#   'her,for',
#   'Annie.Fucking',
#   'her.That',
#   'Popclaw?She',
#   'us.Hey,',
#   'her?Well,',
#   'your',
#   'it.Me,',
#   "that.It's",
#   'everything.No,',
#   'his',
#   'Translucent.Okay?',
#   'Compound'],
#  'it,you': ['understand?I'],
#  'understand?I': ["don't"],
#  'know.And': ["you're"],
#  'done,': ['okay?No'],
#  'okay?No': ['more'],
#  'around.Did': ['you'],
#  'see': ['my',
#   'Ezekieland',
#   'it.Right,',
#   'it.Please?I',
#   'you.Hi,',
#   'you',
#   'you.I,'],
#  'last': ['timeout', 'timeMaeve', 'half'],
#  'timeout': ['there?Sioux'],
#  'there?Sioux': ["City's"],
#  "City's": ['got'],
#  'fuckingfaster': ['runner'],
#  'runner': ['than'],
#  'me.Then': ['no'],
#  'club': ['openingsand'],
#  'openingsand': ['commercial'],
#  'commercial': ['shoots.Okay?'],
#  'shoots.Okay?': ['None'],
#  'None': ['of'],
#  'shit.We': ['train.Back'],
#  'train.Back': ['to'],
#  'basics.Nobody': ['gets'],
#  'gets': ['it'],
#  'back': ['at', 'off,', 'with', 'at'],
#  "age.I'm": ['gonna'],
#  'be': ['a',
#   'known,I',
#   'something',
#   'loyalto',
#   'okay.',
#   'the',
#   'right',
#   'all',
#   'pretty',
#   'thrilled.Ugh,',
#   'a',
#   'gentle,',
#   'gentle.Ow,',
#   'different.Matter',
#   'my',
#   'honest.Well,',
#   'a',
#   'okay,you',
#   'safe'],
#  'freak': ['showlike'],
#  'showlike': ['Ben'],
#  'Ben': ['Johnson,racing'],
#  'Johnson,racing': ['against'],
#  'horses.At': ['least'],
#  'least': ["you'll", 'now'],
#  "you'll": ['stillbe'],
#  'stillbe': ['breathing.Shit.-'],
#  'breathing.Shit.-': ['I'],
#  'go.-': ['Where?-', 'Not'],
#  'Where?-': ["What's"],
#  'on?-': ['I'],
#  'missed': ['you'],
#  'guys.Just': ['wanted'],
#  'wanted': ['to'],
#  'seeyour': ['smiling'],
#  'smiling': ['faces.Take'],
#  'faces.Take': ['a'],
#  'seat,': ['buddy.And,'],
#  'buddy.And,': ['truth'],
#  'truth': ['be', 'is,our'],
#  'known,I': ['felt'],
#  'were': ['overduea',
#   'in',
#   'a',
#   'a',
#   'super',
#   'donewith',
#   'gonna',
#   'the',
#   'the',
#   'you'],
#  'overduea': ['little'],
#  'heart-to-heart.A': ['rap'],
#  'rap': ['session,maybe'],
#  'session,maybe': ['a'],
#  'tough': ["love.What's"],
#  "love.What's": ['that'],
#  'supposed': ['to', 'to'],
#  'mean?It': ['means'],
#  'means': ['that', '"Captain."We'],
#  'lately,some': ['of'],
#  'youhave': ['been,'],
#  'been,': ['eh,a', 'John?Long'],
#  'eh,a': ['little'],
#  'sorts.Erratic.Unreliable.Downright': ['sloppy.Not'],
#  'sloppy.Not': ['you,'],
#  "Noir.You've": ['been'],
#  'great.But': ['the'],
#  'you...It': ['is'],
#  'fair': ['to', 'game.Do'],
#  'saythat': ['I'],
#  'am': ['disappointed.Got', 'I', 'not', 'I', 'I'],
#  'disappointed.Got': ['to'],
#  'keep': ['your'],
#  'eyeon': ['the'],
#  'ball,': ['guys.The'],
#  'guys.The': ['enemiesare'],
#  'enemiesare': ['storming'],
#  'storming': ['the'],
#  'gates.I': ['mean,'],
#  'The': ['Sevenanymore,', 'Sevenis', 'Hamptons?Maybe', 'hell', 'Seven'],
#  'Sevenanymore,': ["we're"],
#  "five.We're": ['droppinglike'],
#  'droppinglike': ['fucking'],
#  'flies,but': ['at'],
#  'now': ['I', "I'm", 'doto'],
#  'why.Uh...Why...Is': ['this'],
#  'joke?Why': ['is'],
#  'Hughie': ['up', 'is'],
#  'there?I': ["don't"],
#  'understand.Who': ['is'],
#  'guy?This': ['guy'],
#  'guy': ['is', 'who'],
#  'Hugh': ['Campbell.He', 'Campbell', 'Campbell.-'],
#  'Campbell.He': ['and'],
#  'Starlightare': ['going'],
#  "steady.He's": ['also'],
#  'also': ['one'],
#  'one': ['of', 'of', 'at', 'of', 'of', 'of', 'calls', 'could'],
#  'guyswho': ['killed'],
#  'killed': ['Translucent.Wait,', 'Translucent.This'],
#  'Translucent.Wait,': ['what?As'],
#  'what?As': ['well'],
#  'well': ['as'],
#  'blackmailingMesmer,': ['Ezekiel,'],
#  'Ezekiel,': ['Popclaw-'],
#  'Popclaw-': ['and'],
#  'God': ['knows'],
#  'knows': ['who'],
#  'who': ['else.-', 'killed'],
#  'else.-': ['Popclaw?No.'],
#  'Popclaw?No.': ['No,'],
#  'no.You...': ['That-that'],
#  'That-that': ['is'],
#  'insane.Starlight,': ['sticks'],
#  'sticks': ['and'],
#  "stoneswon't": ['break'],
#  'break': ['my'],
#  'bones,-': ['but'],
#  'words...-': ['No,'],
#  "sir.I'm": ['sorry.'],
#  'sorry.': ['I', 'No.Look'],
#  "wasn't...It's": ['just,'],
#  'just,': ["he's", 'uh...Ah...'],
#  "he's": ['not...I', 'pumping', 'burned,then', 'a'],
#  'not...I': ['mean,'],
#  'that?Good': ['question.A-Train,'],
#  'question.A-Train,': ['over'],
#  'over': ['to', 'herein', 'again,only'],
#  'boy.That': ['little'],
#  'egg': ['of'],
#  'yoursis': ['still'],
#  'still': ['scrambled,', 'me,'],
#  'scrambled,': ['huh?How'],
#  'huh?How': ['about'],
#  'now?Oh,': ['shit.I'],
#  'shit.I': ['know'],
#  'guy.You': ['did'],
#  'smashthrough': ['his'],
#  'girlfriend,so': ['I'],
#  'should': ['hope', "go.I'm", 'have'],
#  'hope': ['so.Robin', 'she'],
#  'so.Robin': ['s-something'],
#  's-something': ['or'],
#  'other.I-I': ['remember'],
#  'remember': ['now,', 'the'],
#  'now,': ["I-I've", "Butcher,you're", 'but...Merde!Butcher.-'],
#  "I-I've": ['seenhim'],
#  'seenhim': ['outside'],
#  'outside': ['of'],
#  "Popclaw's": ['place.He'],
#  'place.He': ['was'],
#  'face.-': ["You're"],
#  "You're": ['fucking', 'wrong', 'right.'],
#  'guy?-': ['S...'],
#  'S...': ['Okay,'],
#  'Okay,': ['slow'],
#  'slow': ['down.I'],
#  'down.I': ["don't"],
#  "what's": ['going', 'better,the', 'the'],
#  'on,but': ['Hughie'],
#  'capableof': ['anything'],
#  'anything': ['close', 'for'],
#  'close': ['to'],
#  'this.Well,': ['that'],
#  'true,': ["actually.That's"],
#  "actually.That's": ['very'],
#  'true.He': ['is'],
#  'man,': ['and,by'],
#  'and,by': ['the'],
#  'looks': ['of', 'like'],
#  'it,not': ['much'],
#  'one.But...': ['but'],
#  'hear': ['me'],
#  'out.W-What': ['if'],
#  'helped?': ['Hmm?Say'],
#  'Hmm?Say': ['someone,I'],
#  'someone,I': ["don't"],
#  'know,got': ['him'],
#  'him': ['in', 'go.My', 'go.Alone,', 'go,', 'up.Great.The'],
#  'Ezekieland': ['got'],
#  'rid': ['of'],
#  'Deep.Whoa,': ['whoa,'],
#  'whoa,': ['whoa,', 'whoa,', 'whoa.Hold'],
#  'whoa.Hold': ['on.Keep'],
#  'on.Keep': ['those'],
#  'those': ['hands', 'gills.Oh,'],
#  'hands': ['downby'],
#  'downby': ['your'],
#  'sides,': ['missy.Sit'],
#  'missy.Sit': ['down.Now...'],
#  'down.Now...': ['I'],
#  'knowthat': ['you'],
#  'makethis': ['whole'],
#  'Deep': ['thingan'],
#  'thingan': ['"All'],
#  '"All': ['the'],
#  'single': ['ladies"moment.Power,'],
#  'ladies"moment.Power,': ['right?But'],
#  'right?But': ['really,'],
#  "you've": ['doneis', 'reached', 'reached'],
#  'doneis': ['pulled'],
#  'pulled': ['offevery'],
#  'offevery': ["criminal's"],
#  "criminal's": ['wet'],
#  'wet': ['dream.I'],
#  'dream.I': ['mean,'],
#  'Sevenis': ['down'],
#  'by': ['two.I', 'God.I'],
#  'two.I': ['just'],
#  'help': ['noticingthat', 'Mommypack', 'you.Becca?Your', 'you'],
#  'noticingthat': ['it'],
#  'startedwhen': ['you'],
#  'came': ['along,which', 'alone.You'],
#  'along,which': ['makes'],
#  'makes': ['me'],
#  'wonder,which': ['one'],
#  'us': ['is', 'do', 'in', 'on', 'ahead'],
#  'next,': ['hmm?You'],
#  'hmm?You': ['bitch.-'],
#  'bitch.-': ['I'],
#  'anything.-': ["Enough!We're", 'All'],
#  "Enough!We're": ['a'],
#  'different': ['fucking'],
#  'breed.We': ['shine'],
#  'shine': ['with'],
#  'golden': ['lightof'],
#  'lightof': ['providence,'],
#  'providence,': ['but'],
#  "you,you've": ['been'],
#  'helping': ['thesefucking'],
#  'thesefucking': ['mud'],
#  'mud': ['people-'],
#  'people-': ['to'],
#  'go': ['against', 'to', 'be', 'to', 'bankrupt,and'],
#  'us.-': ['No.Shut'],
#  'No.Shut': ['your'],
#  'mouth,young': ['lady.If'],
#  'lady.If': ['you'],
#  'position......what': ['would'],
#  'you?Homelander,': ["that's"],
#  'enough.You': ['got'],
#  'add,': ['Maeve?She'],
#  'Maeve?She': ["didn't"],
#  'know.Well,': ['she'],
#  'she': ['stinks',
#   'was',
#   'was',
#   'quit.Quit?Is',
#   'doing?Uh,',
#   'does.Dad,',
#   "didn't",
#   'had'],
#  'stinks': ['of'],
#  'adrenalineand': ['her'],
#  'her': ["heart's",
#   'alone.Wow.Starlight,you',
#   'one',
#   'anything.-',
#   'in.-',
#   'in',
#   'outlike',
#   'file,',
#   'husband...Well,',
#   'with',
#   "we'd",
#   'husband.You'],
#  "heart's": ['beatinglike'],
#  'beatinglike': ['a'],
#  'rabbit.The': ['only'],
#  'only': ['thing', 'good', 'differencebetween', 'thing,', 'thingthat'],
#  'thing': ["she's", 'up.How', 'aboutcross-breeding'],
#  "she's": ['guilty', 'missing.What', 'missing?I'],
#  'guilty': ['ofis'],
#  'ofis': ['being'],
#  'being': ['fucking', 'an', 'for.Oh,'],
#  'stupid.She': ['obviously'],
#  'obviously': ['fellfor'],
#  'fellfor': ['this'],
#  'Campbell': ['guyand'],
#  'guyand': ["he's"],
#  'pumping': ['herfor'],
#  'herfor': ['information,so'],
#  'information,so': ['back'],
#  'off,': ['leave'],
#  'alone.Wow.Starlight,you': ['must'],
#  'must': ['be', 'be'],
#  'special.Hmm?I': ["can't"],
#  'timeMaeve': ['gave'],
#  'gave': ['a', 'a', 'me'],
#  'ab...Well,': ['gave'],
#  'anyone,really.And': ['if'],
#  'no?Come': ['on.I'],
#  'on.I': ['got'],
#  "this.It's": ['you'],
#  "me,remember?Don't": ['sayI'],
#  'sayI': ['never'],
#  'you.All': ['right.You'],
#  'right.You': ['want'],
#  'her,': ['you', 'she...No.'],
#  "her.She's": ['your', 'never'],
#  'responsibility': ['now.I'],
#  'now.I': ['just'],
#  "hopeyou're": ['right'],
#  'right': ['about',
#   'behind',
#   'now.-',
#   "now...What's",
#   'genes,you',
#   'now,',
#   'this'],
#  'her,for': ['both'],
#  'both': ['your'],
#  'sakes.Class': ['dismissed.Look'],
#  'dismissed.Look': ['at'],
#  'this.Oh,': ['no.'],
#  'no.': ['You', "I'm", "Don't"],
#  'stir,you': ['fold.'],
#  'fold.': ['Like'],
#  'Like': ['this.Now', 'you'],
#  'this.Now': ["that's"],
#  'whatmakes': ['them'],
#  'them': ['spongy.Here', 'loose.For'],
#  'spongy.Here': ['you'],
#  'go.She': ['wants'],
#  'wants': ['to'],
#  'knowwhere': ['you'],
#  "were.That's": ['a'],
#  'compellingfucking': ['question.Hey,'],
#  'question.Hey,': ['can'],
#  "talk?That's": ['what'],
#  'doing,innit?No,': ['I'],
#  'mean...There': ["ain't"],
#  "ain't": ['no', 'thinking,-', 'blaming', 'your', 'nothing'],
#  'secrets': ['here,son.'],
#  'here,son.': ['Spit'],
#  'Spit': ['it'],
#  'out.Stop': ['being'],
#  'asshole,just': ['talk'],
#  'guy.Hughie': ["doesn't"],
#  "doesn't": ['mind.Do',
#   'know',
#   'knowand',
#   "care?How's",
#   'know.-',
#   'matter.-',
#   'know.',
#   'matterhow',
#   'quitehave'],
#  'mind.Do': ['you,'],
#  'Hughie?Okay,': ['fine.'],
#  'fine.': ['I'],
#  'thinkI': ['can'],
#  'anymore.-': ['Do'],
#  'Do': ['what?-', 'what?-'],
#  'what?-': ['This.I', 'This'],
#  'This.I': ['mean,'],
#  'Vought,whatever': ['with'],
#  "Kimiko,it's-it's": ['awful,and'],
#  'awful,and': ['you'],
#  'stop': ['it,-'],
#  'it,-': ['but'],
#  "can't.-": ['Right.You'],
#  'Right.You': ['just'],
#  'kick': ['back,drink'],
#  'back,drink': ['a'],
#  'Mai': ['Tais,and'],
#  'Tais,and': ['let'],
#  'work,is': ['that'],
#  'it?You': ['know,', 'know,'],
#  'managed': ['to'],
#  'gomy': ['whole'],
#  'lifewithout': ['seeing'],
#  'seeing': ['someonedie'],
#  'someonedie': ['horribly,and'],
#  'horribly,and': ['now'],
#  'abouta': ['half'],
#  'dozen,-': ['so'],
#  'good.-': ["Please.You're"],
#  "Please.You're": ['a'],
#  'killer,': ['Hughie,just'],
#  'Hughie,just': ['like'],
#  'us.Now,': ['why'],
#  'youstop': ['pissing'],
#  'pissing': ['aroundand'],
#  'aroundand': ['tell'],
#  'tell': ['everybody', 'her', 'me', 'me', 'anyone.Not', 'me?To', 'mewhat'],
#  'everybody': ['what'],
#  'thisis': ['really'],
#  'about?-': ['Yeah?-', 'Shut'],
#  'Fine.Annie.-': ['Fuck.-'],
#  'Fuck.-': ["Okay?It's"],
#  "Okay?It's": ['about'],
#  'Annie.Fucking': ["finally.He's"],
#  "finally.He's": ['been'],
#  'sneaking': ['off'],
#  'off': ['togive', 'to'],
#  'togive': ['her'],
#  'Lincoln': ['Grand.-'],
#  'Grand.-': ["You've"],
#  "You've": ['been', 'reached'],
#  'following': ['me?-'],
#  'me?-': ['Like', 'You'],
#  'choice.She': ["doesn't"],
#  'anything,': ["okay?I'm"],
#  "okay?I'm": ['not'],
#  'All': ['right?', 'right.Take', 'right.-'],
#  'right?': ["We'll", 'All'],
#  "We'll": ['just...-'],
#  'just...-': ['Just'],
#  'what?Fuck': ['off'],
#  'Epcot?': ['The'],
#  'Hamptons?Maybe': ['pump'],
#  'pump': ['out'],
#  'fewflying': ['babies?No.'],
#  'babies?No.': ['I...'],
#  'I...': ['I'],
#  'know.No,': ['you'],
#  "know'cause": ['you'],
#  'thinking,-': ['except'],
#  'except': ['with'],
#  'dick.-': ["You're"],
#  'wrong': ['about', 'with'],
#  'her.That': ['bitch'],
#  'bitch': ['is'],
#  'fuckingplaying': ['you,and'],
#  'you,and': ["you're", 'what'],
#  'too': ['fucking', 'late.I'],
#  'blindto': ['see'],
#  'it.Right,': ['so'],
#  'loyalto': ['a'],
#  'womanwho': ["doesn't"],
#  'knowand': ["doesn't"],
#  "care?How's": ['that'],
#  'working': ['out'],
#  'you?-': ['Hey,'],
#  'Hey,': ['Dad.-', 'Hughie.Long'],
#  'Dad.-': ['Hey,', 'Oh.'],
#  'Hughie.Long': ['time'],
#  'time': ['no', 'obsessingabout', 'to', 'to'],
#  'talk.You': ['know,'],
#  "I've": ['been'],
#  'thinkingabout': ['you'],
#  'lot': ["lately.Who's"],
#  "lately.Who's": ['this?I'],
#  'this?I': ['thought'],
#  'thought': ['you', 'I'],
#  'wouldrecognize': ['my'],
#  'voice.You': ['spend'],
#  'spend': ['so'],
#  'obsessingabout': ['me,'],
#  'me,': ['am', 'sir.-', 'sir.Oh,', 'okay?I', 'Annie.Please.'],
#  'right?-': ['Say'],
#  'Say': ['hi'],
#  'hi': ['to'],
#  'baby': ['boy,', 'and......maybe', 'safelyat', 'clawed'],
#  'boy,': ['Dad.-'],
#  'Oh.': ['H-Hey,'],
#  'H-Hey,': ['hey,'],
#  'hey,': ['hey,', 'Hughie.Why'],
#  'Hughie.Why': ['is'],
#  'here?': ['He'],
#  'He': ['says', "ain't"],
#  'says': ["you'rein"],
#  "you'rein": ['some'],
#  'trouble.Dad,': ['are'],
#  'okay?Oh,': ["o-okay.He's"],
#  "o-okay.He's": ['fine.Remington'],
#  'fine.Remington': ["Steele's"],
#  "Steele's": ['almost'],
#  'almost': ['on.A-Train,'],
#  'on.A-Train,': ['listen'],
#  'listen': ['to', 'to'],
#  'me.Oh,': ['shit,', 'my'],
#  'burned,then': ["I'm"],
#  "fucked.He's": ['on'],
#  "Medicaid.He's": ['harmless.'],
#  'harmless.': ['Let'],
#  'Let': ['him'],
#  'go.My': ['place'],
#  "burned.They've": ['got'],
#  'God.Get': ['your'],
#  'ass': ['over'],
#  'herein': ['20'],
#  '20': ['minutes,or'],
#  'minutes,or': ["I'm"],
#  'burst': ['through'],
#  'through': ['himlike'],
#  'himlike': ['a'],
#  'piñata,do': ['you'],
#  'understand': ['me?Just'],
#  'me?Just': ['like'],
#  'girlfriend.-': ['Yeah.'],
#  'Yeah.': ['Got'],
#  'Got': ['it.-'],
#  'And,': ['Hughie,alone.'],
#  'Hughie,alone.': ['If'],
#  'If': ['I', 'you'],
#  'catch': ['a', 'up'],
#  'whiff,a': ['whiff'],
#  'whiff': ['of'],
#  'your-': ['little'],
#  'asshole': ['friends...-'],
#  'friends...-': ['I'],
#  'it.All': ['my'],
#  'bank': ['accounts'],
#  'accounts': ['are'],
#  'frozenand': ['flagged.'],
#  'flagged.': ['Monique,listen,'],
#  'Monique,listen,': ['when'],
#  'when': ['you'],
#  'this,leave': ['the'],
#  'house': ['immediately.Lay'],
#  'immediately.Lay': ['low'],
#  'low': ['and', 'end.-'],
#  'call': ['me.-', 'me', 'her.Please.Yeah.There'],
#  'Well,': ['I', 'most', "yeah.He's", "that's"],
#  'worth': ['it.-', 'running'],
#  "It's": ['not', "okay.It's"],
#  'Annie.-': ['She', 'I'],
#  'She': ["doesn't", 'looks'],
#  'know.-': ['It'],
#  'matter.-': ["I'm"],
#  'in.-': ['The', 'What...'],
#  'hell': ['you', 'of', 'is'],
#  'will!Hey,': ['hold'],
#  'second.She': ["doesn't"],
#  'know.': ['It', 'I'],
#  "wasn't": ["her.She's"],
#  'before.Not': ['once,'],
#  'once,': ['not'],
#  'ever.So': ['how'],
#  'how': ['did', 'that'],
#  'burned?Mesmer.': ['You'],
#  'idiotshad': ['to'],
#  'Mesmer.Fuck': ['me.Thank'],
#  'me.Thank': ['you.That'],
#  'you.That': ['was'],
#  'smart,to': ['sleep'],
#  'sleep': ['with'],
#  'her.-': ['Hughie.-'],
#  'Hughie.-': ["Dad.He's"],
#  "Dad.He's": ['acting'],
#  'acting': ['strange.You'],
#  'strange.You': ['know,'],
#  'real': ['jumpy.-', 'dosehidden'],
#  'jumpy.-': ['Where'],
#  'Where': ['is', 'the'],
#  'he?-': ['I'],
#  'he...Right': ['here,'],
#  'here,': ['sport.Look', 'then,', 'baby.Mmm.Daddy'],
#  'sport.Look': ['what'],
#  'got.Special': ['2016'],
#  '2016': ['Comic-Con'],
#  'Comic-Con': ['edition?What,'],
#  'edition?What,': ['did'],
#  'make,': ['like,a'],
#  'like,a': ['few'],
#  'hundred': ['of'],
#  'these?Watch': ['out,'],
#  'out,': ["A-Train's"],
#  "A-Train's": ['coming.You'],
#  'coming.You': ['were'],
#  'fan!You': ['were'],
#  'fan,': ['and'],
#  'not,like,': ['a'],
#  'dabbler,': ['no,you'],
#  'no,you': ['were'],
#  'super': ['fan'],
#  'fan': ['99.Excuse'],
#  '99.Excuse': ['me,'],
#  'sir.-': ['W-What'],
#  'W-What': ['is', 'is'],
#  'Shut': ['the'],
#  'up.Dad,': ["it's"],
#  'okay.': ['Hey.I', "It's"],
#  'Hey.I': ['came'],
#  'alone.You': ['let'],
#  'go.Alone,': ['huh?-'],
#  'huh?-': ['Wow.-'],
#  'Wow.-': ['Ah!You', 'Yeah.I'],
#  'Ah!You': ['really'],
#  'come': ['alone.Next',
#   "alone.Monique,it's",
#   'here.Give',
#   'to',
#   'to',
#   'on.All'],
#  'alone.Next': ['time...'],
#  'time...': ["there's"],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %% [markdown]
# This code is a function that takes in a dictionary and an optional argument for the number of words in the sentence. It randomly selects a key from the dictionary, capitalizes it, and adds it to the sentence. It then randomly selects a value from the list associated with that key and sets it as the new key. This process repeats until it reaches the number of words specified by count. The sentence is then ended with a period and returned.

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(s1e7_dict)
# Out:
# "Easy, lads. Easy.M.M.Deputy Director.Your family's gonna fucking friends, man.You promised methings would beslightly less humiliating.Yeah,."

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
s1e6_text = data.transcript.loc['s1e6']
s1e6_text[:200]

s1e6_dict = markov_chain(s1e6_text)
s1e6_dict

generate_sentence(s1e6_dict)
# Out:
# 'Angry.after all, Tek-Knight saved me.I-I just trying to hum the world.So every month?One hour, supervised.You.'

# %%
generate_sentence(s1e6_dict)
# Out:
# "Silver paint.I really happened to exploredifferent career paths,and, um, we ain't.Fuck 'em.We got your life.That's."

# %%
bill_text = data.transcript.loc['s1e4']
bill_text[:200]

bill_dict = markov_chain(bill_text)
bill_dict

generate_sentence(bill_dict)
# Out:
# 'Overthink it.We just say where, in bowling?And in everything?And bench-press you?Oh, my solemn promiseto you.Right,.'

# %%
dave_text = data.transcript.loc['s1e8']
dave_text[:200]

dave_dict = markov_chain(dave_text)
dave_dict

generate_sentence(dave_dict)
# Out:
# "Please just gonna need your job.Because you're useful.I mean, especially for,you know, one companythat has."

# %%
jim_text = data.transcript.loc['s1e1']
jim_text[:200]

jim_dict = markov_chain(jim_text)
jim_dict

generate_sentence(jim_dict)
# Out:
# "Jennifer. And we'll havethe fucker, I come on.Stay back.Just stay tuned fora behind-the-scenes lookat Invisible."

# %%
eric_text = data.transcript.loc['s1e2']
eric_text[:200]

eric_dict = markov_chain(eric_text)
eric_dict

generate_sentence(eric_dict)
# Out:
# "He?jersey City.What the onewho's trapped.Well, good boy.You're a team-up tomorrow morningno one's putting Supesinto national."

# %%
jim_text = data.transcript.loc['s1e3']
jim_text[:200]
jim_dict = markov_chain(jim_text)
jim_dict
# Out:
# {"I'll": ['take', 'take', 'stilllove'],
#  'take': ['this.Merci.Sorry', 'care', 'turns', 'care', 'care', 'it', 'me'],
#  'this.Merci.Sorry': ['about'],
#  'about': ['all',
#   'this.I',
#   'Becca,',
#   'Beccawith',
#   'him.We',
#   "it.I'm",
#   'youin',
#   'a',
#   'a',
#   'disciplineand'],
#  'all': ['the...Oh,',
#   'the',
#   'the',
#   'Americans.-',
#   'of',
#   'I',
#   'the',
#   "day?Let's",
#   'done.Thank',
#   "over.It's",
#   'over',
#   'clearedwith',
#   'over',
#   'right?Huh?',
#   'this',
#   'got.Their',
#   'you'],
#  'the...Oh,': ["don't"],
#  "don't": ['be',
#   'know',
#   'know.Well,',
#   'want',
#   'need',
#   'thinkthis',
#   "thinkit's",
#   'trust',
#   'actually',
#   'get',
#   'win,',
#   'want',
#   'you',
#   'know,',
#   "know.I've",
#   'know.Just',
#   'think',
#   'have',
#   'know...',
#   'really',
#   'it?Fuck...Oh.-',
#   'bite.Unless',
#   'be'],
#  'be': ['stupid.You',
#   'right',
#   'doing',
#   'different',
#   'decided',
#   "hurt.How?He's",
#   'fine.My',
#   'right',
#   'a',
#   'a',
#   'shy.Oh!'],
#  'stupid.You': ['did'],
#  'did': ['us', 'you', 'clear', 'we', 'I', 'they'],
#  'us': ['a',
#   "killed?Yeah.I'll",
#   'both',
#   'first.Attagirl.The',
#   'both',
#   'your',
#   'everything'],
#  'a': ['favor.What',
#   'state',
#   'huge',
#   'partnership.In',
#   'partnership,',
#   'while',
#   'while.-',
#   'Hello',
#   'passable',
#   'happy',
#   'man',
#   'difference,I',
#   'smaller',
#   'motherfucker',
#   'heart.Whereas',
#   'motherfucker.Funny',
#   "difference......'cause",
#   'Supe.Bullshit.Translucent.What',
#   'solid',
#   'big',
#   'good',
#   'good',
#   'few',
#   'happy',
#   'happy',
#   'big',
#   'pin',
#   'fucking',
#   'Stephen',
#   'cheap',
#   'camera',
#   'work',
#   'second.And',
#   'thousand',
#   'lot.Okay.',
#   "confession.We're",
#   'ton',
#   "gynecologist's",
#   'direct',
#   'direct',
#   'half.So',
#   "coronary.He's",
#   'good',
#   'girl,',
#   'slippery',
#   'plucked',
#   'couple.I',
#   'squadof',
#   'bit,can',
#   'mild-mannered',
#   'few',
#   'baptism',
#   'rush.I',
#   'price.The',
#   'stature',
#   'colossusfor',
#   "race?Huh?Let's",
#   'selfie?Of',
#   'little',
#   'minute.-',
#   'feeling',
#   'whim?-',
#   'freak.No.',
#   'hero.I',
#   'crime?-',
#   'crimewould',
#   'new',
#   'girl.Ladies',
#   'park',
#   'vial',
#   'slippery',
#   'fewminutes',
#   'joke,',
#   'drink,',
#   'superhero',
#   'worldwhere',
#   'cat',
#   'filthy',
#   'filthy',
#   'filthy',
#   'street,run',
#   'smart',
#   'very',
#   'porpoise.A'],
#  'favor.What': ['are'],
#  'are': ['we',
#   'you',
#   'you',
#   'on',
#   'they',
#   'you',
#   'you',
#   'extremelypowerful',
#   'you',
#   'you',
#   'you?All'],
#  'we': ['gonna',
#   'can',
#   'do',
#   'just',
#   'play',
#   'gota',
#   "don't",
#   'can',
#   'met',
#   'can',
#   'jump.Why?',
#   'do',
#   'just',
#   'could',
#   'think',
#   'get',
#   'burn',
#   'ever',
#   'not',
#   'need',
#   'could',
#   'got',
#   'want',
#   'got'],
#  'gonna': ['do',
#   'stash',
#   'do',
#   'lie',
#   'make',
#   'happen',
#   'be',
#   'eye-fuck',
#   "lose.You're",
#   'come,I',
#   'eat',
#   'see',
#   'take',
#   'sit',
#   'help'],
#  'do': ['with',
#   'you',
#   'you',
#   'you',
#   'here,',
#   'you',
#   'is',
#   'thatto',
#   'it?Well...Big',
#   'Homelander?This',
#   'you',
#   'we',
#   "that?'Cause",
#   'to',
#   'the',
#   'it.Am',
#   'not',
#   'you,',
#   'I',
#   'anything',
#   'you'],
#  'with': ['him?Ah,',
#   'you.Wait,',
#   'you,or',
#   'men...for',
#   'women,',
#   'females',
#   'her',
#   'my',
#   "y'all?This",
#   'these',
#   'that.But',
#   'a',
#   'him,be',
#   'Bryman',
#   'Stillwell.Look,',
#   'a',
#   'thatshit',
#   'you.-'],
#  'him?Ah,': ["we'll"],
#  "we'll": ['take'],
#  'care': ['of', 'of', 'of'],
#  'of': ['it.The-the,',
#   'shock,',
#   'course...but',
#   'it',
#   'the',
#   'trackat',
#   'thisfresh-faced',
#   'the',
#   'everybody',
#   'the',
#   'your',
#   'C-4,packed',
#   'that"secrets',
#   'committee,corporate',
#   'it.Yes.',
#   'your',
#   'mine.Mr.',
#   'shit!-',
#   'you,knock',
#   "y'all,",
#   "here.Who's",
#   'surprises.Okay,',
#   'people.Come',
#   'here.-',
#   'the',
#   'the',
#   'the',
#   'course.But',
#   'knowingunless',
#   'all...we',
#   'lost',
#   'time.Talk',
#   "fire.I'll",
#   "good.It's",
#   'my',
#   'the',
#   'The',
#   'comfortingthat',
#   "here.I'll",
#   'Vlike',
#   'Snickers.What,',
#   "A-Train's",
#   'guyshave',
#   'the',
#   'stairsin',
#   'mine-',
#   'maniac...Mm-mm.',
#   'him...eventually.So'],
#  'it.The-the,': ['uh,'],
#  'uh,': ['tracking', 'there', 'Aleksy.I'],
#  'tracking': ['chip.Already'],
#  'chip.Already': ['disabled.Sit'],
#  'disabled.Sit': ['down'],
#  'down': ['and', 'Sevenand', 'a'],
#  'and': ['relax,Petit',
#   'San',
#   'Evan',
#   'justice-',
#   'thieves,',
#   'pretendlike',
#   'lies"',
#   'make',
#   'a',
#   'everything.Um...You',
#   'very,',
#   'me?-',
#   'gentlemen,here',
#   'gentlemen,please',
#   'get'],
#  'relax,Petit': ['Hughie.Oi,'],
#  'Hughie.Oi,': ['where'],
#  'where': ['you', 'we'],
#  'you': ["thinkyou're",
#   'clothes.I',
#   'just',
#   'gonna',
#   'know',
#   'going',
#   'can-you',
#   'know,get',
#   "mean,there's...",
#   'mean,',
#   'how',
#   'love',
#   'have',
#   'both',
#   'want?What,',
#   'here?All',
#   'like',
#   'should',
#   'do',
#   "ain't",
#   'bringing',
#   'ever',
#   'make',
#   'these.Here.What',
#   'want',
#   'a',
#   'cheap',
#   'think',
#   "hadn't",
#   "don't",
#   'doing,',
#   'love',
#   'two',
#   'know',
#   'get',
#   'all',
#   'need',
#   'guys',
#   'want',
#   "can't",
#   'bet,',
#   'mean',
#   'guysare',
#   'know.He',
#   'show',
#   'go.Goddamn',
#   'are.You',
#   'do',
#   'put',
#   'sure,',
#   'up',
#   'even',
#   'lose.How',
#   'just',
#   'talking',
#   'kidding',
#   'grinning',
#   'work',
#   'up',
#   'pull',
#   "tell?'Cause",
#   'everbesmirch',
#   'got',
#   'for',
#   'cute?Is',
#   'look',
#   'know',
#   'made',
#   'might.Remember',
#   'and',
#   "didn't.Fuckin'",
#   'an',
#   'got',
#   'know?-',
#   'to',
#   'were',
#   'meant...you',
#   'everjust',
#   'like',
#   'quicker,',
#   'know?You',
#   'going?Just',
#   'know',
#   'think',
#   'celebrating',
#   'know',
#   'managedto',
#   'knowto',
#   'wait',
#   'said',
#   'would',
#   'want,but',
#   'want',
#   'wait?-',
#   'see?Huh?',
#   'can',
#   'talking',
#   'still',
#   'said.Whatever',
#   'got',
#   'knowabout',
#   'say',
#   'asked.Whoever'],
#  "thinkyou're": ["going?I'm"],
#  "going?I'm": ['going'],
#  'going': ['home.I', 'through.How', 'through,', 'somewhere?-'],
#  'home.I': ['need'],
#  'need': ["clothes.\n\n\nWe'll",
#   'to',
#   'these.Okay?I',
#   'five',
#   'it.-',
#   'anything',
#   'it.Honey,',
#   'to',
#   'a',
#   'more'],
#  "clothes.\n\n\nWe'll": ['get'],
#  'get': ['you',
#   'the',
#   'this',
#   'you',
#   'out',
#   'us',
#   'it.Why',
#   'a',
#   "some.Here's",
#   'it.-',
#   'a',
#   'going.-',
#   'back,you',
#   'meto',
#   'her',
#   "me!How'd",
#   'that',
#   'throughhis'],
#  'clothes.I': ['want'],
#  'want': ['my',
#   'to',
#   'to',
#   'a...autograph',
#   'to',
#   'to',
#   'to',
#   'usin',
#   'youto',
#   'me',
#   'a',
#   'her.What?'],
#  'my': ["clothes.I'll",
#   'first',
#   'old',
#   'body.I',
#   'board?Apologies,',
#   'board.Yes',
#   'wayinto',
#   'guest.Oh,',
#   'fault,',
#   'way',
#   'mother',
#   'specialty.Hello,',
#   'collar."Homelander.',
#   'collar.Eh,',
#   'hairdone,',
#   'eyebrows,waxing',
#   'bodylike',
#   'hand,',
#   'life.The',
#   'sweet.Hey,',
#   'boyA-Train.All',
#   'ass,',
#   'ass',
#   'number?Yeah.',
#   'body,you',
#   'little'],
#  "clothes.I'll": ['be'],
#  'right': ['back.You',
#   'to',
#   'up',
#   'over',
#   'there.Look,',
#   'now?-',
#   'in',
#   'now.Putting',
#   'now,',
#   'hereuntil'],
#  'back.You': ['are,'],
#  'are,': ['perhaps...in', 'uh...Yeah,'],
#  'perhaps...in': ['a'],
#  'state': ['of'],
#  'shock,': ['mon'],
#  'mon': ['ami.Hughie,'],
#  'ami.Hughie,': ['you'],
#  'just': ["arse-bombedAmerica's",
#   'piss',
#   'have',
#   "won't",
#   'cut',
#   'feel',
#   'a',
#   'dusted',
#   'I',
#   'another',
#   'need',
#   'sawmy',
#   'needto',
#   'lurkingaround',
#   'glad',
#   'saying,a',
#   'people.But',
#   'cut',
#   'tell',
#   'be',
#   'so',
#   'seemed,',
#   'meant...',
#   'want',
#   'commit',
#   "Mom's,",
#   'about',
#   'here',
#   'buying',
#   'declared'],
#  "arse-bombedAmerica's": ['sweetheart.You'],
#  'sweetheart.You': ["can't"],
#  "can't": ['just',
#   'find',
#   'wear',
#   'visit',
#   'do',
#   'argue',
#   'workwith',
#   'have',
#   'fucking',
#   'walk',
#   'breathe.-',
#   'I'],
#  'piss': ['off.I'],
#  'off.I': ['need'],
#  'to': ['go',
#   '49,even',
#   'say.-',
#   'enjoy',
#   'capitalizeon',
#   'choosehow',
#   'Dr.',
#   "normal.There's",
#   'me.-',
#   'smother',
#   'writein',
#   'see',
#   'come',
#   'yourself.I',
#   'know',
#   'mention,',
#   'God.Are',
#   'goto',
#   'give',
#   'go',
#   '82and',
#   'put',
#   'marinadethe',
#   'go.All',
#   'do.Fuck',
#   'Translucent,A-Train',
#   'a',
#   'your',
#   'downloadthe',
#   'get',
#   'him,then',
#   'say',
#   'a',
#   'the',
#   'the',
#   "me.Yeah.We're",
#   'do',
#   'win',
#   'besome',
#   'go.Why',
#   'see',
#   'tell',
#   'getmy',
#   'get',
#   "knowwhat's",
#   'Robin...was',
#   'live',
#   'hear.-',
#   'see',
#   'meet',
#   'pressyour',
#   'justfly',
#   'Paris,',
#   'see',
#   'someonewho',
#   'be',
#   'prove.I',
#   'rock',
#   'A-Train.A-Train',
#   "catch.I'm",
#   'offers,though,',
#   'go',
#   'write',
#   'eat',
#   'eat',
#   'eat',
#   'hurt',
#   'dois'],
#  'go': ['home.All', 'with', 'to', 'around.A-Train,'],
#  'home.All': ['right.Frenchie'],
#  'right.Frenchie': ['will'],
#  'will': ['go', 'come'],
#  'you.Wait,': ['what?'],
#  'what?': ['No.Either', 'Shockwave'],
#  'No.Either': ['he'],
#  'he': ['goes', 'murdered', 'met', 'stands...six', "didn't"],
#  'goes': ['with'],
#  'you,or': ['I'],
#  'I': ['break',
#   "don't",
#   'said',
#   'show.That',
#   "don't",
#   'fucking',
#   'was',
#   'was',
#   'tell',
#   'not?-',
#   "can't",
#   'can',
#   "can't",
#   "ain't",
#   'realized',
#   'heard',
#   'said,"No.',
#   "don't",
#   'am,some',
#   "don't",
#   'forgot',
#   'just...Uh,',
#   "need's",
#   "didn't",
#   'just',
#   'have',
#   'mean,Terminal',
#   'thinkwhat',
#   'love',
#   "can't",
#   'let',
#   "lose?You're",
#   "don't",
#   'need',
#   'have',
#   'got',
#   "don't",
#   'can',
#   'try',
#   'guess.Still.',
#   'knowhow',
#   'had',
#   'felt,',
#   'felt',
#   'got',
#   'got',
#   'got',
#   'want',
#   'right?',
#   'get',
#   'need',
#   'rememberfreezing',
#   'ever',
#   'could',
#   'not',
#   'should',
#   'meant',
#   'just...I',
#   'was.Once',
#   'was',
#   'call',
#   'just',
#   'roll,',
#   'see',
#   'mean...-',
#   'got',
#   'see'],
#  'break': ['your', 'up?You'],
#  'your': ['legs.Good',
#   'own',
#   'transformation,',
#   'doctor.And',
#   'names',
#   'John',
#   'name',
#   'talents?-',
#   "reasons?It'll",
#   'tune?No',
#   'baby,and',
#   "mother's",
#   'manager',
#   'serverin',
#   'John',
#   'shooter?-',
#   "cover.You're",
#   'face,Hughie.What?',
#   'back.Now,',
#   'old',
#   'tits!Come',
#   'money.I',
#   'new',
#   'job,',
#   'attentionto',
#   'secret?Secret?',
#   'headin',
#   'message.Where'],
#  'legs.Good': ["lad.Translucent's"],
#  "lad.Translucent's": ['skin,it'],
#  'skin,it': ["won't"],
#  "won't": ['burn', 'be'],
#  'burn': ['off.Where', 'it.First'],
#  'off.Where': ['you'],
#  'stash': ['itHomelander'],
#  'itHomelander': ["can't"],
#  'find': ['it?Nowhere.\n\n\nBut',
#   'outone',
#   "it.You're",
#   'it,',
#   "Translucent...what's"],
#  'it?Nowhere.\n\n\nBut': ['we'],
#  'can': ['slow',
#   'A-Train',
#   'talk',
#   "see.Don't",
#   'trust.Since',
#   'sell',
#   'get',
#   'help,',
#   'runsome',
#   'you',
#   'order',
#   'only',
#   'wait',
#   'cross',
#   'you?And',
#   'show'],
#  'slow': ['the'],
#  'the': ['cunt',
#   'roof.You',
#   'ass-kicking,',
#   'empowerment.16',
#   'liberalretreat',
#   'buzz.',
#   'girl',
#   'story.Of',
#   'effort,I',
#   'right',
#   'century.The',
#   'fastest',
#   'dayhe',
#   'hands',
#   'century.Well,',
#   'Supe',
#   'name',
#   'TVlike',
#   'hellis',
#   'pong?Oslo,',
#   'other',
#   'unit.Now,',
#   'English',
#   'bottom',
#   'list.Oh,',
#   'fuck',
#   'unbreakable',
#   "same,let's",
#   'small',
#   'groundevery',
#   'Mallory',
#   'f...Well,',
#   'hell',
#   'fireworks,he',
#   'beans',
#   'same',
#   'only',
#   'record-',
#   'military.-',
#   'floor.Oh,',
#   'military',
#   'shit',
#   'red',
#   'flag"?Remember',
#   'military.Thank',
#   'side',
#   'street.Bang',
#   'game',
#   'bridge.You',
#   'bridge.-',
#   'both',
#   'head,',
#   "Supe.Oh.She's",
#   "bishop.Didn't",
#   'check',
#   'bugs',
#   'house',
#   'toilet?-',
#   'toilet.',
#   'new',
#   'whole',
#   'wayup',
#   'Seven',
#   'Seven,which',
#   'one',
#   'blueand',
#   'extra',
#   'real',
#   'raceto',
#   'partwhere',
#   'raceanyway?See,',
#   'only',
#   "truth.Mm-mm.It's",
#   'drill.He',
#   'thing?Yeah.',
#   "problem?Shockwave's",
#   'problem.What',
#   'fastest',
#   'secondfastest',
#   'V',
#   'race.What',
#   'worldas',
#   'V?-',
#   'hell',
#   'kindof',
#   'spoonful.Not',
#   'fuckdid',
#   'detonatorin',
#   'shit',
#   'last',
#   'rest',
#   'Race',
#   'Century.This...',
#   'highest',
#   'station.He',
#   'worldare',
#   'whole',
#   'deep-state',
#   'people',
#   'armed',
#   'singingof',
#   "part.It's",
#   'new',
#   'Atlantic.Yeah,',
#   'A-Train.All',
#   'station.Ooh!All',
#   'clear.Starlight!',
#   'bench',
#   'other',
#   'way.-',
#   'other',
#   "scenes,it's...-",
#   'benchwhen',
#   'show.Ladies',
#   'V.We',
#   'hell',
#   'track.Please,',
#   "track.Set.Yes!He's",
#   'helldo',
#   'world,and',
#   'A-Train,',
#   'game,but',
#   'game,',
#   'rent.The',
#   'check.I',
#   'name',
#   'law.Oh,',
#   'cops',
#   "price,you'll",
#   'fire?No,',
#   'bottomof',
#   'harbor.Go',
#   'box'],
#  'cunt': ['downa'],
#  'downa': ['bit.Come', 'point'],
#  'bit.Come': ['on'],
#  'on': ['in.Ms.',
#   'YouTubeand',
#   'pay-per-view,the',
#   'that',
#   'my',
#   'my',
#   'the',
#   'a',
#   'the',
#   'it.All',
#   'time.Uh,',
#   'your',
#   'the',
#   'these',
#   'it.They',
#   'in.The',
#   'to',
#   "me.You've",
#   '31.All',
#   'itwhen',
#   'top?There',
#   'a',
#   'the',
#   "A-Train.He's",
#   'a',
#   'top',
#   'her?Okay.You'],
#  'in.Ms.': ['Stillwell.'],
#  'Stillwell.': ['Hello.Please'],
#  'Hello.Please': ['sit.Starlight,'],
#  'sit.Starlight,': ['that'],
#  'that': ['video.-',
#   'video',
#   'feminist?-',
#   'couch,staring',
#   'work!-',
#   "we're",
#   'was...If',
#   'Mallory',
#   'motherfucker.Frenchie?No,',
#   'affects',
#   'the',
#   'is',
#   'you',
#   'onereally',
#   'all',
#   'mewling',
#   'stuff,',
#   'supposedto',
#   'we',
#   'Langleyis',
#   'sounds',
#   'off?I',
#   'moment,',
#   'rush,',
#   'wind',
#   'one',
#   "you'd",
#   'so?-',
#   'red',
#   'check.You',
#   'guy',
#   'Translucent?Still'],
#  'video.-': ['Ms.'],
#  'Ms.': ['Stillwell,'],
#  'Stillwell,': ['please.-'],
#  'please.-': ['No,'],
#  'No,': ['no.',
#   'you',
#   'sir.Nuh-uh,',
#   'no,',
#   'I',
#   'Frenchie,not',
#   'Hughie,',
#   'not',
#   "that's",
#   'no,'],
#  'no.': ['Let', 'We', 'Popclaw'],
#  'Let': ['me', 'me'],
#  'me': ['finish.The',
#   'the',
#   'youput',
#   'old',
#   'come',
#   'in',
#   'on',
#   'through',
#   'knowif',
#   'the',
#   'to',
#   'right',
#   'he',
#   'feel.When',
#   'a',
#   'to.That'],
#  'finish.The': ['date-rape'],
#  'date-rape': ['girl?'],
#  'girl?': ['The'],
#  'The': ['victim?She',
#   'Seven.Destiny',
#   'Big',
#   'Seven,unless',
#   'Today',
#   'Seven.Babe.Compound',
#   'Seven...Starlight,accompanied'],
#  'victim?She': ['saw'],
#  'saw': ['that'],
#  'video': ['on'],
#  'YouTubeand': ['she'],
#  'she': ['came',
#   'answers,to',
#   'do?',
#   'cry',
#   'quit?-',
#   'heardbefore',
#   'burst',
#   'going?-',
#   'nickedsome',
#   'told'],
#  'came': ['forwardto', 'together.Let'],
#  'forwardto': ['thank'],
#  'thank': ['you.She'],
#  'you.She': ['could'],
#  'could': ['not', 'shake', 'be', 'finallystand', 'handle', 'come......to'],
#  'not': ['have',
#   'me.I',
#   'afraidto',
#   "seven.I'm",
#   'crying.The',
#   'the',
#   'even',
#   'gonna',
#   'gonnahappen',
#   'whatI',
#   'like...',
#   'need',
#   'crack',
#   'realize',
#   'at...',
#   'thatyou',
#   'a',
#   'fire.'],
#  'have': ['beenmore',
#   'a',
#   'to',
#   'some',
#   'the',
#   'never',
#   'never',
#   'cut',
#   'I',
#   'another',
#   'that...You',
#   'onein',
#   'a',
#   'to',
#   'been',
#   'been',
#   'hid',
#   'that...-',
#   'you',
#   'clawedyour'],
#  'beenmore': ["effusive.That's..."],
#  "effusive.That's...": ["that's"],
#  "that's": ['good,', 'a', 'why', 'true.I', 'suchthat', 'notwhat', 'the'],
#  'good,': ['right?It', 'just...-', 'clean'],
#  'right?It': ['is'],
#  'is': ["fantastic.You're",
#   'so',
#   'Seth',
#   'rough,',
#   'notin',
#   'that',
#   'a',
#   'giveand',
#   "take.It's",
#   'true.',
#   'wrapped',
#   'tomorrow',
#   'notwhat',
#   'lieand',
#   'good,-',
#   'back,',
#   'Monique?Spits',
#   "God's",
#   'about',
#   'it?Those',
#   'conspicuous?Conspicuous?',
#   'conspicuous.This',
#   'just',
#   'this',
#   'coming-',
#   'me',
#   'water',
#   'Mallory?All',
#   'it?Nothing.This',
#   'full',
#   'no',
#   'missing,they',
#   'a',
#   'this',
#   'that',
#   'gonna',
#   'Compound',
#   'exactly',
#   'our',
#   'what',
#   'readyto',
#   'looking',
#   'readyto',
#   'just',
#   'insane,',
#   'a',
#   'the'],
#  "fantastic.You're": ['polling'],
#  'polling': ['through'],
#  'through': ['the', 'at', 'a', 'my'],
#  'roof.You': ['have'],
#  'huge': ['boost'],
#  'boost': ['with'],
#  'men...for': ['the'],
#  'ass-kicking,': ['of'],
#  'course...but': ['with'],
#  'women,': ['too.They'],
#  'too.They': ['love'],
#  'love': ['the', 'Pizza', 'so', 'you,', "you.You're", 'your'],
#  'empowerment.16': ['points'],
#  'points': ['with'],
#  'females': ['18'],
#  '18': ['to'],
#  '49,even': ['in'],
#  'in': ['the',
#   'her',
#   'that.Tomorrow,A-Train',
#   'linein',
#   'a',
#   'years.M.M.,',
#   'the',
#   'committee.-',
#   'the',
#   'it.And',
#   'it,all',
#   'anything.-',
#   'the',
#   'the',
#   'The',
#   'that',
#   'excessof',
#   'the',
#   'New',
#   'the',
#   'some',
#   'townand',
#   'later.Where',
#   'the',
#   'the'],
#  'liberalretreat': ['jurisdictionslike'],
#  'jurisdictionslike': ['New'],
#  'New': ['York', 'York.Who'],
#  'York': ['and'],
#  'San': ['Francisco.-'],
#  'Francisco.-': ['I'],
#  'know': ['what',
#   "whatI'm",
#   'how',
#   'that,',
#   'nothingabout',
#   'the-the',
#   "this.I've",
#   'the',
#   'what',
#   'what?Save',
#   'Starlight?Well,',
#   'who',
#   "you're",
#   'what',
#   'Starlight?I',
#   'herknow',
#   'what?',
#   "me.I'm"],
#  'what': ['to',
#   'does',
#   "you're",
#   'Stillwell',
#   'we',
#   "we've",
#   'I',
#   'I',
#   "I'm",
#   "I'm",
#   'you'],
#  'say.-': ['You'],
#  'You': ['just', 'do.You', 'get', 'prefer', 'know...-'],
#  'enjoy': ['this.This'],
#  'this.This': ['is'],
#  'so': ['good',
#   'great',
#   'I',
#   'sorry,',
#   'much.Yeah,',
#   'weird.I',
#   'normal,',
#   'fast.Oh,',
#   'glad'],
#  'good': ['for', 'boy?-', 'boy?-', 'boy.Mmm.Oh,', 'times.Why', 'friend'],
#  'for': ['you.And',
#   'us,because',
#   'The',
#   'truth',
#   "ourselves.Where-Where'd",
#   'Supes?-',
#   'the',
#   'one',
#   'my',
#   'the',
#   'coming.It',
#   'the',
#   'someone',
#   'me.-',
#   'A-Train.They',
#   'an',
#   'the'],
#  'you.And': ["it's"],
#  "it's": ['so',
#   'feminist.-',
#   'all',
#   'just',
#   'waterunder',
#   "'causeThe",
#   'just...-',
#   'different.-',
#   'just',
#   'made',
#   'gonna'],
#  'great': ['for'],
#  'us,because': ['it'],
#  'it': ['isa',
#   'I',
#   'is',
#   'mean?Come',
#   'out.Means',
#   'myself,',
#   'in.Look,',
#   'to',
#   'on',
#   'the',
#   'up',
#   'on',
#   'wasStephen',
#   'still',
#   'from',
#   'was',
#   'with',
#   'was,he',
#   'does.If',
#   'out?Oh,',
#   "is...I'll",
#   'for',
#   'okay',
#   'was...It',
#   'somewhere',
#   'three',
#   'again!A-Train',
#   'for',
#   'was...they'],
#  'isa': ['partnership,'],
#  'partnership,': ['after', 'there'],
#  'after': ['all.-', 'the'],
#  'all.-': ['This'],
#  'This': ['is', "isn't"],
#  'Seth': ['and'],
#  'Evan': ['from'],
#  'from': ['marketing.-', 'work,I', 'me.No,'],
#  'marketing.-': ['Hi.They'],
#  'Hi.They': ['have'],
#  'some': ['brilliant',
#   'bad',
#   'myself.Amazing',
#   'ways...just',
#   'noise!Glad',
#   'overpriced',
#   'Supe,'],
#  'brilliant': ['ideason'],
#  'ideason': ['how'],
#  'how': ['to',
#   'muchI',
#   'to',
#   "you're",
#   "'bout",
#   'muchyou',
#   'I',
#   'the',
#   'have'],
#  'capitalizeon': ['all'],
#  'buzz.': ['Gentlemen.-'],
#  'Gentlemen.-': ['Okay.'],
#  'Okay.': ['So...-'],
#  'So...-': ['Yeah.Now,', 'Yeah,'],
#  'Yeah.Now,': ['small-town'],
#  'small-town': ['Iowa'],
#  'Iowa': ['girl,unexpected'],
#  'girl,unexpected': ['child'],
#  'child': ['prodigy,is'],
#  'prodigy,is': ['chosen'],
#  'chosen': ['for'],
#  'Seven.Destiny': ['knockson'],
#  'knockson': ['the'],
#  'girl': ['next', 'gets'],
#  'next': ["door's"],
#  "door's": ['door,and'],
#  'door,and': ['she'],
#  'answers,to': ['fight'],
#  'fight': ['for'],
#  'truth': ['and'],
#  'justice-': ['side'],
#  'side': ['by', 'with', 'is'],
#  'by': ['side', 'a', "DeLuca's,pick", 'the', 'Black'],
#  'her': ['heroes.-',
#   'milk?-',
#   'feminine',
#   'again,',
#   'IPv6',
#   'number?Yeah.Hughie?Uh,'],
#  'heroes.-': ['The', "We're"],
#  'Big': ['Apple'],
#  'Apple': ['is'],
#  'rough,': ["tumble.It's"],
#  "tumble.It's": ['got'],
#  'got': ['worms.',
#   'your',
#   'diamond',
#   'to',
#   'a',
#   'the',
#   'a',
#   'blood',
#   "excited.I'm",
#   'to',
#   'to',
#   'to',
#   'to',
#   'this?Yeah.Hey...Ma',
#   'this?-',
#   'this.-',
#   'this.',
#   'room',
#   'time.Throw',
#   'nothing',
#   'eyes',
#   'experience.I',
#   'there,she',
#   'herright',
#   'to',
#   'your',
#   'nothingto'],
#  'worms.': ['Muggersand'],
#  'Muggersand': ['rapists'],
#  'rapists': ['and'],
#  'thieves,': ['oh,'],
#  'oh,': ['my.Dorothy'],
#  'my.Dorothy': ['is'],
#  'notin': ['Kansas'],
#  'Kansas': ['anymore.Or'],
#  'anymore.Or': ['Iowa.'],
#  'Iowa.': ['Poor'],
#  'Poor': ['girl'],
#  'gets': ['knockedaround'],
#  'knockedaround': ['something'],
#  'something': ['fierce.-', 'fierce.Remember'],
#  'fierce.-': ['Kicked'],
#  'Kicked': ['while'],
#  'while': ["she's", 'now,'],
#  "she's": ['down.-', 'got'],
#  'down.-': ['So'],
#  'So': ['what', 'we'],
#  'does': ['she', 'it', 'what'],
#  'do?': ['Does'],
#  'Does': ['she', 'she'],
#  'cry': ['in'],
#  'milk?-': ['Does'],
#  'quit?-': ['No'],
#  'No': ['way!She', 'V.-'],
#  'way!She': ['adapts!'],
#  'adapts!': ['She'],
#  'She': ['transforms!Embraces'],
#  'transforms!Embraces': ['her'],
#  'feminine': ['strengths.Good-bye,'],
#  'strengths.Good-bye,': ['Yellow'],
#  'Yellow': ['Brick'],
#  'Brick': ['Road...And'],
#  'Road...And': ['hello,'],
#  'hello,': ['Starlight.I'],
#  'Starlight.I': ["can't"],
#  'wear': ['that.What?Why'],
#  'that.What?Why': ['not?'],
#  'not?': ["It's"],
#  "It's": ["beautiful.Seriously?I-It's", "bold,it's"],
#  "beautiful.Seriously?I-It's": ["just...It's"],
#  "just...It's": ['not'],
#  'me.I': ['designed', 'am'],
#  'designed': ["Homelander's"],
#  "Homelander's": ['suit.-'],
#  'suit.-': ['This'],
#  "isn't": ['my', "it?It's"],
#  'first': ['rodeo.-'],
#  'rodeo.-': ["You're"],
#  "You're": ["wrong.It's"],
#  "wrong.It's": ['totally'],
#  'totally': ['you.', 'jacked.He'],
#  'you.': ["It's"],
#  "bold,it's": ['brave,'],
#  'brave,': ["it's"],
#  'feminist.-': ['How'],
#  'How': ['is', 'is', 'can'],
#  'feminist?-': ['Empowering.It'],
#  'Empowering.It': ['says'],
#  'says': ["you're"],
#  "you're": ['confidentin',
#   'not',
#   'going',
#   'gonna',
#   'doing',
#   'the',
#   'a',
#   'right,',
#   'right.I',
#   'behind',
#   'youand'],
#  'confidentin': ['your'],
#  'own': ['skin,and'],
#  'skin,and': ["you're"],
#  'afraidto': ['show'],
#  'show': ['it.Most', 'up', 'her.Well,'],
#  'it.Most': ['importantly,it'],
#  'importantly,it': ['tells'],
#  'tells': ['the', 'me', 'me'],
#  'story.Of': ['your'],
#  'transformation,': ['of...of'],
#  'of...of': ['what'],
#  'through.How': ['exactly'],
#  'exactly': ['do', 'rolling', 'the', 'what'],
#  "whatI'm": ['going'],
#  'through,': ["exactly?I'm"],
#  "exactly?I'm": ['sorry.I-I'],
#  'sorry.I-I': ['appreciate'],
#  'appreciate': ['the'],
#  'effort,I': ['really'],
#  'really': ['do,but',
#   'big',
#   'messed',
#   'dress',
#   'thought-',
#   'nice',
#   'niceto',
#   'know'],
#  'do,but': ["I'm"],
#  "I'm": ['fine',
#   'sorry',
#   'gonna',
#   'happy',
#   'actuallymaking',
#   'gonna',
#   'not',
#   'not.You',
#   'out.Nobody',
#   'talking',
#   'late.You',
#   'a',
#   'messing',
#   'ready',
#   "good.I'm",
#   "saying?I've",
#   'saying.Get',
#   'too',
#   'just'],
#  'fine': ['with', 'AF!Lean'],
#  'old': ['outfit.-', 'mate?Rekindle', 'uniform,'],
#  'outfit.-': ["We're"],
#  "We're": ['not.-', 'just', "different.We're", 'fucked.No,'],
#  'not.-': ['Excuse'],
#  'Excuse': ['me?Starlight,', 'me,', 'us,'],
#  'me?Starlight,': ['like'],
#  'like': ['I',
#   'to',
#   'engine',
#   'that.No,',
#   'that',
#   'one.The',
#   'my',
#   'that.Sounds',
#   'to'],
#  'said': ['before,this', 'to', "it.She's", 'you'],
#  'before,this': ['is'],
#  'partnership.In': ['a'],
#  'there': ['is', 'is', 'together', 'can', 'if'],
#  'giveand': ['there'],
#  "take.It's": ['my'],
#  'body.I': ['have'],
#  'choosehow': ['much'],
#  'much': ['of', 'I', 'better.-'],
#  'show.That': ['is'],
#  'true.': ['You'],
#  'do.You': ['just'],
#  'doing': ['itin', 'fine,and'],
#  'itin': ['The'],
#  'Seven,unless': ['it'],
#  'wrapped': ['in'],
#  'that.Tomorrow,A-Train': ['versus'],
#  'versus': ['Shockwave.The'],
#  'Shockwave.The': ['race'],
#  'race': ['of', 'of'],
#  'century.The': ['question'],
#  'question': ['now,'],
#  'now,': ['Al,is', 'so...What,', 'huh?Are', 'right?Kick', "it's"],
#  'Al,is': ['can'],
#  'A-Train': ['keep', 'are,', 'shoots'],
#  'keep': ['his', 'an'],
#  'his': ['titleas', 'ass!Yo!What', 'fudger.Boom.'],
#  'titleas': ['the'],
#  'fastest': ['man', 'man', 'men', 'man'],
#  'man': ['alive?Or', 'now.Life', 'of', 'alive.Until', 'in', 'in'],
#  'alive?Or': ['is'],
#  'tomorrow': ['the'],
#  'dayhe': ['runs'],
#  'runs': ['out'],
#  'out': ['of',
#   'there!Well,',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'on',
#   'of',
#   'this'],
#  'trackat': ['the'],
#  'hands': ['of'],
#  'thisfresh-faced': ['young'],
#  'young': ['challenger?Just', 'gun'],
#  'challenger?Just': ['wait'],
#  'wait': ['here,', 'aroundlong', 'there'],
#  'here,': ['okay?Tomorrow,', 'gentlemen.Now,', "ma'am.Only", "honey.Let's"],
#  'okay?Tomorrow,': ['live'],
#  'live': ['on', 'with'],
#  'pay-per-view,the': ['race'],
#  'century.Well,': ['Shockwave...Hughie?Oh,'],
#  'Shockwave...Hughie?Oh,': ['hey,'],
#  'hey,': ['Dad.Wh...', 'hey,', 'hey,', 'hey,', 'hey.You'],
#  'Dad.Wh...': ['look'],
#  'look': ['at', 'fine', 'like', 'wired'],
#  'at': ['the,-',
#   'the',
#   'the',
#   'the',
#   'him,',
#   'the',
#   'us',
#   'your',
#   'you!You',
#   'all.I',
#   'it'],
#  'the,-': ["you-you've,"],
#  "you-you've,": ['this'],
#  'this': ['is...-',
#   'is',
#   'right,we',
#   'go,all',
#   'time.I',
#   'guy?!-',
#   'frog',
#   'French',
#   'guy?The',
#   'birdinside',
#   'shit,Circuit',
#   'about',
#   'close',
#   'thing.I',
#   'is',
#   'job',
#   'job?Then,',
#   'is',
#   "time?What's",
#   'little'],
#  'is...-': ['Yeah,'],
#  'Yeah,': ['yeah,',
#   'sure.-',
#   'you',
#   "okay.Okay.That's",
#   'I',
#   'you',
#   'totally.',
#   "that's-that's,",
#   'yeah,'],
#  'yeah,': ["I'm", "yeah.I'm"],
#  'sorry': ['about'],
#  'this.I': ['just,'],
#  'just,': ["I've"],
#  "I've": ['been', 'seento'],
#  'been': ['meaningto',
#   'very',
#   'meaning',
#   'getting',
#   'scary.You',
#   'at',
#   'around'],
#  'meaningto': ['clean'],
#  'clean': ['up', 'race,but,'],
#  'up': ['the',
#   'on',
#   'his',
#   'a',
#   'with',
#   'two',
#   'on',
#   'out',
#   'to',
#   'something',
#   'B-squader.Like',
#   'there',
#   'by',
#   'here.So,',
#   'for',
#   'the',
#   'four'],
#  'Supe': ['stufffor'],
#  'stufffor': ['a'],
#  'so...What,': ['are'],
#  'somewhere?-': ['Yeah.'],
#  'Yeah.': ['For', 'I', 'Well,', 'Yeah,'],
#  'For': ['a'],
#  'while.-': ['Where?Uh,'],
#  'Where?Uh,': ['I'],
#  'know.Well,': ["now,you're"],
#  "now,you're": ['scaring'],
#  'scaring': ['me,'],
#  'me,': ['Hugh.All', 'neither,', 'bud.What,'],
#  'Hugh.All': ['right,'],
#  'right,': ['now,I-I',
#   'the',
#   'sweetheart.Yeah.',
#   "you're",
#   'champ.-',
#   'Frenchie,',
#   'I'],
#  'now,I-I': ['spoke'],
#  'spoke': ['to'],
#  'Dr.': ['Feldman...-'],
#  'Feldman...-': ['My'],
#  'My': ['pediatrician?-'],
#  'pediatrician?-': ["He's"],
#  "He's": ['still', 'not', 'a', 'upgrading'],
#  'still': ['your', 'is.Yeah,', "ain't"],
#  'doctor.And': ["he's"],
#  "he's": ['given', 'a'],
#  'given': ['me'],
#  'name': ['ofsomeone', 'comes', 'of'],
#  'ofsomeone': ['you'],
#  'can-you': ['can'],
#  'talk': ['to.Help', 'to'],
#  'to.Help': ['you,'],
#  'you,': ['you', 'too.Okay.', 'guys.Thank', 'uh...?-'],
#  'know,get': ['back'],
#  'back': ['to', 'to', "first.Where's"],
#  "normal.There's": ['no'],
#  'no': ['normal', 'pin.I', 'one', 'way', 'differentthan', "secret.It's"],
#  'normal': ['anymore.What'],
#  'anymore.What': ['do'],
#  "mean,there's...": ["Look.We've"],
#  "Look.We've": ['always'],
#  'always': ['been', 'toldeach', 'about', 'in'],
#  'very': ['openwith', 'quick.The', 'good'],
#  'openwith': ['each'],
#  'each': ['other,'],
#  'other,': ["right?We-We've"],
#  "right?We-We've": ['always'],
#  'toldeach': ['other'],
#  'other': ['everything.-',
#   'niggas...Excuse',
#   "day?You're,",
#   'day....-',
#   'day'],
#  'everything.-': ['Talk'],
#  'Talk': ['to'],
#  'me.-': ['Stop', 'So...-'],
#  'Stop': ['it.-', 'it.I'],
#  'it.-': ['What', 'Uh,', 'Like', 'Is'],
#  'What': ['do', 'agreement?-', 'the', 'do'],
#  'mean,': ['stop', 'home', 'that', 'it', 'the', "it's...", 'I...'],
#  'stop': ['it?-', 'by'],
#  'it?-': ['Stop'],
#  'it.I': ['have', 'had'],
#  'never': ['told', 'told'],
#  'told': ['youeverything.I', 'you', 'me?If', 'A-Trainthat'],
#  'youeverything.I': ['have'],
#  'muchI': ['hate'],
#  'hate': ['sitting'],
#  'sitting': ['on'],
#  'couch,staring': ['at'],
#  'TVlike': ["we're"],
#  "we're": ['already', 'disrespectingall', 'good,', 'sureit'],
#  'already': ['dead.How'],
#  'dead.How': ['much'],
#  'fucking': ['hatePizza',
#   '"Flowers"on',
#   'job',
#   'Hawking.-',
#   'Hawkingwho',
#   'standTranslucent.-',
#   'cocksuckers.Please',
#   'Homie.Now',
#   'head',
#   'porpoise'],
#  'hatePizza': ['Rolls.-'],
#  'Rolls.-': ['No,', 'When'],
#  'Pizza': ['Rolls.-'],
#  'When': ['I'],
#  'was': ['seven!I',
#   'bipolar.One',
#   'ten,he',
#   'no',
#   'due',
#   'my',
#   'all',
#   'juiced',
#   'the',
#   'nice',
#   'really',
#   'really',
#   'asking.-',
#   'a',
#   'dead',
#   'a'],
#  'seven!I': ['am'],
#  'am': ['not', 'more', 'so', 'gonna'],
#  "seven.I'm": ['sorry.My'],
#  'sorry.My': ['father'],
#  'father': ['was'],
#  'bipolar.One': ['night,'],
#  'night,': ['when'],
#  'when': ['I', 'we', 'used', 'I'],
#  'ten,he': ['tried'],
#  'tried': ['to'],
#  'smother': ['mewith'],
#  'mewith': ['a'],
#  'Hello': ['Kitty'],
#  'Kitty': ['duvet.-'],
#  'duvet.-': ['Give'],
#  'Give': ['him', "'em"],
#  'him': ['that', 'in'],
#  'work!-': ['Kick'],
#  'Kick': ['his'],
#  'ass!Yo!What': ['the'],
#  'hellis': ['wrong'],
#  'wrong': ['with'],
#  "y'all?This": ['is'],
#  'notwhat': ['we', 'I'],
#  'gentlemen.Now,': ["didn't"],
#  "didn't": ['I', 'make', 'mention', 'know', 'do'],
#  'tell': ['you,we', 'me', 'thatto', 'mewhere', 'you.Are', 'us'],
#  'you,we': ['take'],
#  'turns': ['at'],
#  'pong?Oslo,': ['Deeaygo,'],
#  'Deeaygo,': ['tell'],
#  'youput': ['your'],
#  'names': ['up'],
#  'board?Apologies,': ['Mr.'],
#  'Mr.': ['Milk.', 'Milk.Which', 'Milk.', 'Lutz.'],
#  'Milk.': ['No,', 'Thank'],
#  'sir.Nuh-uh,': ['me,'],
#  'neither,': ['Mr.'],
#  'Milk.Which': ['meansthat'],
#  'meansthat': ['you'],
#  'cut': ['in', 'the', 'to'],
#  'linein': ['front'],
#  'front': ['of', 'of'],
#  'everybody': ['elsein'],
#  'elsein': ['here.What'],
#  'here.What': ['else'],
#  'else': ['does'],
#  'mean?Come': ['on,'],
#  'on,': ['spit', 'M.M.Bring', 'man.My', 'Frenchie.Like'],
#  'spit': ['it'],
#  'out.Means': ['that'],
#  'disrespectingall': ['the'],
#  'niggas...Excuse': ['me?All'],
#  'me?All': ['our'],
#  'our': ['fellow',
#   'checks.Can',
#   'time',
#   'legacyand',
#   'future.Athletes',
#   'national'],
#  'fellow': ['brothersin'],
#  'brothersin': ['the'],
#  'unit.Now,': ['you'],
#  'both': ['know', 'of', 'at', 'right'],
#  'writein': ['the'],
#  'English': ['languagein'],
#  'languagein': ['a'],
#  'passable': ['fashion.I'],
#  'fashion.I': ['know'],
#  'that,': ["'cause", 'that'],
#  "'cause": ["I've"],
#  'seento': ['it'],
#  'myself,': ['have'],
#  'not?-': ['Yes,'],
#  'Yes,': ['sir.-', 'baby.-'],
#  'sir.-': ['Then'],
#  'Then': ['please,'],
#  'please,': ['place'],
#  'place': ['your'],
#  'John': ['Hancocks', 'Hancock?-'],
#  'Hancocks': ['on'],
#  'board.Yes': ['sir,'],
#  'sir,': ['Mr.'],
#  'Thank': ['you.At', 'you.Ooh.'],
#  'you.At': ['the'],
#  'bottom': ['of'],
#  'list.Oh,': ['hell'],
#  'hell': ['nah.What', 'did', 'is', 'you'],
#  'nah.What': ['the'],
#  'fuck': ['do'],
#  'want?What,': ['I'],
#  'visit': ['me'],
#  'mate?Rekindle': ['the'],
#  'unbreakable': ['bondsof'],
#  'bondsof': ['brothers-in-arms?-'],
#  'brothers-in-arms?-': ['Nope.-'],
#  'Nope.-': ['Come'],
#  'Come': ['on,', 'on', 'on.I', 'on!-'],
#  'M.M.Bring': ['it'],
#  'in.Look,': ['if'],
#  'if': ["it's",
#   'you',
#   'you',
#   'people',
#   "something'shappened",
#   'I',
#   'you',
#   'I',
#   'we',
#   "you've-you've...if",
#   'they',
#   'you',
#   'you',
#   'you'],
#  "same,let's": ['just'],
#  'small': ['talk.All'],
#  'talk.All': ["you're"],
#  'lieand': ['say'],
#  'say': ['how', 'is,"Gee,', "lightningdoesn't", "that?I'm"],
#  'fine,and': ["I'm"],
#  'lie': ['and'],
#  'pretendlike': ["I'm"],
#  'happy': ['to', 'man', 'boy', 'boy?A'],
#  'see': ['you.Why',
#   'youtomorrow',
#   'a',
#   'you,but',
#   'about',
#   'that',
#   'one.And',
#   'through?-'],
#  'you.Why': ['are'],
#  'here?All': ['right.-'],
#  'right.-': ["How'd", "Where's"],
#  "How'd": ['you'],
#  'come': ['back,',
#   'out',
#   'on,you',
#   'back',
#   'out',
#   'here,',
#   'on.You',
#   'in.You'],
#  'back,': ['have', "we're"],
#  'another': ['go?-', 'truckon'],
#  'go?-': ['Mm-mm.No,'],
#  'Mm-mm.No,': ['sir.'],
#  'sir.': ['Keep'],
#  'Keep': ['it'],
#  'yourself.I': ["don't"],
#  'nothingabout': ["nothing.I'm"],
#  "nothing.I'm": ['a'],
#  'now.Life': ['is'],
#  'good,-': ['Monique'],
#  'Monique': ['is'],
#  'just...-': ['Oh,', 'Now,'],
#  'Oh,': ['yeah?', 'well,', 'sure.-'],
#  'yeah?': ['How'],
#  'Monique?Spits': ['on'],
#  'groundevery': ['time'],
#  'time': ['your', 'is'],
#  'comes': ['up.I', 'with', 'the', 'Shockwave.You'],
#  'up.I': ["can't"],
#  'thatto': ['her', "Mallory's"],
#  'again,': ['man.Not'],
#  'man.Not': ['to'],
#  'mention,': ["I'm"],
#  'actuallymaking': ['progress'],
#  'progress': ['with'],
#  'these': ['boys.Yeah,', 'things.According'],
#  'boys.Yeah,': ['so'],
#  "see.Don't": ['make'],
#  'make': ['me', 'a', 'it...', 'up,', 'an', 'this', 'some'],
#  'there!Well,': ['this'],
#  "God's": ['work.I'],
#  'work.I': ["can't"],
#  'argue': ['with'],
#  'that.But': ['a'],
#  'talents?-': ['Wasted'],
#  'Wasted': ['here.-'],
#  'here.-': ['Look,', 'Excuse'],
#  'Look,': ['Butcher,we', 'all'],
#  'Butcher,we': ['were'],
#  'were': ['into', 'good', 'talkingabout', 'just'],
#  'into': ['some', 'pieces.And-and'],
#  'bad': ['shit,'],
#  'shit,': ['man.Even'],
#  'man.Even': ['before'],
#  'before': ['the', 'the', 'they'],
#  'Mallory': ['stuff.And', "shitain't"],
#  'stuff.And': ['that,'],
#  'was...If': ["I'm"],
#  'difference,I': ['just'],
#  'feel': ['more'],
#  'more': ['comfortabledoing',
#   'American',
#   'importantthan',
#   'time.-',
#   'exotic.-'],
#  'comfortabledoing': ['it'],
#  'smaller': ["scale.I'm"],
#  "scale.I'm": ['a'],
#  'motherfucker': ['with'],
#  'heart.Whereas': ["you?You're"],
#  "you?You're": ['just'],
#  'motherfucker.Funny': ['you'],
#  'should': ['mentionmaking', 'get', 'probably', 'come'],
#  'mentionmaking': ['a'],
#  "difference......'cause": ['we'],
#  'dusted': ['a', 'the'],
#  'Supe.Bullshit.Translucent.What': ['the'],
#  'f...Well,': ['come'],
#  'on,you': ['lime-sucking'],
#  'lime-sucking': ['smart-ass.How'],
#  'smart-ass.How': ['the'],
#  'it?Well...Big': ['lump'],
#  'lump': ['of'],
#  'C-4,packed': ['right'],
#  'fudger.Boom.': ['Claret'],
#  'Claret': ['everywhere,fucking'],
#  'everywhere,fucking': ['diabolical.But'],
#  'diabolical.But': ['before'],
#  'fireworks,he': ['coughed'],
#  'coughed': ['up'],
#  'solid': ['lead.Spilled'],
#  'lead.Spilled': ['the'],
#  'beans': ['in'],
#  'big': ['way.Now,', 'black', 'fans.'],
#  'way.Now,': ['we'],
#  'play': ['this'],
#  'right,we': ['could'],
#  'shake': ['upthe'],
#  'upthe': ['whole'],
#  'whole': ["hornets'", 'building.-', 'world.-'],
#  "hornets'": ['nest,bring'],
#  'nest,bring': ['down'],
#  'Sevenand': ['Vought'],
#  'Vought': ['at'],
#  'same': ['time.Mm-hmm.You'],
#  'time.Mm-hmm.You': ['mean'],
#  'mean': ['do', 'to'],
#  'Homelander?This': ['is'],
#  'Becca,': ["isn't"],
#  "it?It's": ['always'],
#  'Beccawith': ['you.Oh,'],
#  'you.Oh,': ['you'],
#  "ain't": ['got', 'seen', 'exactly', 'twiggedthe', 'here'],
#  "reasons?It'll": ['be'],
#  'different': ['this'],
#  'go,all': ['right?None'],
#  'right?None': ['of'],
#  'that"secrets': ['and'],
#  'lies"': ['bollocks.And'],
#  'bollocks.And': ['that'],
#  "shitain't": ['gonna'],
#  'happen': ['this'],
#  'time.I': ['swear'],
#  'swear': ['to'],
#  'God.Are': ['you'],
#  'bringing': ['Frenchie', 'the'],
#  'Frenchie': ["back?'Cause"],
#  "back?'Cause": ['I'],
#  'workwith': ['that'],
#  'motherfucker.Frenchie?No,': ['I'],
#  'seen': ['him'],
#  'years.M.M.,': ["you're"],
#  'only': ['blokeI', 'onewho', 'beone'],
#  'blokeI': ['can'],
#  'trust.Since': ['whenhave'],
#  'whenhave': ['you'],
#  'ever': ['trusted', 'said', 'break', 'really'],
#  'trusted': ['anybody?Oh,'],
#  'anybody?Oh,': ['fuck.Senator'],
#  'fuck.Senator': ["Calhoun,you've"],
#  "Calhoun,you've": ['gone'],
#  'gone': ['on'],
#  'record-': ['against'],
#  'against': ['superheroes'],
#  'superheroes': ['in'],
#  'military.-': ["Who's"],
#  "Who's": ['a', 'a'],
#  'boy?-': ["Who's", 'Why'],
#  'Why': ['change', 'are', 'do'],
#  'change': ['your'],
#  'tune?No': ["one's"],
#  "one's": ['changing'],
#  'changing': ['their'],
#  'their': ['tune.Uh,', 'fingersand'],
#  'tune.Uh,': ["it's"],
#  'realized': ["thatit's"],
#  "thatit's": ['an'],
#  'an': ['issue',
#   'agreement',
#   'appointment.-',
#   'overpriced',
#   'hour.Come',
#   'eye',
#   'understanding.Stop!'],
#  'issue': ['that'],
#  'affects': ['all'],
#  'Americans.-': ["Can't"],
#  "Can't": ['you'],
#  'it...': ['stop?-'],
#  'stop?-': ['It'],
#  'It': ["shouldn't", 'is', 'was', 'was'],
#  "shouldn't": ['be'],
#  'decided': ['by'],
#  'few': ['congressmen-', 'days'],
#  'congressmen-': ['hidden'],
#  'hidden': ['in'],
#  'committee.-': ["He's"],
#  'crying.The': ['bill'],
#  'bill': ['needs'],
#  'needs': ['to'],
#  'goto': ['the'],
#  'floor.Oh,': ['okay.Aw.'],
#  'okay.Aw.': ['Aw.Oh,'],
#  'Aw.Oh,': ['no.'],
#  'We': ["can't", 'had'],
#  'that...You': ['know,'],
#  'know,': ['I', 'we', 'mate.Maybe', 'if', 'before', 'get...Would'],
#  'heard': ["Translucent'stracking"],
#  "Translucent'stracking": ['chip'],
#  'chip': ['went'],
#  'went': ['dead.-'],
#  'dead.-': ['Yeah?-'],
#  'Yeah?-': ['He'],
#  'He': ['could', "can't"],
#  "hurt.How?He's": ['got'],
#  'diamond': ["skin.He's"],
#  "skin.He's": ['gonna'],
#  'fine.My': ['guys'],
#  'guys': ['are', 'need'],
#  'it.All': ['right,I'],
#  'right,I': ['forgot'],
#  'forgot': ['to', 'to'],
#  'give': ['you', 'the'],
#  'these.Here.What': ['is'],
#  'it?Those': ['areyour'],
#  'areyour': ['new'],
#  'new': ['talking',
#   'lad.',
#   'router.',
#   'talking',
#   'one.Hey,',
#   'outfit!Annie?',
#   'young',
#   'world'],
#  'talking': ['points.Now',
#   'points.You',
#   "about?I've",
#   'about!-',
#   "about?You're"],
#  'points.Now': ['that'],
#  'military': ['billis'],
#  'billis': ['out'],
#  'committee,corporate': ['wantsto'],
#  'wantsto': ['sell'],
#  'sell': ['the', 'my'],
#  'shit': ['out', 'A-Train'],
#  'it.Yes.': ['They'],
#  'They': ['do.Hey.'],
#  'do.Hey.': ['Y-You'],
#  'Y-You': ['remember'],
#  'remember': ['whenyou'],
#  'whenyou': ['wanted'],
#  'wanted': ['me', 'to...you'],
#  'red': ['capeand-and', 'tapeand', 'caseover'],
#  'capeand-and': ['I'],
#  'said,"No.': ['No,'],
#  'no,': ['no.Make', 'wait.', 'not'],
#  'no.Make': ['it'],
#  'flag"?Remember': ['that?-'],
#  'that?-': ['Uh-huh.-'],
#  'Uh-huh.-': ['Yeah.'],
#  'these.Okay?I': ['can'],
#  'wayinto': ['the'],
#  'military.Thank': ['you.You'],
#  'you.You': ['take', 'gonna'],
#  'baby,and': ["I'll"],
#  'mine.Mr.': ['Edgar'],
#  'Edgar': ['wrotethose'],
#  'wrotethose': ['personally.So'],
#  'personally.So': ['if'],
#  '82and': ['take'],
#  'him,be': ['my'],
#  'guest.Oh,': ['yes.Oh,'],
#  'yes.Oh,': ["you're"],
#  'boy': ['now,'],
#  'huh?Are': ['you'],
#  'boy?A': ['rental,'],
#  'rental,': ['you'],
#  'cheap': ['bastard?Who', 'bastard.You'],
#  'bastard?Who': ['do'],
#  'think': ['I', 'a', 'herand', 'it', 'I', 'they', 'she', 'we'],
#  'am,some': ['double-O'],
#  'double-O': ['wanker?In'],
#  'wanker?In': ['case'],
#  'case': ['you'],
#  "hadn't": ['noticed,we'],
#  'noticed,we': ["ain't"],
#  'rolling': ['in'],
#  'it.And': ['you'],
#  'thinkthis': ['is'],
#  'conspicuous?Conspicuous?': ['No,'],
#  "thinkit's": ['conspicuous.I'],
#  'conspicuous.I': ['think'],
#  'black': ['vanwith'],
#  'vanwith': ['fucking'],
#  '"Flowers"on': ['the'],
#  'conspicuous.This': ['is'],
#  'truckon': ['the'],
#  'street.Bang': ['on'],
#  'time.Uh,': ['hi.Hughie.Smelly'],
#  'hi.Hughie.Smelly': ['motherfucker.-'],
#  'motherfucker.-': ['Butcher,'],
#  'Butcher,': ['who'],
#  'who': ['is', 'I'],
#  'guy?!-': ["You'll"],
#  "You'll": ['give'],
#  'game': ['away!Not'],
#  'away!Not': ['until'],
#  'until': ['this', "we're"],
#  'frog': ["getswhat's"],
#  "getswhat's": ['coming.Only'],
#  'coming.Only': ['thing'],
#  'thing': ['that'],
#  'coming-': ['is'],
#  "mother's": ['titties!-'],
#  'titties!-': ['Let'],
#  'him,': ['bitch!-'],
#  'bitch!-': ['Hey!-'],
#  'Hey!-': ['We'],
#  'had': ['an', 'the', 'a'],
#  'agreement': ['about'],
#  'him.We': ['agreed'],
#  'agreed': ['to'],
#  'put': ['a', 'it?Oh,'],
#  'pin': ['in'],
#  'it,all': ['right?-'],
#  'right?-': ['What', "That's"],
#  'agreement?-': ['There'],
#  'There': ['was'],
#  'pin.I': ["don't"],
#  'trust': ['this'],
#  'French': ['whore.I', 'whoreand'],
#  'whore.I': ['am'],
#  'American': ['than'],
#  'than': ['you,you', '20'],
#  'you,you': ['racist'],
#  'racist': ['piece'],
#  'piece': ['of'],
#  'shit!-': ['Why'],
#  'they': ['fighting?!-',
#   'snap',
#   'sign',
#   'reallywant',
#   'just',
#   'senda',
#   'all',
#   'even',
#   'were'],
#  'fighting?!-': ['Nothing.'],
#  'Nothing.': ['It'],
#  'water': ['under'],
#  'under': ['the', 'control.'],
#  'bridge.You': ['tell'],
#  "Mallory's": ['grandkids.Tell'],
#  'grandkids.Tell': ['them'],
#  'them': ["it's"],
#  'waterunder': ['the'],
#  'bridge.-': ['That'],
#  'That': ["wasn't"],
#  "wasn't": ['my', 'getting'],
#  'fault,': ['huh?-'],
#  'huh?-': ['Who'],
#  'Who': ['is'],
#  'Mallory?All': ['right,'],
#  'you,knock': ['it'],
#  'head,': ['now!Shit!Hey,'],
#  'now!Shit!Hey,': ['Monique.How'],
#  'Monique.How': ['you'],
#  'doing,': ['baby?Ooh,'],
#  'baby?Ooh,': ['I'],
#  'marinadethe': ['tilapia.I'],
#  'tilapia.I': ['am'],
#  'sorry,': ['sweetheart.Okay,'],
#  'sweetheart.Okay,': ['how'],
#  "'bout": ['this?How'],
#  'this?How': ['about,on'],
#  'about,on': ['my'],
#  'way': ['home', 'of'],
#  'home': ['from', 'serviceis'],
#  'work,I': ['stop'],
#  "DeLuca's,pick": ['up'],
#  'two': ['fat', 'knobberskiss', 'days?', 'equals'],
#  'fat': ['tenderloins,some'],
#  'tenderloins,some': ['portobello'],
#  'portobello': ['mushrooms,'],
#  'mushrooms,': ['thatpinot'],
#  'thatpinot': ['that'],
#  'much.Yeah,': ['baby.Okay,'],
#  'baby.Okay,': ['I-I'],
#  'I-I': ['got'],
#  'go.All': ['right,'],
#  'sweetheart.Yeah.': ['Me,'],
#  'Me,': ['too.Baby,'],
#  'too.Baby,': ['I'],
#  'just...Uh,': ["you're"],
#  'right.I': ['love', "don't"],
#  'too.Okay.': ['Bye.Fuck'],
#  'Bye.Fuck': ['all'],
#  "y'all,": ['okay?All'],
#  'okay?All': ['right.'],
#  'right.': ['All', 'Sit'],
#  'All': ['right.Listen,', 'right,', 'right.Introducingthe'],
#  'right.Listen,': ['you'],
#  'knobberskiss': ['and'],
#  'up,': ['yeah?We'],
#  'yeah?We': ['got'],
#  'job': ['to', 'makes'],
#  'do.Fuck': ['it.'],
#  'it.': ['Dégage,'],
#  'Dégage,': ['huh?Get'],
#  'huh?Get': ['out'],
#  "here.Who's": ['this'],
#  'guy?The': ['new'],
#  'lad.': ['Hughie.Hughie,'],
#  'Hughie.Hughie,': ["Mother's"],
#  "Mother's": ["Milk.That's"],
#  "Milk.That's": ['a...'],
#  'a...': ['nickname?No,'],
#  'nickname?No,': ['my'],
#  'mother': ['actually'],
#  'actually': ['named', 'needto', 'kind', 'shortfor,'],
#  'named': ["meMother's"],
#  "meMother's": ['Milk.-'],
#  'Milk.-': ['Did-did'],
#  'Did-did': ['she?-'],
#  'she?-': ['So'],
#  'gota': ['French'],
#  'whoreand': ['a'],
#  'Stephen': ['fucking'],
#  'Hawking.-': ['Great'],
#  'Great': ['job,'],
#  'job,': ['Butcher.-', 'you'],
#  'Butcher.-': ['Well,'],
#  'Well,': ['it', 'whatever'],
#  'wasStephen': ['fucking'],
#  'Hawkingwho': ['dusted'],
#  "Supe.Oh.She's": ["home.That's"],
#  "home.That's": ['Popclaw,'],
#  'Popclaw,': ["right?A-Train's"],
#  "right?A-Train's": ['girlfriend?Oh,'],
#  'girlfriend?Oh,': ['Popclaw.'],
#  'Popclaw.': ['Hi.Uh,'],
#  'Hi.Uh,': ['you'],
#  'the-the': ['rent?-'],
#  'rent?-': ['It'],
#  'due': ['last'],
#  'last': ['week.-', 'time?Last', 'thingI', 'thingthat'],
#  'week.-': ['Right.'],
#  'Right.': ['Of'],
#  'Of': ['course.You'],
#  'course.You': ['think'],
#  'herand': ['A-Train'],
#  'uh...Yeah,': ['playing'],
#  'playing': ['bury'],
#  'bury': ['the'],
#  "bishop.Didn't": ['hear'],
#  'hear': ['nothing', 'it'],
#  'nothing': ['about', 'to'],
#  "it.I'm": ['usually'],
#  'usually': ['up'],
#  'things.According': ['to'],
#  'Translucent,A-Train': ['knows'],
#  'knows': ['this'],
#  'birdinside': ["out.I'll"],
#  "out.I'll": ['drop'],
#  'drop': ['the'],
#  'check': ['off', 'in'],
#  'off': ['ASAP.-', 'to'],
#  'ASAP.-': ['Okay.-'],
#  'Okay.-': ['Mm-hmm.-', 'Do', 'Mm-hmm.Like'],
#  'Mm-hmm.-': ['Yeah.-'],
#  'Yeah.-': ["'Kay.All", "That's"],
#  "'Kay.All": ["right.Let's"],
#  "right.Let's": ['get'],
#  'bugs': ['sorted,see'],
#  'sorted,see': ['for'],
#  "ourselves.Where-Where'd": ['you'],
#  'shit,Circuit': ['City?Right?'],
#  'City?Right?': ["He's"],
#  'bastard.You': ['know,'],
#  'needto': ['sneak', 'sign'],
#  'sneak': ['in'],
#  'anything.-': ['Eh?-'],
#  'Eh?-': ['Look,'],
#  "need's": ['her'],
#  'IPv6': ['number.Every'],
#  'number.Every': ['desktop,'],
#  'desktop,': ['every'],
#  'every': ['smart', 'room.-'],
#  'smart': ['TVin', 'lad,but'],
#  'TVin': ['the'],
#  'house': ['has', 'call?-'],
#  'has': ['a', 'caught'],
#  'camera': ['on'],
#  'it.They': ['probably'],
#  'probably': ['have', 'get'],
#  'onein': ['every'],
#  'room.-': ['Even'],
#  'Even': ['in'],
#  'toilet?-': ['No,'],
#  'Frenchie,not': ['in'],
#  'toilet.': ['Look,I'],
#  'Look,I': ['just'],
#  'five': ['minutes'],
#  'minutes': ['inside.I'],
#  'inside.I': ['mean,'],
#  'serviceis': ['my'],
#  'specialty.Hello,': ["ma'am,we're"],
#  ...}

# %% [markdown]
# This code is a function that generates a sentence of a given length using a Markov chain. The Markov chain is passed as an argument to the function, and it is stored in the variable "chain". The function uses the defaultdict from the collections module to handle any missing keys gracefully. It then chooses the first word randomly from the list of keys in the chain, capitalizes it, and adds it to the sentence. It then iterates through each subsequent word in the sentence, choosing it randomly based on its frequency in the chain. Finally, it ends the sentence with appropriate punctuation.

# %%
import random
from collections import defaultdict

def generate_sentence(chain, count=15):
    if not chain:
        return "Cannot generate a sentence from an empty dictionary"

    # Use defaultdict to handle missing keys gracefully
    chain = defaultdict(list, chain)

    # Choose the first word randomly
    word1 = random.choice(list(chain.keys()))

    # Capitalize the first word
    sentence = word1.capitalize()

    # Generate subsequent words until the sentence has the desired length
    for i in range(count-1):
        # Choose the next word randomly based on its frequency in the chain
        word2 = random.choices(chain[word1], weights=[chain[word1].count(w) for w in chain[word1]])[0]

        # Add the word to the sentence
        sentence += ' ' + word2

        # Update the current word
        word1 = word2

        # End the sentence with appropriate punctuation
        if i == count-2:
            sentence += random.choice(['.', '!', '?'])

    return sentence

# %% [markdown]
# Yes, here's a brief explanation of why the updated implementation of the generate_sentence function is better:
#
# Checks for an empty dictionary: The updated implementation checks if the input dictionary is empty and returns an appropriate message to the user. This makes the function more robust and prevents it from raising an error if the input is invalid.
#
# Uses defaultdict: The updated implementation uses a defaultdict to handle missing keys in the input dictionary. This makes the function more robust by ensuring that it will not raise a KeyError if a word is not present in the dictionary.
#
# Handles punctuation: The updated implementation handles punctuation more gracefully by adding the appropriate punctuation mark at the end of the sentence. This makes the generated sentences more grammatically correct and natural.
#
# Improves randomness: The updated implementation uses random.choices to choose the next word based on its frequency in the chain. This makes the function more diverse by ensuring that less common words are chosen more often, and makes the generated sentences less repetitive.
#
# Overall, these improvements make the function more robust, natural-sounding, and diverse, resulting in better-generated sentences.

# %%
generate_sentence(jim_dict)
# Out:
# "Point and Evan from marketing.- Hi.They have that...- I'm messing with Stillwell.Look, our checks.Can we."

# %%
generate_sentence(bill_dict)
# Out:
# 'Somebodyto go in the flight pathoff the other time.Well, uh, you know, baby.Please,tell me who!'

# %%
eric_text = data.transcript.loc['s1e7']
eric_text[:200]

eric_dict = markov_chain(eric_text)
eric_dict
# Out:
# {'Ho,': ['ho,'],
#  'ho,': ['ho!'],
#  'ho!': ['Merry'],
#  'Merry': ["Christmas!Who's"],
#  "Christmas!Who's": ['been'],
#  'been': ['naughty?-',
#   'great.But',
#   'helping',
#   'sneaking',
#   'following',
#   'thinkingabout',
#   'stupidto',
#   'up',
#   'raisedin',
#   'feedingthe',
#   'using'],
#  'naughty?-': ['It'],
#  'It': ['is', "doesn't", "wasn't"],
#  'is': ['dead',
#   'my',
#   'all',
#   'a',
#   'notas',
#   'just',
#   'killing',
#   'getting',
#   'fair',
#   'Hughie',
#   'this',
#   'Hugh',
#   'insane.Starlight,',
#   'not',
#   'true,',
#   'just',
#   'next,',
#   'fuckingplaying',
#   'he',
#   "burned.They've",
#   'he?-',
#   'this',
#   'that?I',
#   'it?You',
#   'the',
#   'gone',
#   'this,',
#   'beautiful.Thank',
#   'about',
#   "Mallory.I'm",
#   'worse,',
#   'gonna',
#   'tenacious.The',
#   'my',
#   'fair',
#   'dead.And',
#   'going',
#   'that',
#   'always',
#   'so',
#   'about'],
#  'dead': ['center', 'womanwho', 'before'],
#  'center': ['on'],
#  'on': ['your',
#   'your',
#   'fucking',
#   'a',
#   'purpose.So',
#   'a',
#   'the',
#   'youback',
#   'a',
#   'you.You',
#   'the',
#   'itany'],
#  'your': ['brand.-',
#   '"A"',
#   'nametag.Yes,',
#   'place?Well,',
#   'place,or',
#   "job.You're",
#   'per',
#   'eyeon',
#   'sides,',
#   'fucking',
#   'responsibility',
#   'sakes.Class',
#   'dick.-',
#   'baby',
#   'ass',
#   'girlfriend.-',
#   'sleeve.Okay.',
#   'girlfriend.You',
#   'toys?-',
#   'wife.I',
#   'good',
#   'head',
#   'name,',
#   'uncle,',
#   'way,even',
#   'child.Pregnant?Wh...But',
#   'corporationare',
#   'superheroesare',
#   'capes.-',
#   'cutelittle',
#   'help.Yeah.'],
#  'brand.-': ['Mm-hmm.-'],
#  'Mm-hmm.-': ["Let's"],
#  "Let's": ['get', 'get'],
#  'get': ['a',
#   'the',
#   'enoughof',
#   '$75',
#   'out',
#   'this,leave',
#   'burned?Mesmer.',
#   'it.Everything',
#   'Maria',
#   'up',
#   'you',
#   'away,start',
#   'you',
#   'the',
#   'a',
#   'it.Jamming',
#   'down!What',
#   'back'],
#  'a': ['picture.-',
#   'little',
#   'cigar',
#   '"but"',
#   'hotel?Hmm?',
#   'mystery',
#   'nice',
#   'red',
#   'hero',
#   'couple',
#   'day.Grocery',
#   'Dairy',
#   'shitholelike',
#   'fuckingfaster',
#   'freak',
#   'seat,',
#   'little',
#   'joke?Why',
#   'man,',
#   'different',
#   'little',
#   'shit',
#   'shit',
#   'compellingfucking',
#   'few',
#   'fucking',
#   'choice.She',
#   'fewflying',
#   'dead',
#   'lot',
#   'fucking',
#   'whiff,a',
#   'second.She',
#   'fan!You',
#   'fan,',
#   'dabbler,',
#   'little',
#   'bigger',
#   'real',
#   'millisecond.-',
#   "kid.You're",
#   'name.And',
#   'name,',
#   'mistake.The',
#   'grown-ass',
#   'hug.',
#   'picture.You',
#   'sleepover.Can',
#   "mommy.I'm",
#   'water',
#   'good',
#   'little',
#   "daughter!No!Don't",
#   'few',
#   'fucking',
#   'family.So',
#   "deal.I'm",
#   'secure',
#   'few',
#   'hell',
#   'lad',
#   'plate,and',
#   'first.Eight',
#   'secure',
#   'boy?Does',
#   'perfect',
#   'home',
#   'familywho',
#   'cold',
#   'fucking',
#   'gun.-',
#   'human',
#   'deal.Everyone',
#   'good',
#   'shit,but',
#   'lovelyshade',
#   'bitchstill',
#   'Supe',
#   'murderer.We',
#   'choice.-',
#   'choice.-',
#   'long'],
#  'picture.-': ['I'],
#  'I': ['love',
#   'have',
#   'loved',
#   'wouldlove',
#   'just...Mm.',
#   "can't",
#   'mean,you',
#   'know',
#   'mean,everyone',
#   'got',
#   'missed',
#   'am',
#   'know',
#   "wasn't...It's",
#   'should',
#   'knowthat',
#   "didn't",
#   'say',
#   'mean...There',
#   "don't",
#   "can't.-",
#   'managed',
#   'think',
#   "don't",
#   'right?-',
#   'did',
#   'catch',
#   'got',
#   'hope',
#   'get',
#   "don't",
#   'got.Special',
#   'do',
#   'hand',
#   'kill',
#   'made',
#   'get',
#   "ain't",
#   "checked,you're",
#   'was',
#   'see?Oh,',
#   'supposed',
#   'just',
#   'was,',
#   'wasthinking',
#   "don't",
#   'said',
#   'can',
#   'have',
#   'had',
#   'say,',
#   'take',
#   "can't",
#   "don't",
#   'said.You',
#   'think',
#   'doing',
#   'thought',
#   "couldn't.So",
#   'raise',
#   'turned',
#   'thinkwhat',
#   "don't",
#   'get',
#   'hope?Someone',
#   'missing?Just',
#   'could'],
#  'love': ['pictures.Hey.Smile.Another', 'it'],
#  'pictures.Hey.Smile.Another': ['one.Oi,'],
#  'one.Oi,': ['gorgeous.-'],
#  'gorgeous.-': ['Vodka'],
#  'Vodka': ['soda,'],
#  'soda,': ['hold'],
#  'hold': ['the', 'on', 'on.To'],
#  'the': ['soda.-',
#   "food's",
#   'sound',
#   'work.She',
#   'experts.Listen,',
#   'fuck',
#   'fuck',
#   'hotelis',
#   'localbranch',
#   'whole',
#   'street.To',
#   'best',
#   'board.Not',
#   'doc.Your',
#   'basics.Nobody',
#   'rest',
#   'ball,',
#   'gates.I',
#   'guyswho',
#   'looks',
#   'Deep.Whoa,',
#   'single',
#   'golden',
#   'last',
#   'guy.Hughie',
#   'work,is',
#   'rest',
#   'house',
#   'fuck',
#   'fuckis',
#   'fastest?If',
#   'fuck',
#   'V?-',
#   'B.A.',
#   'Pentagonis',
#   'low',
#   'baby',
#   'suit.Well,',
#   'flesh.I',
#   'fuck',
#   'personwho',
#   'same',
#   'phone...-',
#   'phone',
#   'Oriental',
#   "lab,I'll",
#   'lab.',
#   'old',
#   'sizeof',
#   'potential',
#   'table.A-And',
#   'baby?Lived',
#   'right',
#   "world's",
#   'phone',
#   'last',
#   'linethat',
#   'same',
#   'worst.What',
#   'U.S.',
#   "floor.They're",
#   'conceptfor',
#   'deal',
#   'governmentand',
#   'military,and',
#   'century.Vought',
#   'hell',
#   'problem?Watch.We',
#   'fuck',
#   'cops!',
#   'only',
#   'only',
#   'Supes',
#   'fuck',
#   'fuck'],
#  'soda.-': ['Thank'],
#  'Thank': ['you.Drinks', 'you.-'],
#  'you.Drinks': ['are'],
#  'are': ['free,but',
#   'getting',
#   'you',
#   'frozenand',
#   'askingall',
#   'we?How',
#   'you?My',
#   'these?',
#   'you',
#   'a',
#   'you',
#   'no',
#   'you',
#   'you'],
#  'free,but': ['the'],
#  "food's": ['bloody'],
#  'bloody': ['awful.Ahi'],
#  'awful.Ahi': ['tartare,'],
#  'tartare,': ['for'],
#  'for': ["fuck's",
#   'shit.That',
#   'you.All',
#   'you?-',
#   'a',
#   'theirs.That',
#   'yourself.Jings.Cold',
#   'Homelanderright',
#   'you?For',
#   '15',
#   'a',
#   'your'],
#  "fuck's": ['sakes.\n\n\nOkay.'],
#  'sakes.\n\n\nOkay.': ['Just'],
#  'Just': ['let', 'what?Fuck', 'listen'],
#  'let': ['me', 'us', 'him', 'anythingget'],
#  'me': ['shakea',
#   'out.W-What',
#   'wonder,which',
#   'a',
#   'before.Not',
#   "what's",
#   'a',
#   'and',
#   'to',
#   'one',
#   'about',
#   'Uncle',
#   'John',
#   'with',
#   'now?You',
#   'that',
#   'in,-'],
#  'shakea': ['few'],
#  'few': ['more', 'Mai', 'hundred', 'cards', 'daysafter', 'nights.No,'],
#  'more': ['hands,and', 'fucking', 'club', 'of'],
#  'hands,and': ['then'],
#  'then': ["we'll", 'you'],
#  "we'll": ['beout'],
#  'beout': ['of'],
#  'of': ['here...',
#   'that.-',
#   'stuff,so',
#   'my',
#   'here.-',
#   'a',
#   'pointless.And',
#   "A.We're",
#   'that',
#   'youhave',
#   'sorts.Erratic.Unreliable.Downright',
#   'you...It',
#   'the',
#   'yoursis',
#   "Popclaw's",
#   'it,not',
#   'one.But...',
#   'the',
#   'us',
#   'adrenalineand',
#   'us.Now,',
#   'trouble.Dad,',
#   'one',
#   'your-',
#   'these?Watch',
#   'Lockheed.-',
#   'these',
#   'a',
#   "yours.'Cause,",
#   'those?You',
#   'a',
#   'here.Just',
#   'theselobsters',
#   'a',
#   'fact,',
#   'her.The',
#   'ten',
#   'yourself.All',
#   'the',
#   'orange',
#   'Damascus.Right,',
#   'a',
#   'press.The'],
#  'here...': ['whoa.Easy,'],
#  'whoa.Easy,': ['tiger.I'],
#  'tiger.I': ['want'],
#  'want': ['you',
#   'to',
#   'to',
#   'to',
#   'her,',
#   'to',
#   'with',
#   'none,',
#   'to',
#   'to',
#   'anythingfrom',
#   'to',
#   'this',
#   'to'],
#  'you': ['on',
#   'know?-',
#   'handledmy',
#   'take',
#   'up',
#   'weresuch',
#   'bring',
#   'know.I',
#   'got',
#   'ina',
#   'want',
#   'know,',
#   'see',
#   'guys.Just',
#   'want',
#   'came',
#   'were',
#   'do',
#   'and',
#   'got',
#   'go.She',
#   "were.That's",
#   'got',
#   'gave',
#   "don't",
#   "ain't",
#   'a',
#   'wouldrecognize',
#   'okay?Oh,',
#   'understand',
#   'get',
#   'will!Hey,',
#   "don't?So",
#   "don't",
#   'can',
#   'take',
#   'try',
#   'kill',
#   'threw',
#   'and',
#   'didwas',
#   'were',
#   'been',
#   'a',
#   'help',
#   'and',
#   'rememberthat',
#   'mean,',
#   'knewwhat',
#   'are',
#   'go',
#   'here',
#   'should',
#   'little',
#   'like',
#   'know,',
#   'expect',
#   'find',
#   'met',
#   "payback.Who's",
#   'want',
#   'end',
#   "can't",
#   'out',
#   'blewthe',
#   'swore',
#   'and',
#   'go.Dr.',
#   'ever,',
#   'mindif',
#   "knewthat'd",
#   'tell',
#   'telling',
#   'can',
#   'want?What?What',
#   'want...',
#   'raised',
#   'again,Marvin.Come',
#   'want',
#   'okay?I',
#   'and',
#   'doto',
#   'want?-',
#   'go',
#   'telling',
#   'kill',
#   "haven't",
#   'doing?-',
#   'in.-',
#   'better-',
#   'bring',
#   'talking',
#   'thinking,coming'],
#  '"A"': ['game.-', 'game?-'],
#  'game.-': ['"A"'],
#  'game?-': ['Mm-hmm.You'],
#  'Mm-hmm.You': ['know,I'],
#  'know,I': ['like'],
#  'like': ['the',
#   'pancakes?-',
#   'you',
#   'Sandusky,',
#   'we',
#   'the',
#   'I',
#   'this?-',
#   'roller',
#   'that?-',
#   'gettingyour',
#   'you.-',
#   "this.I'm"],
#  'sound': ['of'],
#  'that.-': ['Yeah?-'],
#  'Yeah?-': ['Yeah.Merry', 'Fine.Annie.-'],
#  'Yeah.Merry': ['Christmas.Becca.New'],
#  'Christmas.Becca.New': ['senior'],
#  'senior': ['director,digital'],
#  'director,digital': ['marketing.-'],
#  'marketing.-': ['Uh,'],
#  'Uh,': ['yeah.', 'this'],
#  'yeah.': ['How', 'You'],
#  'How': ['did'],
#  'did': ['you',
#   'you',
#   'smashthrough',
#   'your',
#   'I',
#   'they',
#   'come',
#   'this,',
#   'you...?I',
#   'you',
#   'I.Apparently,',
#   'you'],
#  'know?-': ['I'],
#  'have': ['my',
#   'a',
#   'a',
#   'a',
#   'you',
#   'time',
#   'a',
#   'we',
#   'survived.She',
#   'been',
#   'my',
#   'to',
#   'to',
#   'been',
#   'a',
#   'a'],
#  'my': ['sources.And',
#   'husband,',
#   'photos,she',
#   'messages.It',
#   'social',
#   'attention,',
#   'Dadcould',
#   'dadwas',
#   'job.Um,',
#   'dad,but',
#   'own',
#   'last',
#   "age.I'm",
#   'bones,-',
#   'face.-',
#   'position......what',
#   'voice.You',
#   'God.Get',
#   'bank',
#   "kid.Dad.I'll",
#   'God,',
#   'life',
#   'fault,',
#   'goodness,this',
#   'God,',
#   'pinkie.No,',
#   'God.',
#   'guy.Oh,',
#   'family.And',
#   'subjects.Hmm.',
#   'fault.What',
#   'greatest',
#   'word.Thank',
#   'entire'],
#  'sources.And': ['your'],
#  'nametag.Yes,': ['that,'],
#  'that,': ['too.-'],
#  'too.-': ['Uh,'],
#  'this': ['is',
#   'would',
#   'is',
#   'is',
#   'shit,',
#   'a',
#   'guy?This',
#   'guy.You',
#   'guy?-',
#   'Hugh',
#   'anymore.-',
#   'about?-',
#   'shitmust',
#   'not',
#   'right',
#   'was',
#   'is',
#   "timeit's",
#   'is',
#   'way,',
#   'or',
#   'make',
#   'one,',
#   'is',
#   'drug.It,'],
#  'husband,': ['Billy.-'],
#  'Billy.-': ['Great'],
#  'Great': ['to'],
#  'to': ['meet',
#   'that',
#   'the',
#   'talk',
#   'youabout',
#   'meet',
#   'meet',
#   'behave.-',
#   "me.T-That's",
#   'understandthat',
#   'know',
#   'have',
#   'swim.-',
#   'know.And',
#   'the',
#   'go.-',
#   'seeyour',
#   'mean?It',
#   'saythat',
#   'keep',
#   "five.We're",
#   'you.-',
#   'this.Well,',
#   'see',
#   'makethis',
#   'go',
#   'you?Homelander,',
#   'add,',
#   'knowwhere',
#   'the',
#   'stop',
#   'kick',
#   'gomy',
#   'abouta',
#   'Epcot?',
#   'be',
#   'your',
#   'me.Oh,',
#   'go',
#   'Mesmer.Fuck',
#   'dear',
#   'go.-',
#   'go.You',
#   'meand',
#   'Jesus',
#   'flaming',
#   'pack',
#   'go.I',
#   'go.And',
#   'fire',
#   'know',
#   'her.No,',
#   'stay',
#   'do?It',
#   'talk',
#   'me.Wait,',
#   'talk,I',
#   'the',
#   'meet',
#   'you.-',
#   'see',
#   'gettoo',
#   'my',
#   'knowabout',
#   'Stillwellabout',
#   'me.So',
#   'her',
#   'sign',
#   'you,and',
#   'see',
#   'see',
#   'explain,',
#   'status',
#   'zero.The',
#   'a',
#   '30.Ms.',
#   'me.Listen',
#   'me,',
#   'stringyou'],
#  'meet': ['you.Billy', 'you,', 'you.Love', 'my', 'you.Billy'],
#  'you.Billy': ['Butcher.\n\n\nBecca,', 'Butcher.Oh,'],
#  'Butcher.\n\n\nBecca,': ['you'],
#  'handledmy': ['takeover,'],
#  'takeover,': ['right?Y-Yes,'],
#  'right?Y-Yes,': ['I-I'],
#  'I-I': ['did.-'],
#  'did.-': ['You', 'If'],
#  'You': ['saw',
#   'promised',
#   "don't",
#   'fucking',
#   'mean,',
#   'put',
#   'like',
#   'got',
#   'got',
#   'know'],
#  'saw': ['it?-'],
#  'it?-': ['I'],
#  'loved': ['it.-', 'you.Not'],
#  'it.-': ['U-Uh,', 'And,', "It's", 'Thanks.Oh,'],
#  'U-Uh,': ['wow.'],
#  'wow.': ['Thank'],
#  'you.-': ['No,', "What'd", 'What?-', "Nah.She's", 'Monique.Good', 'Never'],
#  'No,': ['thank', 'no,', "sir.I'm", 'fuck!-', 'I', 'no,'],
#  'thank': ['you.-'],
#  "What'd": ['you'],
#  'take': ['over?-', "it,you'll", 'one', 'the'],
#  'over?-': ["Vought's"],
#  "Vought's": ['Twitter'],
#  'Twitter': ['account.-'],
#  'account.-': ['Yeah.-'],
#  'Yeah.-': ['Your', 'Now,', "You're"],
#  'Your': ['brilliant'],
#  'brilliant': ['wife'],
#  'wife': ['heredid'],
#  'heredid': ['all'],
#  'all': ['the',
#   'thumbs',
#   'really',
#   'right.Yeah.Yeah,',
#   'in',
#   'startedwhen',
#   'the',
#   'about?-',
#   "right.You're",
#   'right.I',
#   'startwith',
#   'mine.Hello,',
#   'over',
#   'of',
#   'under'],
#  'work.She': ['posted'],
#  'posted': ['my'],
#  'photos,she': ['wrote'],
#  'wrote': ['my'],
#  'messages.It': ['was'],
#  'was': ['exceptional.All',
#   'you',
#   'really',
#   'gone,',
#   'all',
#   'helped?',
#   'fucking',
#   'not',
#   'an',
#   'fucking',
#   'drawing',
#   'suicide.Mm.Yeah,',
#   'just',
#   'Homelander.You',
#   'a',
#   'alone',
#   'pregnant.With',
#   'developingunnaturally',
#   'difficult.The',
#   'that?Is'],
#  'exceptional.All': ['right,'],
#  'right,': ['so', 'where', 'look,I', 'easy,'],
#  'so': ['they',
#   'I',
#   'better',
#   'much',
#   'fucked',
#   'ever',
#   'far?No,',
#   'hot',
#   'fucked.You',
#   'sorry.Annie.',
#   'sorry.Get'],
#  'they': ['thoughtit', 'make,', 'say?Come', 'get', "are.It's"],
#  'thoughtit': ['was'],
#  'up': ['there,but',
#   'against',
#   'there?I',
#   'to',
#   'your',
#   'to',
#   'to?-',
#   'to.Who',
#   'here?Oh,',
#   'for',
#   'with',
#   'for'],
#  'there,but': ['it'],
#  'it': ['was',
#   'to',
#   'is.-',
#   'out',
#   'back',
#   'all',
#   'out.Stop',
#   'over,then',
#   'was',
#   'seems',
#   'here.You',
#   'true',
#   'hurt.All',
#   'kill',
#   'is?I',
#   'been,',
#   'because',
#   'led',
#   'out...Oh,',
#   'a',
#   'matter?Why',
#   "doesn't",
#   'up.N...',
#   'all'],
#  'really': ['Becca.Bit',
#   'nice.-',
#   "should've",
#   'all',
#   'did',
#   "bulletproof.What's",
#   'notthat',
#   "sorry.I'm"],
#  'Becca.Bit': ['deceptive,'],
#  'deceptive,': ["isn't"],
#  "isn't": ['it?Uh,', 'it?Protect', 'about'],
#  'it?Uh,': ['no,'],
#  'no,': ['Billy,',
#   'no.You...',
#   'no.Seven,',
#   'no,',
#   'no,',
#   'no.Not',
#   'no.Wait,',
#   'I',
#   'no.'],
#  'Billy,': ["that's"],
#  "that's": ['what',
#   'enough.You',
#   'whatmakes',
#   'so',
#   'my',
#   'what',
#   'true.Seems',
#   'not'],
#  'what': ['we',
#   'aboutmy',
#   "you've",
#   "we're",
#   'thisis',
#   'I',
#   'that',
#   'about',
#   'they',
#   "I'm",
#   'happened?Well...Everyone',
#   'I',
#   'I',
#   'happenedwith',
#   'are',
#   'you'],
#  'we': ["do'cause",
#   'got',
#   'were',
#   "talk?That's",
#   "can't",
#   'couldorder',
#   'just,',
#   'care',
#   'got',
#   "don't",
#   'refuse?-'],
#  "do'cause": ["Homelander's"],
#  "Homelander's": ['busysaving'],
#  'busysaving': ["lives.It's"],
#  "lives.It's": ['okay,'],
#  'okay,': ["it's", 'I'],
#  "it's": ['okay.I-It...',
#   'gonna',
#   'worth',
#   'definitely',
#   'tender.',
#   'just',
#   'done',
#   'his...Supe'],
#  'okay.I-It...': ["you're"],
#  "you're": ["right.It's",
#   'gonnaregret',
#   'gonna',
#   'done,',
#   'too',
#   'right.It',
#   'pulling',
#   'just'],
#  "right.It's": ['a'],
#  'little': ['dishonest,but',
#   'heart-to-heart.A',
#   'tough',
#   'out',
#   'egg',
#   'rabbit.The',
#   'asshole',
#   'jet',
#   'fucking',
#   'fucking',
#   'bug'],
#  'dishonest,but': ["I'm"],
#  "I'm": ['all',
#   'sorry,',
#   'up',
#   'good.-',
#   "fucked.He's",
#   'gonna',
#   'gonna',
#   'sorry,I-I',
#   'just...',
#   'not',
#   'counting',
#   'really',
#   'sorry.I',
#   'not',
#   'taking',
#   'dead'],
#  'thumbs': ['whenit'],
#  'whenit': ['comes'],
#  'comes': ['to', "up,we'll"],
#  'that': ['kind',
#   'accent.Hello,',
#   'sweaty',
#   'the',
#   'shit.We',
#   'supposed',
#   'lately,some',
#   'is',
#   'it?You',
#   'working',
#   'shit',
#   'I',
#   'you',
#   'the',
#   'maybe,',
#   'shithole',
#   'Christmas',
#   'one.This',
#   'situationgot',
#   'would',
#   "much.I'm",
#   'clearer',
#   "doesn't",
#   'say?"Naqib."Hey!Freeze,',
#   'son',
#   'simple.And'],
#  'kind': ['of', 'of', 'of', 'of'],
#  'stuff,so': ['leave'],
#  'leave': ['it', 'her'],
#  'experts.Listen,': ['I'],
#  'wouldlove': ['to'],
#  'talk': ['to', 'to', 'to'],
#  'youabout': ['maybe'],
#  'maybe': ['quarterbackingthe', 'you'],
#  'quarterbackingthe': ['rest'],
#  'rest': ['of', 'of', 'of'],
#  'social': ['media.-'],
#  'media.-': ['Seriously?-'],
#  'Seriously?-': ['Absolutely.My'],
#  'Absolutely.My': ['dad,'],
#  'dad,': ['he'],
#  'he': ['always', 'walk', 'was', 'do', 'was', 'here?', 'got'],
#  'always': ['said,"Surround', "asks,what's", 'job', 'a'],
#  'said,"Surround': ['yourself'],
#  'yourself': ['with'],
#  'with': ['peoplesmarter',
#   'him.I',
#   'the',
#   "Kimiko,it's-it's",
#   'your',
#   'her.-',
#   'you?I',
#   'me.Now',
#   'himfor',
#   'me?-',
#   'anyof',
#   'quitean',
#   'a...completely',
#   'a',
#   'doctors.And',
#   'Mommy.All'],
#  'peoplesmarter': ['than'],
#  'than': ['you."Oh,', 'me.Then', 'The'],
#  'you."Oh,': ['my,'],
#  'my,': ['uh,'],
#  'uh,': ['better'],
#  'better': ['half', 'to'],
#  'half': ['is,', 'dozen,-', 'century,you'],
#  'is,': ['uh,wanting'],
#  'uh,wanting': ['my'],
#  'attention,': ['but'],
#  'but': ['maybewe', 'corny', 'words...-', 'hear', "you,you've", 'I', 'next'],
#  'maybewe': ['could'],
#  'could': ['chat', 'get', 'have', 'count'],
#  'chat': ['tomorrow.That'],
#  'tomorrow.That': ['sounds'],
#  'sounds': ['wonderful.Thank', 'amazing.But'],
#  'wonderful.Thank': ['you.Thank'],
#  'you.Thank': ['you.Greet'],
#  'you.Greet': ['to'],
#  'you,': ['pal.Good',
#   'but...I',
#   "Noir.You've",
#   'Hughie?Okay,',
#   'Hughie?The',
#   'baby.Janine,',
#   "John.I'm",
#   "okay?You're",
#   "Michaela.We're"],
#  'pal.Good': ['to'],
#  'you.Love': ['that'],
#  'accent.Hello,': ['beautiful.How'],
#  'beautiful.How': ['the'],
#  'fuck': ['does',
#   'out',
#   'up.Dad,',
#   'is',
#   'Edgar.We',
#   'you.No...What',
#   "off.I'm",
#   'are',
#   'does',
#   'away',
#   'were'],
#  'does': ['he', 'this', 'that'],
#  'walk': ['aroundin'],
#  'aroundin': ['that'],
#  'sweaty': ['fucking'],
#  'fucking': ['wetsuitall',
#   'way.You',
#   'around.Did',
#   'flies,but',
#   'this',
#   'breed.We',
#   'mouth,young',
#   'stupid.She',
#   'killer,',
#   'blindto',
#   "Medicaid.He's",
#   'piñata,do',
#   'worth',
#   'do',
#   'idiotshad',
#   'garbage.How',
#   'freak.Lay',
#   'freak.Oh,',
#   'gills',
#   'superhero.You',
#   'thing',
#   'friends,',
#   'apology.All',
#   'lab',
#   'move!I'],
#  'wetsuitall': ['day'],
#  'day': ['long,-', 'now.And'],
#  'long,-': ['balls'],
#  'balls': ['mashed'],
#  'mashed': ['up'],
#  'against': ['his', 'horses.At', 'us.-'],
#  'his': ['leg', 'girlfriend,so', 'name?No.', "mistakes.I'm"],
#  'leg': ['like'],
#  'pancakes?-': ['Oh,'],
#  'Oh,': ['shh.-',
#   'yeah.Ooh.',
#   'this',
#   'boy.That',
#   'God.Okay.',
#   'God.-',
#   'yeah.',
#   'God.Ow,',
#   'God.Having',
#   'damn'],
#  'shh.-': ['What?-'],
#  'What?-': ['You', 'Oh,'],
#  'promised': ['to', 'methings'],
#  'behave.-': ["Let's"],
#  'out': ['of',
#   'thereand',
#   'loud,all',
#   'of',
#   'a',
#   'for',
#   'of',
#   'great.When',
#   'Abu'],
#  'here.-': ['Yeah?Yeah.Hi.-'],
#  'Yeah?Yeah.Hi.-': ['Huh.-'],
#  'Huh.-': ['Hmm.I'],
#  'Hmm.I': ["didn't"],
#  "didn't": ['realize',
#   'do',
#   'know.Well,',
#   'kill',
#   'bring',
#   'you',
#   'have',
#   'ask'],
#  'realize': ['you'],
#  'weresuch': ['a'],
#  'cigar': ['aficionado.I'],
#  'aficionado.I': ['really,'],
#  'really,': ['I', 'what'],
#  'just...Mm.': ['I'],
#  "can't": ['get',
#   'do',
#   'help',
#   'remember',
#   'do',
#   'getin',
#   'come',
#   'cometo',
#   'cometo'],
#  'enoughof': ['huge'],
#  'huge': ['gross'],
#  'gross': ['logsof'],
#  'logsof': ['filterless'],
#  'filterless': ['tobacco.-'],
#  'tobacco.-': ['This'],
#  'This': ['is', 'cat', 'is'],
#  'nice.-': ['Mm-hmm.But...There'],
#  'Mm-hmm.But...There': ['is'],
#  '"but"': ['coming.Okay.But'],
#  'coming.Okay.But': ['why'],
#  'why': ['did', 'would', "don't", 'are'],
#  'bring': ['meto', "youHomelander's", 'me'],
#  'meto': ['a', 'get'],
#  'hotel?Hmm?': ['And'],
#  'And': ['not', 'if'],
#  'not': ['your',
#   'you,',
#   'a',
#   'a',
#   'even',
#   'capableof',
#   'gonna',
#   'Annie.-',
#   'ever.So',
#   'smart,to',
#   'gonna',
#   'leaving',
#   'all',
#   'safe',
#   'most',
#   'going',
#   'talk?Uh,',
#   'gonna',
#   'to',
#   'enough.When',
#   'gettoo',
#   'following.You',
#   'even',
#   'all.How',
#   'that'],
#  'place?Well,': ['you'],
#  'know.I': ['mean,'],
#  'mean,': ['yeah,',
#   'what',
#   "we're",
#   "we're",
#   'why',
#   'The',
#   'Vought,whatever',
#   'um,you',
#   'like',
#   'missing?I',
#   "it's...Yeah.",
#   'I',
#   'that'],
#  'yeah,': ['sure,', 'I', "here's"],
#  'sure,': ['my'],
#  'Dadcould': ['make'],
#  'make': ['yousome', 'my', 'me', 'this', 'sense.Just'],
#  'yousome': ['post-coital'],
#  'post-coital': ['pizza'],
#  'pizza': ['rolls.I'],
#  'rolls.I': ['just'],
#  'just': ['figured',
#   'tickled',
#   'a',
#   'a',
#   "can't",
#   "hopeyou're",
#   'want',
#   'a',
#   'wondering',
#   'assumedthat',
#   'my',
#   'need',
#   'please',
#   'breeding',
#   "ask.I'll",
#   'an',
#   'assholesrunning'],
#  'figured': ['this'],
#  'would': ['beslightly', 'he', 'you', 'it', 'be', 'be'],
#  'beslightly': ['less'],
#  'less': ['humiliating.Yeah,'],
#  'humiliating.Yeah,': ['all'],
#  'right.Yeah.Yeah,': ['very'],
#  'very': ['convincing.You', 'true.He'],
#  'convincing.You': ['okay?'],
#  'okay?': ["What's"],
#  "What's": ['going', 'this?-', 'going'],
#  'going': ["on?It's",
#   'on?-',
#   "steady.He's",
#   'on,but',
#   'anywhere,you',
#   'on.About'],
#  "on?It's": ["just...I've"],
#  "just...I've": ['never'],
#  'never': ['seen', 'do', 'seen', 'want', 'seen'],
#  'seen': ['your', 'me', 'herin'],
#  'place,or': ['your'],
#  "job.You're": ['kind'],
#  'mystery': ['to'],
#  "me.T-That's": ['hot,'],
#  'hot,': ['right?Look,'],
#  'right?Look,': ['you'],
#  'got': ['to',
#   'Cedar',
#   'a',
#   'to',
#   'rid',
#   'something',
#   "this.It's",
#   "her.She's",
#   'to',
#   'me.Oh,',
#   'it.All',
#   'this.Go.All',
#   'to',
#   'to',
#   'pretty',
#   'both.Mm-hmm.You',
#   'you',
#   'to',
#   'it.-',
#   'a',
#   'here,',
#   'cold',
#   'two.-',
#   'movement!-'],
#  'understandthat': ['my'],
#  'dadwas': ['nothing'],
#  'nothing': ['but', 'to'],
#  'corny': ['jokesand'],
#  'jokesand': ['expensive'],
#  'expensive': ['gifts,until'],
#  'gifts,until': ['he'],
#  'gone,': ['and'],
#  'and': ['allthe',
#   'stuff?You',
#   'Starlightare',
#   'God',
#   "stoneswon't",
#   "me,remember?Don't",
#   'call',
#   'not,like,',
#   'you',
#   'meis',
#   'me.This',
#   'you.You',
#   'for',
#   'Raynoror',
#   'mouse',
#   'me.You',
#   'your',
#   "why?I've"],
#  'allthe': ['money'],
#  'money': ['along'],
#  'along': ['with'],
#  'him.I': ['know'],
#  'know': ["thatthat's",
#   'that',
#   'this',
#   'shit',
#   'why.Uh...Why...Is',
#   'this',
#   "what's",
#   'anything,',
#   'what',
#   'his',
#   'what?That',
#   'what',
#   'what',
#   'this',
#   'me.I',
#   'you.-'],
#  "thatthat's": ['not'],
#  'but...I': ['need', 'was'],
#  'need': ['to', '3,000', 'a'],
#  'hotelis': ['a'],
#  'nice': ['thingand'],
#  'thingand': ['not'],
#  'red': ['flag', 'flags.Hmm.Now,'],
#  'flag': ['thing.I'],
#  'thing.I': ['quit'],
#  'quit': ['my'],
#  'job.Um,': ["I'm"],
#  'sorry,': ['I-I...I'],
#  'I-I...I': ['really'],
#  "should've": ['told'],
#  'told': ['you.After', 'her'],
#  'you.After': ['Robin,'],
#  'Robin,': ['programmingother'],
#  'programmingother': ["people's"],
#  "people's": ['remotes,it'],
#  'remotes,it': ['felt'],
#  'felt': ['kind', 'like'],
#  'pointless.And': ['yeah,'],
#  'mean,you': ['can-you'],
#  'can-you': ['can'],
#  'can': ['meet',
#   'we',
#   'do',
#   'do',
#   'catch',
#   'help',
#   'help',
#   'get',
#   'call',
#   'imagine',
#   'get',
#   'now'],
#  'dad,but': ["you're"],
#  'gonnaregret': ['asking'],
#  'asking': ['that.So'],
#  'that.So': ["everything's"],
#  "everything's": ["okay?It's"],
#  "okay?It's": ['great.No'],
#  'great.No': ['red'],
#  'flags.Hmm.Now,': ['I'],
#  'notas': ['swanky'],
#  'swanky': ['as'],
#  'as': ['New',
#   'blackmailingMesmer,',
#   'you',
#   'in',
#   "anyone's.It's",
#   'planned.So'],
#  'New': ['York'],
#  'York': ['City,but'],
#  'City,but': ['to'],
#  'hero': ['like'],
#  'ina': ['place'],
#  'place': ['like', 'is'],
#  'Sandusky,': ['I'],
#  'mean,everyone': ['down'],
#  'down': ['at', 'the', 'to', 'by'],
#  'at': ['the',
#   'my',
#   'least',
#   'this.Oh,',
#   'Lincoln',
#   'leasta',
#   'her',
#   'those',
#   'that',
#   'you,standing',
#   'the',
#   "A-Train?Y...You're"],
#  'localbranch': ['is'],
#  'tickled': ['pink.-'],
#  'pink.-': ['Yeah.-'],
#  'Now,': ['we'],
#  'Cedar': ['Point,biggest', "Point's"],
#  'Point,biggest': ['roller-coaster'],
#  'roller-coaster': ['parkin'],
#  'parkin': ['the'],
#  'whole': ['U.S.', 'Deep', 'lifewithout', 'fucking'],
#  'U.S.': ['of', 'Armed'],
#  "A.We're": ['just'],
#  'couple': ['short'],
#  'short': ['hoursfrom'],
#  'hoursfrom': ['Cleveland'],
#  'Cleveland': ['or'],
#  'or': ['Toledo.And', 'other.I-I', 'knowing', 'another,', 'not?Annie,'],
#  'Toledo.And': ['Lake'],
#  'Lake': ['Erie?'],
#  'Erie?': ['Right'],
#  'Right': ['here,-'],
#  'here,-': ['if'],
#  'if': ['you',
#   'something',
#   'he',
#   'I',
#   "he's",
#   'I',
#   'you',
#   'you...if',
#   "it'syour",
#   'something',
#   'we'],
#  'swim.-': ['Oh,'],
#  'yeah.Ooh.': ['Uh...There'],
#  'Uh...There': ['it'],
#  'is.-': ["What's"],
#  'this?-': ["That's", 'Jonesing', 'Do'],
#  "That's": ['your'],
#  'per': ['diem.You'],
#  'diem.You': ['get'],
#  '$75': ['a'],
#  'day.Grocery': ['store,right'],
#  'store,right': ['down'],
#  'street.To': ['make'],
#  'own': ["food?There's", 'fucking'],
#  "food?There's": ['a'],
#  'Dairy': ['Queen,'],
#  'Queen,': ['too.Like'],
#  'too.Like': ['Blizzards'],
#  'Blizzards': ['and'],
#  'stuff?You': ['betcha.Well...I'],
#  'betcha.Well...I': ['mean,'],
#  'aboutmy': ['crime'],
#  'crime': ['itinerary?I', 'in'],
#  'itinerary?I': ['think'],
#  'think': ['the', "I'm", 'it', 'maybe', 'she', 'it'],
#  'best': ["thing's"],
#  "thing's": ['justto,'],
#  'justto,': ['you'],
#  'know,': ['get',
#   'I',
#   "I've",
#   'real',
#   'he...Right',
#   'this',
#   "you're",
#   'I',
#   'I',
#   'fuck',
#   'I'],
#  'thereand': ['put'],
#  'put': ['some', 'her', 'us'],
#  'some': ['pointson', 'kind'],
#  'pointson': ['the'],
#  'board.Not': ['much'],
#  'much': ['crime', 'of', 'time'],
#  'in': ['Sandusky.I',
#   'my',
#   'to',
#   'my',
#   'danger,and',
#   'danger',
#   'missing,presumed',
#   'and...catch',
#   'the',
#   'your',
#   'on',
#   'its',
#   'a',
#   'your'],
#  'Sandusky.I': ['mean,'],
#  "we're": ['not', 'not', 'down', 'doing,innit?No,', 'running', 'gonna', 'the'],
#  'shitholelike': ['Akron.But'],
#  'Akron.But': ['if'],
#  'something': ['comes', 'to', 'special.Hmm?I', 'happensto'],
#  "up,we'll": ["call.You'll"],
#  "call.You'll": ['call?-'],
#  'call?-': ['Absolutely.-'],
#  'Absolutely.-': ['Okay.-'],
#  'Okay.-': ['Oh,'],
#  'killing': ['me.-', 'you.Hey.'],
#  'me.-': ['Come', 'Well,'],
#  'Come': ['on.Damn.Oh,', 'on,'],
#  'on.Damn.Oh,': ['no'],
#  'no': ['fucking', 'more', 'secrets', 'talk.You', 'superheroesin'],
#  'way.You': ['need'],
#  '3,000': ['calories'],
#  'calories': ['an'],
#  'an': ['hour,or', 'asshole,just', 'accident.-', "NDA.Couldn't", 'old'],
#  'hour,or': ["you're"],
#  'gonna': ['pass',
#   'be',
#   'tell',
#   'burst',
#   'fucking',
#   'be',
#   'bea',
#   'love',
#   'get',
#   'get',
#   'let',
#   "beMallory's",
#   'be',
#   'be',
#   'be',
#   'vote',
#   'goback'],
#  'pass': ['out.I'],
#  'out.I': ["can't"],
#  'do': ['this',
#   'that?Good',
#   'anything.-',
#   'to',
#   'anything',
#   'this',
#   'all',
#   'her',
#   'this.-',
#   'whateveryou',
#   'this',
#   'you',
#   'you',
#   'you',
#   'this?-',
#   'you',
#   'you',
#   'you',
#   'anythingto'],
#  'shit,': ['man.Tough', 'if'],
#  'man.Tough': ['shit.You'],
#  'shit.You': ['heard'],
#  'heard': ['the'],
#  'doc.Your': ['heart'],
#  'heart': ['is'],
#  'getting': ['bigger,balls', 'smaller,your'],
#  'bigger,balls': ['are'],
#  'smaller,your': ['bone'],
#  'bone': ["density's"],
#  "density's": ['for'],
#  'shit.That': ['Compound'],
#  'Compound': ['V', 'V.Compound'],
#  'V': ['shitis'],
#  'shitis': ['killing'],
#  'you.Hey.': ["Don't"],
#  "Don't": ['even', 'say', 'fucking'],
#  'even': ['say', 'The', 'her', 'the'],
#  'say': ['it', 'no?Come', 'sorry.'],
#  'loud,all': ['right?You'],
#  'right?You': ["don't"],
#  "don't": ['know',
#   'want',
#   'understand.Who',
#   'know',
#   'know,got',
#   'stir,you',
#   'thinkI',
#   'youstop',
#   'know.No,',
#   "know'cause",
#   'know,',
#   'know',
#   'mind',
#   'have',
#   'looklike',
#   'think',
#   'know',
#   'do',
#   'understand.The',
#   'wantyour',
#   'want',
#   'know.',
#   "thinkthat's",
#   'give',
#   'know'],
#  'shit': ['about', 'ab...Well,', 'about', 'is.Oh,', 'that'],
#  'about': ['it,you',
#   'now?Oh,',
#   'anyone,really.And',
#   'her,for',
#   'Annie.Fucking',
#   'her.That',
#   'Popclaw?She',
#   'us.Hey,',
#   'her?Well,',
#   'your',
#   'it.Me,',
#   "that.It's",
#   'everything.No,',
#   'his',
#   'Translucent.Okay?',
#   'Compound'],
#  'it,you': ['understand?I'],
#  'understand?I': ["don't"],
#  'know.And': ["you're"],
#  'done,': ['okay?No'],
#  'okay?No': ['more'],
#  'around.Did': ['you'],
#  'see': ['my',
#   'Ezekieland',
#   'it.Right,',
#   'it.Please?I',
#   'you.Hi,',
#   'you',
#   'you.I,'],
#  'last': ['timeout', 'timeMaeve', 'half'],
#  'timeout': ['there?Sioux'],
#  'there?Sioux': ["City's"],
#  "City's": ['got'],
#  'fuckingfaster': ['runner'],
#  'runner': ['than'],
#  'me.Then': ['no'],
#  'club': ['openingsand'],
#  'openingsand': ['commercial'],
#  'commercial': ['shoots.Okay?'],
#  'shoots.Okay?': ['None'],
#  'None': ['of'],
#  'shit.We': ['train.Back'],
#  'train.Back': ['to'],
#  'basics.Nobody': ['gets'],
#  'gets': ['it'],
#  'back': ['at', 'off,', 'with', 'at'],
#  "age.I'm": ['gonna'],
#  'be': ['a',
#   'known,I',
#   'something',
#   'loyalto',
#   'okay.',
#   'the',
#   'right',
#   'all',
#   'pretty',
#   'thrilled.Ugh,',
#   'a',
#   'gentle,',
#   'gentle.Ow,',
#   'different.Matter',
#   'my',
#   'honest.Well,',
#   'a',
#   'okay,you',
#   'safe'],
#  'freak': ['showlike'],
#  'showlike': ['Ben'],
#  'Ben': ['Johnson,racing'],
#  'Johnson,racing': ['against'],
#  'horses.At': ['least'],
#  'least': ["you'll", 'now'],
#  "you'll": ['stillbe'],
#  'stillbe': ['breathing.Shit.-'],
#  'breathing.Shit.-': ['I'],
#  'go.-': ['Where?-', 'Not'],
#  'Where?-': ["What's"],
#  'on?-': ['I'],
#  'missed': ['you'],
#  'guys.Just': ['wanted'],
#  'wanted': ['to'],
#  'seeyour': ['smiling'],
#  'smiling': ['faces.Take'],
#  'faces.Take': ['a'],
#  'seat,': ['buddy.And,'],
#  'buddy.And,': ['truth'],
#  'truth': ['be', 'is,our'],
#  'known,I': ['felt'],
#  'were': ['overduea',
#   'in',
#   'a',
#   'a',
#   'super',
#   'donewith',
#   'gonna',
#   'the',
#   'the',
#   'you'],
#  'overduea': ['little'],
#  'heart-to-heart.A': ['rap'],
#  'rap': ['session,maybe'],
#  'session,maybe': ['a'],
#  'tough': ["love.What's"],
#  "love.What's": ['that'],
#  'supposed': ['to', 'to'],
#  'mean?It': ['means'],
#  'means': ['that', '"Captain."We'],
#  'lately,some': ['of'],
#  'youhave': ['been,'],
#  'been,': ['eh,a', 'John?Long'],
#  'eh,a': ['little'],
#  'sorts.Erratic.Unreliable.Downright': ['sloppy.Not'],
#  'sloppy.Not': ['you,'],
#  "Noir.You've": ['been'],
#  'great.But': ['the'],
#  'you...It': ['is'],
#  'fair': ['to', 'game.Do'],
#  'saythat': ['I'],
#  'am': ['disappointed.Got', 'I', 'not', 'I', 'I'],
#  'disappointed.Got': ['to'],
#  'keep': ['your'],
#  'eyeon': ['the'],
#  'ball,': ['guys.The'],
#  'guys.The': ['enemiesare'],
#  'enemiesare': ['storming'],
#  'storming': ['the'],
#  'gates.I': ['mean,'],
#  'The': ['Sevenanymore,', 'Sevenis', 'Hamptons?Maybe', 'hell', 'Seven'],
#  'Sevenanymore,': ["we're"],
#  "five.We're": ['droppinglike'],
#  'droppinglike': ['fucking'],
#  'flies,but': ['at'],
#  'now': ['I', "I'm", 'doto'],
#  'why.Uh...Why...Is': ['this'],
#  'joke?Why': ['is'],
#  'Hughie': ['up', 'is'],
#  'there?I': ["don't"],
#  'understand.Who': ['is'],
#  'guy?This': ['guy'],
#  'guy': ['is', 'who'],
#  'Hugh': ['Campbell.He', 'Campbell', 'Campbell.-'],
#  'Campbell.He': ['and'],
#  'Starlightare': ['going'],
#  "steady.He's": ['also'],
#  'also': ['one'],
#  'one': ['of', 'of', 'at', 'of', 'of', 'of', 'calls', 'could'],
#  'guyswho': ['killed'],
#  'killed': ['Translucent.Wait,', 'Translucent.This'],
#  'Translucent.Wait,': ['what?As'],
#  'what?As': ['well'],
#  'well': ['as'],
#  'blackmailingMesmer,': ['Ezekiel,'],
#  'Ezekiel,': ['Popclaw-'],
#  'Popclaw-': ['and'],
#  'God': ['knows'],
#  'knows': ['who'],
#  'who': ['else.-', 'killed'],
#  'else.-': ['Popclaw?No.'],
#  'Popclaw?No.': ['No,'],
#  'no.You...': ['That-that'],
#  'That-that': ['is'],
#  'insane.Starlight,': ['sticks'],
#  'sticks': ['and'],
#  "stoneswon't": ['break'],
#  'break': ['my'],
#  'bones,-': ['but'],
#  'words...-': ['No,'],
#  "sir.I'm": ['sorry.'],
#  'sorry.': ['I', 'No.Look'],
#  "wasn't...It's": ['just,'],
#  'just,': ["he's", 'uh...Ah...'],
#  "he's": ['not...I', 'pumping', 'burned,then', 'a'],
#  'not...I': ['mean,'],
#  'that?Good': ['question.A-Train,'],
#  'question.A-Train,': ['over'],
#  'over': ['to', 'herein', 'again,only'],
#  'boy.That': ['little'],
#  'egg': ['of'],
#  'yoursis': ['still'],
#  'still': ['scrambled,', 'me,'],
#  'scrambled,': ['huh?How'],
#  'huh?How': ['about'],
#  'now?Oh,': ['shit.I'],
#  'shit.I': ['know'],
#  'guy.You': ['did'],
#  'smashthrough': ['his'],
#  'girlfriend,so': ['I'],
#  'should': ['hope', "go.I'm", 'have'],
#  'hope': ['so.Robin', 'she'],
#  'so.Robin': ['s-something'],
#  's-something': ['or'],
#  'other.I-I': ['remember'],
#  'remember': ['now,', 'the'],
#  'now,': ["I-I've", "Butcher,you're", 'but...Merde!Butcher.-'],
#  "I-I've": ['seenhim'],
#  'seenhim': ['outside'],
#  'outside': ['of'],
#  "Popclaw's": ['place.He'],
#  'place.He': ['was'],
#  'face.-': ["You're"],
#  "You're": ['fucking', 'wrong', 'right.'],
#  'guy?-': ['S...'],
#  'S...': ['Okay,'],
#  'Okay,': ['slow'],
#  'slow': ['down.I'],
#  'down.I': ["don't"],
#  "what's": ['going', 'better,the', 'the'],
#  'on,but': ['Hughie'],
#  'capableof': ['anything'],
#  'anything': ['close', 'for'],
#  'close': ['to'],
#  'this.Well,': ['that'],
#  'true,': ["actually.That's"],
#  "actually.That's": ['very'],
#  'true.He': ['is'],
#  'man,': ['and,by'],
#  'and,by': ['the'],
#  'looks': ['of', 'like'],
#  'it,not': ['much'],
#  'one.But...': ['but'],
#  'hear': ['me'],
#  'out.W-What': ['if'],
#  'helped?': ['Hmm?Say'],
#  'Hmm?Say': ['someone,I'],
#  'someone,I': ["don't"],
#  'know,got': ['him'],
#  'him': ['in', 'go.My', 'go.Alone,', 'go,', 'up.Great.The'],
#  'Ezekieland': ['got'],
#  'rid': ['of'],
#  'Deep.Whoa,': ['whoa,'],
#  'whoa,': ['whoa,', 'whoa,', 'whoa.Hold'],
#  'whoa.Hold': ['on.Keep'],
#  'on.Keep': ['those'],
#  'those': ['hands', 'gills.Oh,'],
#  'hands': ['downby'],
#  'downby': ['your'],
#  'sides,': ['missy.Sit'],
#  'missy.Sit': ['down.Now...'],
#  'down.Now...': ['I'],
#  'knowthat': ['you'],
#  'makethis': ['whole'],
#  'Deep': ['thingan'],
#  'thingan': ['"All'],
#  '"All': ['the'],
#  'single': ['ladies"moment.Power,'],
#  'ladies"moment.Power,': ['right?But'],
#  'right?But': ['really,'],
#  "you've": ['doneis', 'reached', 'reached'],
#  'doneis': ['pulled'],
#  'pulled': ['offevery'],
#  'offevery': ["criminal's"],
#  "criminal's": ['wet'],
#  'wet': ['dream.I'],
#  'dream.I': ['mean,'],
#  'Sevenis': ['down'],
#  'by': ['two.I', 'God.I'],
#  'two.I': ['just'],
#  'help': ['noticingthat', 'Mommypack', 'you.Becca?Your', 'you'],
#  'noticingthat': ['it'],
#  'startedwhen': ['you'],
#  'came': ['along,which', 'alone.You'],
#  'along,which': ['makes'],
#  'makes': ['me'],
#  'wonder,which': ['one'],
#  'us': ['is', 'do', 'in', 'on', 'ahead'],
#  'next,': ['hmm?You'],
#  'hmm?You': ['bitch.-'],
#  'bitch.-': ['I'],
#  'anything.-': ["Enough!We're", 'All'],
#  "Enough!We're": ['a'],
#  'different': ['fucking'],
#  'breed.We': ['shine'],
#  'shine': ['with'],
#  'golden': ['lightof'],
#  'lightof': ['providence,'],
#  'providence,': ['but'],
#  "you,you've": ['been'],
#  'helping': ['thesefucking'],
#  'thesefucking': ['mud'],
#  'mud': ['people-'],
#  'people-': ['to'],
#  'go': ['against', 'to', 'be', 'to', 'bankrupt,and'],
#  'us.-': ['No.Shut'],
#  'No.Shut': ['your'],
#  'mouth,young': ['lady.If'],
#  'lady.If': ['you'],
#  'position......what': ['would'],
#  'you?Homelander,': ["that's"],
#  'enough.You': ['got'],
#  'add,': ['Maeve?She'],
#  'Maeve?She': ["didn't"],
#  'know.Well,': ['she'],
#  'she': ['stinks',
#   'was',
#   'was',
#   'quit.Quit?Is',
#   'doing?Uh,',
#   'does.Dad,',
#   "didn't",
#   'had'],
#  'stinks': ['of'],
#  'adrenalineand': ['her'],
#  'her': ["heart's",
#   'alone.Wow.Starlight,you',
#   'one',
#   'anything.-',
#   'in.-',
#   'in',
#   'outlike',
#   'file,',
#   'husband...Well,',
#   'with',
#   "we'd",
#   'husband.You'],
#  "heart's": ['beatinglike'],
#  'beatinglike': ['a'],
#  'rabbit.The': ['only'],
#  'only': ['thing', 'good', 'differencebetween', 'thing,', 'thingthat'],
#  'thing': ["she's", 'up.How', 'aboutcross-breeding'],
#  "she's": ['guilty', 'missing.What', 'missing?I'],
#  'guilty': ['ofis'],
#  'ofis': ['being'],
#  'being': ['fucking', 'an', 'for.Oh,'],
#  'stupid.She': ['obviously'],
#  'obviously': ['fellfor'],
#  'fellfor': ['this'],
#  'Campbell': ['guyand'],
#  'guyand': ["he's"],
#  'pumping': ['herfor'],
#  'herfor': ['information,so'],
#  'information,so': ['back'],
#  'off,': ['leave'],
#  'alone.Wow.Starlight,you': ['must'],
#  'must': ['be', 'be'],
#  'special.Hmm?I': ["can't"],
#  'timeMaeve': ['gave'],
#  'gave': ['a', 'a', 'me'],
#  'ab...Well,': ['gave'],
#  'anyone,really.And': ['if'],
#  'no?Come': ['on.I'],
#  'on.I': ['got'],
#  "this.It's": ['you'],
#  "me,remember?Don't": ['sayI'],
#  'sayI': ['never'],
#  'you.All': ['right.You'],
#  'right.You': ['want'],
#  'her,': ['you', 'she...No.'],
#  "her.She's": ['your', 'never'],
#  'responsibility': ['now.I'],
#  'now.I': ['just'],
#  "hopeyou're": ['right'],
#  'right': ['about',
#   'behind',
#   'now.-',
#   "now...What's",
#   'genes,you',
#   'now,',
#   'this'],
#  'her,for': ['both'],
#  'both': ['your'],
#  'sakes.Class': ['dismissed.Look'],
#  'dismissed.Look': ['at'],
#  'this.Oh,': ['no.'],
#  'no.': ['You', "I'm", "Don't"],
#  'stir,you': ['fold.'],
#  'fold.': ['Like'],
#  'Like': ['this.Now', 'you'],
#  'this.Now': ["that's"],
#  'whatmakes': ['them'],
#  'them': ['spongy.Here', 'loose.For'],
#  'spongy.Here': ['you'],
#  'go.She': ['wants'],
#  'wants': ['to'],
#  'knowwhere': ['you'],
#  "were.That's": ['a'],
#  'compellingfucking': ['question.Hey,'],
#  'question.Hey,': ['can'],
#  "talk?That's": ['what'],
#  'doing,innit?No,': ['I'],
#  'mean...There': ["ain't"],
#  "ain't": ['no', 'thinking,-', 'blaming', 'your', 'nothing'],
#  'secrets': ['here,son.'],
#  'here,son.': ['Spit'],
#  'Spit': ['it'],
#  'out.Stop': ['being'],
#  'asshole,just': ['talk'],
#  'guy.Hughie': ["doesn't"],
#  "doesn't": ['mind.Do',
#   'know',
#   'knowand',
#   "care?How's",
#   'know.-',
#   'matter.-',
#   'know.',
#   'matterhow',
#   'quitehave'],
#  'mind.Do': ['you,'],
#  'Hughie?Okay,': ['fine.'],
#  'fine.': ['I'],
#  'thinkI': ['can'],
#  'anymore.-': ['Do'],
#  'Do': ['what?-', 'what?-'],
#  'what?-': ['This.I', 'This'],
#  'This.I': ['mean,'],
#  'Vought,whatever': ['with'],
#  "Kimiko,it's-it's": ['awful,and'],
#  'awful,and': ['you'],
#  'stop': ['it,-'],
#  'it,-': ['but'],
#  "can't.-": ['Right.You'],
#  'Right.You': ['just'],
#  'kick': ['back,drink'],
#  'back,drink': ['a'],
#  'Mai': ['Tais,and'],
#  'Tais,and': ['let'],
#  'work,is': ['that'],
#  'it?You': ['know,', 'know,'],
#  'managed': ['to'],
#  'gomy': ['whole'],
#  'lifewithout': ['seeing'],
#  'seeing': ['someonedie'],
#  'someonedie': ['horribly,and'],
#  'horribly,and': ['now'],
#  'abouta': ['half'],
#  'dozen,-': ['so'],
#  'good.-': ["Please.You're"],
#  "Please.You're": ['a'],
#  'killer,': ['Hughie,just'],
#  'Hughie,just': ['like'],
#  'us.Now,': ['why'],
#  'youstop': ['pissing'],
#  'pissing': ['aroundand'],
#  'aroundand': ['tell'],
#  'tell': ['everybody', 'her', 'me', 'me', 'anyone.Not', 'me?To', 'mewhat'],
#  'everybody': ['what'],
#  'thisis': ['really'],
#  'about?-': ['Yeah?-', 'Shut'],
#  'Fine.Annie.-': ['Fuck.-'],
#  'Fuck.-': ["Okay?It's"],
#  "Okay?It's": ['about'],
#  'Annie.Fucking': ["finally.He's"],
#  "finally.He's": ['been'],
#  'sneaking': ['off'],
#  'off': ['togive', 'to'],
#  'togive': ['her'],
#  'Lincoln': ['Grand.-'],
#  'Grand.-': ["You've"],
#  "You've": ['been', 'reached'],
#  'following': ['me?-'],
#  'me?-': ['Like', 'You'],
#  'choice.She': ["doesn't"],
#  'anything,': ["okay?I'm"],
#  "okay?I'm": ['not'],
#  'All': ['right?', 'right.Take', 'right.-'],
#  'right?': ["We'll", 'All'],
#  "We'll": ['just...-'],
#  'just...-': ['Just'],
#  'what?Fuck': ['off'],
#  'Epcot?': ['The'],
#  'Hamptons?Maybe': ['pump'],
#  'pump': ['out'],
#  'fewflying': ['babies?No.'],
#  'babies?No.': ['I...'],
#  'I...': ['I'],
#  'know.No,': ['you'],
#  "know'cause": ['you'],
#  'thinking,-': ['except'],
#  'except': ['with'],
#  'dick.-': ["You're"],
#  'wrong': ['about', 'with'],
#  'her.That': ['bitch'],
#  'bitch': ['is'],
#  'fuckingplaying': ['you,and'],
#  'you,and': ["you're", 'what'],
#  'too': ['fucking', 'late.I'],
#  'blindto': ['see'],
#  'it.Right,': ['so'],
#  'loyalto': ['a'],
#  'womanwho': ["doesn't"],
#  'knowand': ["doesn't"],
#  "care?How's": ['that'],
#  'working': ['out'],
#  'you?-': ['Hey,'],
#  'Hey,': ['Dad.-', 'Hughie.Long'],
#  'Dad.-': ['Hey,', 'Oh.'],
#  'Hughie.Long': ['time'],
#  'time': ['no', 'obsessingabout', 'to', 'to'],
#  'talk.You': ['know,'],
#  "I've": ['been'],
#  'thinkingabout': ['you'],
#  'lot': ["lately.Who's"],
#  "lately.Who's": ['this?I'],
#  'this?I': ['thought'],
#  'thought': ['you', 'I'],
#  'wouldrecognize': ['my'],
#  'voice.You': ['spend'],
#  'spend': ['so'],
#  'obsessingabout': ['me,'],
#  'me,': ['am', 'sir.-', 'sir.Oh,', 'okay?I', 'Annie.Please.'],
#  'right?-': ['Say'],
#  'Say': ['hi'],
#  'hi': ['to'],
#  'baby': ['boy,', 'and......maybe', 'safelyat', 'clawed'],
#  'boy,': ['Dad.-'],
#  'Oh.': ['H-Hey,'],
#  'H-Hey,': ['hey,'],
#  'hey,': ['hey,', 'Hughie.Why'],
#  'Hughie.Why': ['is'],
#  'here?': ['He'],
#  'He': ['says', "ain't"],
#  'says': ["you'rein"],
#  "you'rein": ['some'],
#  'trouble.Dad,': ['are'],
#  'okay?Oh,': ["o-okay.He's"],
#  "o-okay.He's": ['fine.Remington'],
#  'fine.Remington': ["Steele's"],
#  "Steele's": ['almost'],
#  'almost': ['on.A-Train,'],
#  'on.A-Train,': ['listen'],
#  'listen': ['to', 'to'],
#  'me.Oh,': ['shit,', 'my'],
#  'burned,then': ["I'm"],
#  "fucked.He's": ['on'],
#  "Medicaid.He's": ['harmless.'],
#  'harmless.': ['Let'],
#  'Let': ['him'],
#  'go.My': ['place'],
#  "burned.They've": ['got'],
#  'God.Get': ['your'],
#  'ass': ['over'],
#  'herein': ['20'],
#  '20': ['minutes,or'],
#  'minutes,or': ["I'm"],
#  'burst': ['through'],
#  'through': ['himlike'],
#  'himlike': ['a'],
#  'piñata,do': ['you'],
#  'understand': ['me?Just'],
#  'me?Just': ['like'],
#  'girlfriend.-': ['Yeah.'],
#  'Yeah.': ['Got'],
#  'Got': ['it.-'],
#  'And,': ['Hughie,alone.'],
#  'Hughie,alone.': ['If'],
#  'If': ['I', 'you'],
#  'catch': ['a', 'up'],
#  'whiff,a': ['whiff'],
#  'whiff': ['of'],
#  'your-': ['little'],
#  'asshole': ['friends...-'],
#  'friends...-': ['I'],
#  'it.All': ['my'],
#  'bank': ['accounts'],
#  'accounts': ['are'],
#  'frozenand': ['flagged.'],
#  'flagged.': ['Monique,listen,'],
#  'Monique,listen,': ['when'],
#  'when': ['you'],
#  'this,leave': ['the'],
#  'house': ['immediately.Lay'],
#  'immediately.Lay': ['low'],
#  'low': ['and', 'end.-'],
#  'call': ['me.-', 'me', 'her.Please.Yeah.There'],
#  'Well,': ['I', 'most', "yeah.He's", "that's"],
#  'worth': ['it.-', 'running'],
#  "It's": ['not', "okay.It's"],
#  'Annie.-': ['She', 'I'],
#  'She': ["doesn't", 'looks'],
#  'know.-': ['It'],
#  'matter.-': ["I'm"],
#  'in.-': ['The', 'What...'],
#  'hell': ['you', 'of', 'is'],
#  'will!Hey,': ['hold'],
#  'second.She': ["doesn't"],
#  'know.': ['It', 'I'],
#  "wasn't": ["her.She's"],
#  'before.Not': ['once,'],
#  'once,': ['not'],
#  'ever.So': ['how'],
#  'how': ['did', 'that'],
#  'burned?Mesmer.': ['You'],
#  'idiotshad': ['to'],
#  'Mesmer.Fuck': ['me.Thank'],
#  'me.Thank': ['you.That'],
#  'you.That': ['was'],
#  'smart,to': ['sleep'],
#  'sleep': ['with'],
#  'her.-': ['Hughie.-'],
#  'Hughie.-': ["Dad.He's"],
#  "Dad.He's": ['acting'],
#  'acting': ['strange.You'],
#  'strange.You': ['know,'],
#  'real': ['jumpy.-', 'dosehidden'],
#  'jumpy.-': ['Where'],
#  'Where': ['is', 'the'],
#  'he?-': ['I'],
#  'he...Right': ['here,'],
#  'here,': ['sport.Look', 'then,', 'baby.Mmm.Daddy'],
#  'sport.Look': ['what'],
#  'got.Special': ['2016'],
#  '2016': ['Comic-Con'],
#  'Comic-Con': ['edition?What,'],
#  'edition?What,': ['did'],
#  'make,': ['like,a'],
#  'like,a': ['few'],
#  'hundred': ['of'],
#  'these?Watch': ['out,'],
#  'out,': ["A-Train's"],
#  "A-Train's": ['coming.You'],
#  'coming.You': ['were'],
#  'fan!You': ['were'],
#  'fan,': ['and'],
#  'not,like,': ['a'],
#  'dabbler,': ['no,you'],
#  'no,you': ['were'],
#  'super': ['fan'],
#  'fan': ['99.Excuse'],
#  '99.Excuse': ['me,'],
#  'sir.-': ['W-What'],
#  'W-What': ['is', 'is'],
#  'Shut': ['the'],
#  'up.Dad,': ["it's"],
#  'okay.': ['Hey.I', "It's"],
#  'Hey.I': ['came'],
#  'alone.You': ['let'],
#  'go.Alone,': ['huh?-'],
#  'huh?-': ['Wow.-'],
#  'Wow.-': ['Ah!You', 'Yeah.I'],
#  'Ah!You': ['really'],
#  'come': ['alone.Next',
#   "alone.Monique,it's",
#   'here.Give',
#   'to',
#   'to',
#   'on.All'],
#  'alone.Next': ['time...'],
#  'time...': ["there's"],
#  ...}

# %%
generate_sentence(eric_dict)
# Out:
# 'Know what are frozenand flagged. Monique,listen, when you and you bring meto get a good!'
